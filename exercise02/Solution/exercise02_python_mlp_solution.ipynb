# %% [markdown]
# # Second exercise (Chapter 6 & 8)
#
# In this exercise we consider Chapters 6 & 8 of the book "Deep Learning". The exercise focuses on implementing a small feedforward neural network and training it on the MNIST dataset.
#
# We provide code for structure and utility, you have to **fill in the TODO-gaps**.
# It might initially look like a lot of unnecessary code, but it keeps the network extensible. In the following exercises you can reuse what you've done here. Most common neural network libraries (*pytorch*, *tensorflow/keras*, …) are similarly structured, hence they will be easy to use once you've finished this notebook. As we will be using *pytorch* towards the end of the lecture, our API resembles the API of the pytorch framework.
#
#
# We will implement two different cost functions and play a bit with the value of the different hyperparameters to see how performances change as a function of those. In particular, we will focus on
#
# * Sigmoid Neurons
# * Stochastic Gradient Descent
# * Quadratic Cost Function
# * Cross Entropy Cost Function
# * Learning Rate
# * Generalization
#
# Note that we'll implement all of these operations to operate on mini-batches of data.

# %%
# Some imports used in the code below

from typing import Iterable, List, Optional, Tuple  # type annotations
import pickle  # data loading
import gzip  # data loading

import numpy as np  # linear algebra
import matplotlib.pyplot as plt  # plotting
import scipy.optimize  # gradient check

# %% [markdown]
# The cell below contains the two main classes to structure your network.
#
# **Parameter** is used to represent trainable variables in the network, e.g., a layer's weights $w$. The weights themself are a *numpy array* as the parameter's `data` attribute. The associated parameter gradient (e.g. $\frac{\partial L}{\partial w}$) can be stored in the `grad` attribute.
#
#
#
# **Module** is the base class for all parts of the network (activations, layers, …) and even the network itself. They all have to implement the `forward` and `backward` methods. For backpropagation activation will flow *forward* and gradient will flow *backward* through the *network graph and it's modules*.
#
# Additional module provides utility to check the correctness of implementation by approximating *backward* with [finite difference approximations](https://en.wikipedia.org/wiki/Finite_difference#Relation_with_derivatives)  of *forward*.
#
# *Note:* All modules operate on batches of samples. E.g. the input shape of `Linear.forward` is `(batch_size, feature_shape, 1)` (we will use the last dimension in future exercises).

# %%
class Parameter:
    """A trainable parameter.

    This class not only stores the value of the parameter (self.data) but also tensors/
    properties associated with it, such as the gradient (self.grad) of the current backward
    pass.
    """

    def __init__(self, data: np.ndarray, grad: Optional[np.ndarray] = None, name=None):
        self.data = data  # type: np.ndarray
        self.grad = grad  # type: Optional[np.ndarray]
        self.name = name  # type: Optional[str]
        self.state_dict = dict()  # dict to store additional, optional information
        
        
class Module:
    """The base class all network modules must inherit from."""

    def __init__(self):
        # Cache of the input of the forward pass.
        # We need it during the backward pass in most layers,
        #  e.g., to compute the gradient w.r.t to the weights.
        self.input_cache = None

    def __call__(self, *args) -> np.ndarray:
        """Alias for forward, convenience function."""
        return self.forward(*args)

    def forward(self, *args) -> np.ndarray:
        """Compute the forward pass through the module.

        Args:
           args: The inputs, e.g., the output of the previous layer.
        """
        raise NotImplementedError

    def backward(self, grad: np.ndarray) -> np.ndarray:
        """Compute the backward pass through the module.

        This method computes the gradients with respect to the trainable
        parameters and with respect to the first input.
        If the module has trainable parameters, this method needs to update
        the respective parameter.grad property.

        Args:
            grad: The gradient of the following layer.

        Returns:
            The gradient with respect to the first input argument. In general
            it might be useful to return the gradients w.r.t. to all inputs, we
            omit this here to keep things simple.
        """
        raise NotImplementedError

    def parameters(self) -> List[Parameter]:
        """Return the module parameters."""
        return []  # default to empty list

    def check_gradients(self, input_args: Tuple[np.ndarray]):
        """Verify the implementation of the gradients.

        This includes the gradient with respect to the input as well as the
        gradients w.r.t. the parameters if the module contains any.

        As the scipy grad check only works on scalar functions, we compute
        the sum over the output to obtain a scalar.
        """
        assert isinstance(input_args, tuple), (
            "input_args must be a tuple but is {}".format(type(input_args)))
        TOLERANCE = 1e-6
        self.check_gradients_wrt_input(input_args, TOLERANCE)
        self.check_gradients_wrt_params(input_args, TOLERANCE)

    def _zero_grad(self):
        """(Re-) intialize the param's grads to 0. Helper for grad checking."""
        for p in self.parameters():
            p.grad = np.zeros_like(p.data)

    def check_gradients_wrt_input(self, input_args: Tuple[np.ndarray],
                                  tolerance: float):
        """Verify the implementation of the module's gradient w.r.t. input."""

        def output_given_input(x: np.ndarray):
            """Wrap self.forward for scipy.optimize.check_grad."""
            # we only compute the gradient w.r.t. to the first input arg.
            args = (x.reshape(input_args[0].shape),) + input_args[1:]
            return np.sum(self.forward(*args))

        def grad_given_input(x: np.ndarray):
            """Wrap self.backward for scipy.optimize.check_grad."""
            self._zero_grad()
            # run self.forward to store the new input
            args = (x.reshape(input_args[0].shape),) + input_args[1:]
            out = self.forward(*args)
            # compute the gradient w.r.t. to the input
            return np.ravel(self.backward(np.ones_like(out)))

        error = scipy.optimize.check_grad(
            output_given_input, grad_given_input, np.ravel(input_args[0]))
        num_outputs = np.prod(self.forward(*input_args).shape)
        if np.squeeze(error) / num_outputs > tolerance:
            raise RuntimeError("Check of gradient w.r.t. to input for {} failed."
                               "Error {:.4E} > {:.4E}."
                               .format(self, np.squeeze(error), tolerance))

    def check_gradients_wrt_params(self, input_args: Tuple[np.ndarray],
                                   tolerance: float):
        """Verify the implementation of the module's gradient w.r.t. params."""
        for param in self.parameters():
            def output_given_params(new_param: np.ndarray):
                """Wrap self.forward, change the parameters to new_param."""
                param.data = new_param.reshape(param.data.shape)
                return np.sum(self.forward(*input_args))

            def grad_given_params(new_param: np.ndarray):
                self._zero_grad()
                param.data = new_param.reshape(param.data.shape)
                out = self.forward(*input_args)
                # compute the gradient w.r.t. to param
                self.backward(np.ones_like(out))
                return np.ravel(param.grad)
            # flatten the param as scipy can only handle 1D params
            param_init = np.ravel(np.copy(param.data))
            error = scipy.optimize.check_grad(output_given_params,
                                              grad_given_params,
                                              param_init)
            num_outputs = np.prod(self.forward(*input_args).shape)
            if np.squeeze(error) / num_outputs > tolerance:
                raise RuntimeError("Check of gradient w.r.t. to param '{}' for"
                                   "{} failed. Error {:.4E} > {:.4E}."
                                   .format(param.name, self, error, tolerance))

# %% [markdown]
# # Nonlinearities
#
# ## Sigmoid
#
# Implement your first network module: The sigmoid activation function.
#
# Verify your sigmoid function by plotting.

# %%
class Sigmoid(Module):
    def _sigmoid(self, z: np.ndarray) -> np.ndarray:
        # START TODO ################
        # raise NotImplementedError
        return 1.0 / (1.0 + np.exp(-z))
        # END TODO###################

    def forward(self, z: np.ndarray) -> np.ndarray:
        assert len(z.shape) == 3, ("z.shape should be (batch_size, input_size, 1)"
                                   " but is {}.".format(z.shape))
        h = self._sigmoid(z)
        
        # here it's useful to store the activation 
        #  instead of the input
        self.input_cache = h
        
        return h

    def backward(self, grad: np.ndarray) -> np.ndarray:
        h = self.input_cache
        # START TODO ################
        # raise NotImplementedError
        return grad * h * (1 - h)
        # END TODO###################

# %%
x = np.linspace(-4, +4, 100)
sigmoid = Sigmoid()

y = np.ravel(sigmoid(x.reshape(-1, 1, 1)))
# equal to call of sigmoid.forward(x)
    
plt.plot(x,y)
plt.xlabel('input')
plt.ylabel('output')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Relu
#
# Implement Relu and plot for verification

# %%
class Relu(Module):
    def forward(self, z: np.ndarray) -> np.ndarray:
        self.input_cache = z
        # START TODO ################
        # raise NotImplementedError
        return np.maximum(0, z)
        # END TODO###################

    def backward(self, grad: np.ndarray) -> np.ndarray:
        z = self.input_cache
        # START TODO ################
        # raise NotImplementedError
        return grad.reshape(z.shape) * np.where(z > 0, 1, 0)
        # END TODO###################

# %%
# Plot Relu

# START TODO ################
x = np.linspace(-4, +4, 100)
relu = Relu()

y = np.ravel(relu(x.reshape(-1, 1, 1)))
    
plt.plot(x,y)
plt.xlabel('input')
plt.ylabel('output')
plt.grid(True)
plt.show()
# END TODO###################

# %% [markdown]
# ## Softmax
#
# Implement the numerical stable softmax. We will not need the backward pass.

# %%
class Softmax(Module):
    def _softmax(self, z):
        # don't reduce (sum) over batch axis
        reduction_axes = tuple(range(1, len(z.shape))) 
        
        # START TODO ################
        # raise NotImplementedError
        # Shift input for numerical stability.
        shift_z = z - np.max(z, axis=reduction_axes, keepdims=True)
        exps = np.exp(shift_z)
        h = exps / np.sum(exps, axis=reduction_axes, keepdims=True)
        # END TODO###################
        return h
    
    def forward(self, z: np.ndarray) -> np.ndarray:
        h = self._softmax(z)
        return h

    def backward(self, grad) -> np.ndarray:
        error_msg = ("Softmax doesn't need to implement a gradient here, as it's"
                     "only needed in CrossEntropyLoss, where we can simplify"
                     "the gradient for the combined expression.")
        raise NotImplementedError(error_msg)

# %%
# Check your softmax
softmax = Softmax()
x = np.array([1.0, 2.0, 3.0, 4.0, 1.0, 2.0, 3.0]).reshape(1, -1, 1)

# Testcase from https://en.wikipedia.org/wiki/Softmax_function#Example
np.testing.assert_allclose(
    np.ravel(softmax(x)), 
    [0.02364054, 0.06426166, 0.1746813, 0.474833, 0.02364054, 0.06426166, 0.1746813],
    rtol=1e-5, err_msg="Softmax is not correct implemented")

# %% [markdown]
# # Linear Layer
#
# Implement a linear (in other frameworks also called dense or fully connected) network layer.
# Here you also have to use the Parameter class.

# %%
class Linear(Module):

    def __init__(self, in_features: int, out_features: int):
        super().__init__()
        
        w_data = 0.01 * np.random.randn(out_features, in_features)
        self.W = Parameter(w_data, "W")
        
        b_data = 0.01 * np.ones((out_features, 1))
        self.b = Parameter(b_data, "b")

    def forward(self, x: np.ndarray) -> np.ndarray:
        assert len(x.shape) == 3, ("x.shape should be (batch_size, input_size, 1)"
                                   " but is {}.".format(x.shape))
        self.input_cache = x
        # START TODO ################
        # Remember: Access weight data through self.W.data
        # raise NotImplementedError
        z = self.W.data @ x + self.b.data
        return z
        # END TODO ##################

    def backward(self, grad: np.ndarray) -> np.ndarray:
        x = self.input_cache
        # remember that input has a batch dimension when transposing, i.e.,
        # we need to use np.transpose instead of x.T
        x_transpose = np.transpose(x, [0, 2, 1])
        
        # START TODO ################ 
        # self.W.grad += ...
        # ...
        # raise NotImplementedError
        self.W.grad += np.sum(grad @ x_transpose, axis=0)
        self.b.grad += np.sum(grad, axis=0)
        return self.W.data.T @ grad        
        # END TODO ##################
    

    def parameters(self) -> List[Parameter]:
        # START TODO ################ 
        # Return all parameters of Linear
        # raise NotImplementedError
        return self.W, self.b
        # END TODO ##################

# %% [markdown]
# # Cost Functions

# %%
# Define the Cross-Entropy cost functions
class CrossEntropyLoss(Module):
    """Compute the cross entropy."""

    def __init__(self):
        super().__init__()
        self.softmax = Softmax()

    def forward(self, a: np.ndarray, y: np.ndarray) -> np.ndarray:
        """Compute the cross entropy, mean over batch size."""
        a = self.softmax(a)
        self.input_cache = a, y
        # compute the mean over the batch
        return -np.sum(np.log(a[y == 1])) / len(a)

    def backward(self, _=None) -> np.ndarray:
        # we introduce the argument _ here, to have a unified interface with
        # other Module objects. This simplifies code for gradient checking. 
        # We don't need this arg.
        a, y = self.input_cache
        
        # START TODO ################ 
        # raise NotImplementedError
        grad = (a - y) / len(a)
        # Recreate the batch dimension
        grad = np.expand_dims(grad, -1)
        # END TODO ##################
        
        assert len(grad.shape) == 3, ("CrossEntropyLoss.backward should return (batch_size, grad_size, 1)"
                                      " but is {}.".format(z.shape))
        return grad


class MSELoss(Module):
    """Compute the mean squared error loss."""

    def forward(self, a: np.ndarray, y: np.ndarray) -> np.ndarray:
        self.input_cache = a, y
        return np.sum(0.5 * np.linalg.norm(a - y, axis=-1)**2) / len(a)

    def backward(self, _=None):
        # we introduce the argument _ here, to have a unified interface with
        # other Module objects. This simplifies code for gradient checking. 
        # We don't need this arg
        a, y = self.input_cache
        
        # START TODO ################ 
        # raise NotImplementedError
        grad = (a - y) / len(a)
        # Recreate the batch dimension
        grad = np.expand_dims(grad, -1) 
        # END TODO ##################
        
        assert len(grad.shape) == 3, ("MSELossCrossEntropyLoss.backward should return (batch_size, grad_size, 1)"
                                      " but is {}.".format(z.shape))
        return grad

# %% [markdown]
# # Sequential Network

# %%
class Sequential(Module):
    """A sequential container to stack modules.

    Modules will be added to it in the order they are passed to the
    constructor.

    Example network with one hidden layer:
    model = Sequential(
                  Linear(5,10),
                  ReLU(),
                  Linear(10,10),
                )
    """
    def __init__(self, *args: List[Module]):
        super().__init__()
        self.modules = args

    def forward(self, x: np.ndarray) -> np.ndarray:
        # START TODO ################ 
        # raise NotImplementedError
        # Remember: module(x) is equivalent to module.forward(x)
        for module in self.modules:
            x = module(x)  
        # END TODO ##################
        return x

    def backward(self, grad: np.ndarray) -> np.ndarray:
        # START TODO ################ 
        # raise NotImplementedError
        for module in reversed(self.modules):
            grad = module.backward(grad)
        # END TODO ##################
        return grad

    def parameters(self) -> List[Parameter]:
        # iterate over modules and retrieve their parameters, iterate over
        # parameters to flatten the list
        return [param for module in self.modules
                for param in module.parameters()]

# %% [markdown]
# # One hot encoding
# To handle categorical data, we need to implement the one_hot_encoding utility function.

# %%
def one_hot_encoding(y: np.ndarray, num_classes: int) -> np.ndarray:
    """Convert integer labels to one hot encoding.

    Example: y=[1, 2] --> [[0, 1, 0], [0, 0, 1]]
    """
    # START TODO ################ 
    # raise NotImplementedError
    encoded = np.zeros(y.shape + (num_classes,))
    encoded[np.arange(len(y)), y] = 1
    # END TODO ##################
    return encoded


y = np.array([1, 2, 0])
np.testing.assert_equal(one_hot_encoding(y, 3), [[0, 1, 0], [0, 0, 1], [1, 0, 0]])

# %% [markdown]
# # Gradient Check
#
# Gradient checking is a useful utility to check, whether forward and backward pass are matching.
# Backward passes are approximated by finite differences of the forward pass.
# We have implemented the gradient checking in the Module class for you. As all classes we defined up to here inherit from Module, we can run `check_gradients`.

# %%
input_vector = np.random.uniform(-1., 1., size=(2, 10, 1))
input_args = (input_vector,)

# layers + activations
Relu().check_gradients(input_args)
Sigmoid().check_gradients(input_args)
Linear(10, 30).check_gradients(input_args)

# MLP
# START TODO ################ 
# raise NotImplementedError
# gradient check a Sequential network with 
# layers: linear, sigmoid, linear, sigmoid
model = Sequential(Linear(10, 30),
                   Sigmoid(),
                   Linear(30, 10)
                   )
model.check_gradients(input_args)
# END TODO ##################

# losses
input_args_losses = (one_hot_encoding(np.array([1, 2]), 3),  # a
                     one_hot_encoding(np.array([1, 1]), 3))  # y (ground truth)
MSELoss().check_gradients(input_args_losses)
CrossEntropyLoss().check_gradients(input_args_losses)

# %% [markdown]
# # Optimizers
#
# Below you see the base class for all optimizers. An Optimizer needs to implement the `step()` function, which updates the parameters passed to the constructor.

# %%
class Optimizer:
    """The base class for optimizers.

    All optimizers must implement a step() method that updates the parameters.
    The general optimization loop then looks like this:

    for inputs, targets in dataset:
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = loss_fn(outputs, targets)
        loss.backward()
        optimizer.step()

    `zero_grad` initializes the gradients of the parameters to zero. This
    allows to accumulate gradients (instead of replacing it) during
    backpropagation, which is e.g. useful for skip connections.
    """

    def __init__(self, params: Iterable[Parameter]):
        """
        Args:
            params: The parameters to be optimized.
        """
        self._params = params

    def step(self) -> None:
        """Update the parameters."""
        raise NotImplementedError

    def zero_grad(self) -> None:
        """Clear the gradients of all optimized parameters."""
        for param in self._params:
            assert isinstance(param, Parameter)
            param.grad = np.zeros_like(param.data)

# %% [markdown]
# ## SGD
#
# Implement stochastic gradient descent (Chapter 5, Chapter 8).
# The momentum parameter improves training speed (Chapter 8.3).

# %%
class SGD(Optimizer):
    """Stochastic Gradient Descent (SGD) optimizer with optional Momentum."""

    def __init__(self, params: Iterable[Parameter], lr: float,
                 momentum: Optional[float] = None):
        super().__init__(params)
        self.lr = lr
        self.momentum = momentum
        if momentum:
            for param in self._params:
                param.state_dict["momentum"] = np.zeros_like(param.data)

    def step(self):
        for p in self._params:
            if self.momentum:
                # SGD with Momentum
                # START TODO ################ 
                # raise NotImplementedError
                # update the momentum
                p.state_dict["momentum"] *= self.momentum
                p.state_dict["momentum"] -= self.lr * p.grad
                # update the parameter
                p.data += p.state_dict["momentum"]
                # END TODO ##################
            else:
                # Standard SGD
                # START TODO ################ 
                # raise NotImplementedError
                p.data -= self.lr * p.grad
                # END TODO ##################

# %% [markdown]
# ## Data Loading

# %%
def load_mnist_data():
    """Loads the data, returns training_data, validation_data, test_data."""
    with gzip.open('mnist.pkl.gz', 'rb') as f:
        return pickle.load(f, encoding='latin1')


def minibatched(data: np.ndarray, batch_size: int) -> List[np.ndarray]:
    assert len(data) % batch_size == 0, ("Data length {} is not multiple of batch size {}"
                                         .format(len(data), batch_size))
    return data.reshape(-1, batch_size, *data.shape[1:])


(x_train, y_train), (x_val, y_val), (x_test, y_test) = load_mnist_data()
x_train = np.expand_dims(x_train, axis=-1)
x_val = np.expand_dims(x_val, axis=-1)
x_test = np.expand_dims(x_test, axis=-1)

num_classes = 10
y_train = one_hot_encoding(y_train, num_classes)
y_val = one_hot_encoding(y_val, num_classes)
y_test = one_hot_encoding(y_test, num_classes)

# %% [markdown]
# ## Training
#
# Implement the actual training loop.

# %%
def accuracy(y, predictions, y_is_onehot: bool = False) -> float:
    y_predicted = np.argmax(predictions, axis=-1)
    y = np.argmax(y, axis=-1)
    return np.sum(np.equal(y_predicted, y)) / len(y)


def evaluate(data, labels, model, loss_fn, batch_size):
    predictions = []
    eval_cost = 0.
    data_batched = minibatched(data, batch_size)
    labels_batched = minibatched(labels, batch_size)

    for x, y in zip(data_batched, labels_batched):
        # note that when using cross entropy loss, the softmax is included in the
        # loss and we'd need to apply it manually here to obtain the output as probabilities.
        # However, softmax only rescales the outputs and doesn't change the argmax,
        # so we'll skip this here, as we're only interested in the class prediction.
        h_1 = np.squeeze(model(x))
        predictions.append(h_1)
        eval_cost += loss_fn(h_1, y)
    predictions = np.array(predictions).reshape(-1, 10)
    eval_accuracy = accuracy(y_val, predictions, False)
    return eval_accuracy, eval_cost


def train(model, loss_fn, optimizer, x_train, y_train, x_val, y_val, num_epochs, batch_size):
    train_costs, train_accuracies = np.zeros(num_epochs), np.zeros(num_epochs)
    eval_costs, eval_accuracies = np.zeros(num_epochs), np.zeros(num_epochs)
    ix = np.arange(len(x_train))
    
    for epoch in range(num_epochs):
        print("Epoch {} / {}:".format(epoch + 1, num_epochs))
        training_predictions = []
        
        np.random.shuffle(ix)
        x_train_batched = minibatched(x_train[ix], batch_size)
        y_train_batched = minibatched(y_train[ix], batch_size)
        
        # train for one epoch
        for x_batch, y_batch in zip(x_train_batched, y_train_batched):
            # START TODO ################ 
            # raise NotImplementedError
            # TIPP: Look at the optimizer's docstring about how to use it.
            #       You might have to add / remove axes.
            optimizer.zero_grad()
            y_batch_predicted = model(x_batch)
            h_1 = np.squeeze(y_batch_predicted)
            training_predictions.append(h_1)
            loss = loss_fn(h_1, y_batch)
            grad = loss_fn.backward()
            model.backward(grad)
            optimizer.step()
            # END TODO ##################
            train_costs[epoch] += loss
       
        training_predictions = np.array(training_predictions).reshape(-1, 10)
        train_accuracies[epoch] = accuracy(y_train[ix], training_predictions, False)
        print("  Training Accuracy: {:.4f}".format(train_accuracies[epoch]))
        print("  Training Cost: {:.4f}".format(train_costs[epoch]))
        eval_accuracies[epoch], eval_costs[epoch] = evaluate(x_val, y_val, model, loss_fn, batch_size)
        print("  Eval Accuracy: {:.4f}".format(eval_accuracies[epoch]))
    return train_costs, train_accuracies, eval_costs, eval_accuracies

# %% [markdown]
# # Experiments
#
# Apply it on a sequential model (linear, sigmoid, linear, softmax (included in cross entropy!). Use the cross entropy loss and sgd with momentum. Use the hyperparameters defined below.
#
# What is the best accuracy you can achieve?
#
# Note: In a first version we accidently stated you should use (linear, sigmoid, linear, sigmoid). If you use this, you'll get slightly worse accuracy, but your network will still train with a learning rate of 3.

# %%
num_epochs = 10
batch_size = 50
learning_rate = 0.1
momentum = 0.9
linear_units = 30

# START TODO ################ 
# Train the model here!
model = Sequential(Linear(784, linear_units),
                   Sigmoid(),
                   Linear(linear_units, 10),
                   )

loss_fn = CrossEntropyLoss()
optimizer = SGD(model.parameters(), lr=learning_rate, momentum=momentum)
   
train_costs, train_accuracies, eval_costs, eval_accuracies =\
    train(model, loss_fn, optimizer, x_train, y_train, x_val, y_val, num_epochs=num_epochs, batch_size=batch_size)

##  Training Accuracy: 0.9775, Eval Accuracy: 0.9672
# END TODO ##################
# Out:
# Epoch 1 / 10:
#   Training Accuracy: 0.8518
#   Training Cost: 476.3736
#   Eval Accuracy: 0.9370
# Epoch 2 / 10:
#   Training Accuracy: 0.9420
#   Training Cost: 198.8017
#   Eval Accuracy: 0.9539
# Epoch 3 / 10:
#   Training Accuracy: 0.9522
#   Training Cost: 160.4846
#   Eval Accuracy: 0.9582
# Epoch 4 / 10:
#   Training Accuracy: 0.9579
#   Training Cost: 139.7606
#   Eval Accuracy: 0.9601
# Epoch 5 / 10:
#   Training Accuracy: 0.9634
#   Training Cost: 123.8260
#   Eval Accuracy: 0.9591
# Epoch 6 / 10:
#   Training Accuracy: 0.9663
#   Training Cost: 111.2775
#   Eval Accuracy: 0.9605
# Epoch 7 / 10:
#   Training Accuracy: 0.9685
#   Training Cost: 103.2486
#   Eval Accuracy: 0.9547
# Epoch 8 / 10:
#   Training Accuracy: 0.9709
#   Training Cost: 95.8375
#   Eval Accuracy: 0.9640
# Epoch 9 / 10:
#   Training Accuracy: 0.9730
#   Training Cost: 89.3089
#   Eval Accuracy: 0.9631
# Epoch 10 / 10:
#   Training Accuracy: 0.9755
#   Training Cost: 83.3703
#   Eval Accuracy: 0.9606

# %% [markdown]
# Now run again with the increased learning rate. Which accuracy can you achieve now? How did the accuracies change while training, compared to the lower learning rate?
#
# **Note:** Make sure, to reinitialize your model's parameters. Don't continue on the already trained parameters.

# %%
higher_learning_rate = 3

# START TODO ################ 
model = Sequential(Linear(784, linear_units),
                   Sigmoid(),
                   Linear(linear_units, 10),
                   )
optimizer = SGD(model.parameters(), lr=higher_learning_rate, momentum=momentum)
train_costs, train_accuracies, eval_costs, eval_accuracies =\
    train(model, loss_fn, optimizer, x_train, y_train, x_val, y_val, num_epochs=num_epochs, batch_size=batch_size)
## Training Accuracy: 0.9421, Eval Accuracy: 0.9406
## Accuracy isn't much better at the end, but increased faster while training.
# END TODO ##################
# Out:
# Epoch 1 / 10:
#   Training Accuracy: 0.1010
#   Training Cost: 2452.4363
#   Eval Accuracy: 0.1064
# Epoch 2 / 10:
#   Training Accuracy: 0.1015
#   Training Cost: 2444.0635
#   Eval Accuracy: 0.0983
# Epoch 3 / 10:
#   Training Accuracy: 0.0990
#   Training Cost: 2457.1806
#   Eval Accuracy: 0.1064
# Epoch 4 / 10:
#   Training Accuracy: 0.0997
#   Training Cost: 2457.4401
#   Eval Accuracy: 0.1030
# Epoch 5 / 10:
#   Training Accuracy: 0.1011
#   Training Cost: 2463.2233
#   Eval Accuracy: 0.0990
# Epoch 6 / 10:
#   Training Accuracy: 0.1014
#   Training Cost: 2447.0175
#   Eval Accuracy: 0.0991
# Epoch 7 / 10:
#   Training Accuracy: 0.1002
#   Training Cost: 2456.7024
#   Eval Accuracy: 0.1030
# Epoch 8 / 10:
#   Training Accuracy: 0.1007
#   Training Cost: 2461.9570
#   Eval Accuracy: 0.0991
# Epoch 9 / 10:
#   Training Accuracy: 0.1014
#   Training Cost: 2438.2591
#   Eval Accuracy: 0.1090
# Epoch 10 / 10:
#   Training Accuracy: 0.1013
#   Training Cost: 2460.9201
#   Eval Accuracy: 0.0990

# %% [markdown]
# Train only a subset of 1000 training samples, but for 300 epochs.
# Plot the costs & accuracies for both training and validation.
#
# How do the accuracies change compared to the previous runs?
# How is this plot related to the term 'overfitting'?

# %%
num_train_samples = 1000
num_epochs = 300

# START TODO ################ 
model = Sequential(Linear(784, linear_units),
                   Sigmoid(),
                   Linear(linear_units, 10),
                   )
optimizer = SGD(model.parameters(), lr=higher_learning_rate, momentum=momentum)
train_costs, train_accuracies, eval_costs, eval_accuracies =\
    train(model, loss_fn, optimizer, x_train[:num_train_samples], y_train[:num_train_samples], x_val, y_val, num_epochs=num_epochs, batch_size=batch_size)

## Train Accuracies better, but eval accuracies worse than in previous runs
# END TODO ##################
# Out:
# Epoch 1 / 300:
#   Training Accuracy: 0.1090
#   Training Cost: 47.1080
#   Eval Accuracy: 0.1978
# Epoch 2 / 300:
#   Training Accuracy: 0.2340
#   Training Cost: 41.0725
#   Eval Accuracy: 0.2397
# Epoch 3 / 300:
#   Training Accuracy: 0.2530
#   Training Cost: 38.8640
#   Eval Accuracy: 0.2477
# Epoch 4 / 300:
#   Training Accuracy: 0.2890
#   Training Cost: 39.2384
#   Eval Accuracy: 0.2340
# Epoch 5 / 300:
#   Training Accuracy: 0.2780
#   Training Cost: 39.0894
#   Eval Accuracy: 0.2777
# Epoch 6 / 300:
#   Training Accuracy: 0.3560
#   Training Cost: 35.1752
#   Eval Accuracy: 0.3674
# Epoch 7 / 300:
#   Training Accuracy: 0.3650
#   Training Cost: 35.0845
#   Eval Accuracy: 0.3762
# Epoch 8 / 300:
#   Training Accuracy: 0.3700
#   Training Cost: 35.2648
#   Eval Accuracy: 0.3593
# Epoch 9 / 300:
#   Training Accuracy: 0.3770
#   Training Cost: 33.2203
#   Eval Accuracy: 0.2930
# Epoch 10 / 300:
#   Training Accuracy: 0.4070
#   Training Cost: 32.7047
#   Eval Accuracy: 0.4457
# Epoch 11 / 300:
#   Training Accuracy: 0.4820
#   Training Cost: 28.1072
#   Eval Accuracy: 0.4975
# Epoch 12 / 300:
#   Training Accuracy: 0.5460
#   Training Cost: 26.6069
#   Eval Accuracy: 0.4208
# Epoch 13 / 300:
#   Training Accuracy: 0.5060
#   Training Cost: 27.8080
#   Eval Accuracy: 0.4995
# Epoch 14 / 300:
#   Training Accuracy: 0.5340
#   Training Cost: 27.4411
#   Eval Accuracy: 0.4985
# Epoch 15 / 300:
#   Training Accuracy: 0.5780
#   Training Cost: 26.6626
#   Eval Accuracy: 0.6077
# Epoch 16 / 300:
#   Training Accuracy: 0.6460
#   Training Cost: 21.9220
#   Eval Accuracy: 0.5770
# Epoch 17 / 300:
#   Training Accuracy: 0.6570
#   Training Cost: 19.8848
#   Eval Accuracy: 0.6149
# Epoch 18 / 300:
#   Training Accuracy: 0.6650
#   Training Cost: 19.6619
#   Eval Accuracy: 0.6323
# Epoch 19 / 300:
#   Training Accuracy: 0.6720
#   Training Cost: 18.5523
#   Eval Accuracy: 0.6637
# Epoch 20 / 300:
#   Training Accuracy: 0.6460
#   Training Cost: 18.9559
#   Eval Accuracy: 0.6355
# Epoch 21 / 300:
#   Training Accuracy: 0.6610
#   Training Cost: 20.4544
#   Eval Accuracy: 0.6499
# Epoch 22 / 300:
#   Training Accuracy: 0.7160
#   Training Cost: 20.8160
#   Eval Accuracy: 0.6073
# Epoch 23 / 300:
#   Training Accuracy: 0.7070
#   Training Cost: 18.6038
#   Eval Accuracy: 0.7099
# Epoch 24 / 300:
#   Training Accuracy: 0.6660
#   Training Cost: 19.7331
#   Eval Accuracy: 0.6004
# Epoch 25 / 300:
#   Training Accuracy: 0.7140
#   Training Cost: 18.4960
#   Eval Accuracy: 0.7031
# Epoch 26 / 300:
#   Training Accuracy: 0.7700
#   Training Cost: 15.7053
#   Eval Accuracy: 0.6461
# Epoch 27 / 300:
#   Training Accuracy: 0.7830
#   Training Cost: 15.2421
#   Eval Accuracy: 0.6739
# Epoch 28 / 300:
#   Training Accuracy: 0.7850
#   Training Cost: 15.0564
#   Eval Accuracy: 0.6529
# Epoch 29 / 300:
#   Training Accuracy: 0.7340
#   Training Cost: 17.6003
#   Eval Accuracy: 0.6429
# Epoch 30 / 300:
#   Training Accuracy: 0.7360
#   Training Cost: 17.5742
#   Eval Accuracy: 0.7153
# Epoch 31 / 300:
#   Training Accuracy: 0.7970
#   Training Cost: 15.0194
#   Eval Accuracy: 0.7466
# Epoch 32 / 300:
#   Training Accuracy: 0.7800
#   Training Cost: 14.3837
#   Eval Accuracy: 0.6942
# Epoch 33 / 300:
#   Training Accuracy: 0.8330
#   Training Cost: 13.2670
#   Eval Accuracy: 0.7354
# Epoch 34 / 300:
#   Training Accuracy: 0.8280
#   Training Cost: 12.4525
#   Eval Accuracy: 0.6921
# Epoch 35 / 300:
#   Training Accuracy: 0.8450
#   Training Cost: 11.2073
#   Eval Accuracy: 0.7603
# Epoch 36 / 300:
#   Training Accuracy: 0.8240
#   Training Cost: 12.7466
#   Eval Accuracy: 0.7071
# Epoch 37 / 300:
#   Training Accuracy: 0.8100
#   Training Cost: 12.9287
#   Eval Accuracy: 0.6757
# Epoch 38 / 300:
#   Training Accuracy: 0.7600
#   Training Cost: 14.3252
#   Eval Accuracy: 0.7349
# Epoch 39 / 300:
#   Training Accuracy: 0.8290
#   Training Cost: 12.2543
#   Eval Accuracy: 0.7543
# Epoch 40 / 300:
#   Training Accuracy: 0.8150
#   Training Cost: 12.5506
#   Eval Accuracy: 0.7171
# Epoch 41 / 300:
#   Training Accuracy: 0.8620
#   Training Cost: 11.0413
#   Eval Accuracy: 0.7072
# Epoch 42 / 300:
#   Training Accuracy: 0.7730
#   Training Cost: 14.3335
#   Eval Accuracy: 0.7510
# Epoch 43 / 300:
#   Training Accuracy: 0.8210
#   Training Cost: 13.2563
#   Eval Accuracy: 0.7669
# Epoch 44 / 300:
#   Training Accuracy: 0.8440
#   Training Cost: 12.2735
#   Eval Accuracy: 0.7468
# Epoch 45 / 300:
#   Training Accuracy: 0.8410
#   Training Cost: 12.1102
#   Eval Accuracy: 0.7446
# Epoch 46 / 300:
#   Training Accuracy: 0.7830
#   Training Cost: 14.7943
#   Eval Accuracy: 0.7346
# Epoch 47 / 300:
#   Training Accuracy: 0.8370
#   Training Cost: 13.0975
#   Eval Accuracy: 0.7578
# Epoch 48 / 300:
#   Training Accuracy: 0.8700
#   Training Cost: 11.7542
#   Eval Accuracy: 0.7663
# Epoch 49 / 300:
#   Training Accuracy: 0.8680
#   Training Cost: 10.8654
#   Eval Accuracy: 0.7816
# Epoch 50 / 300:
#   Training Accuracy: 0.8810
#   Training Cost: 9.8053
#   Eval Accuracy: 0.7748
# Epoch 51 / 300:
#   Training Accuracy: 0.8830
#   Training Cost: 10.0957
#   Eval Accuracy: 0.7844
# Epoch 52 / 300:
#   Training Accuracy: 0.8980
#   Training Cost: 8.5390
#   Eval Accuracy: 0.7472
# Epoch 53 / 300:
#   Training Accuracy: 0.8620
#   Training Cost: 10.6615
#   Eval Accuracy: 0.6961
# Epoch 54 / 300:
#   Training Accuracy: 0.8370
#   Training Cost: 12.7242
#   Eval Accuracy: 0.7721
# Epoch 55 / 300:
#   Training Accuracy: 0.8810
#   Training Cost: 10.0785
#   Eval Accuracy: 0.7605
# Epoch 56 / 300:
#   Training Accuracy: 0.8990
#   Training Cost: 8.7257
#   Eval Accuracy: 0.7868
# Epoch 57 / 300:
#   Training Accuracy: 0.8850
#   Training Cost: 8.0985
#   Eval Accuracy: 0.7859
# Epoch 58 / 300:
#   Training Accuracy: 0.8970
#   Training Cost: 8.2143
#   Eval Accuracy: 0.7748
# Epoch 59 / 300:
#   Training Accuracy: 0.9060
#   Training Cost: 7.9349
#   Eval Accuracy: 0.7773
# Epoch 60 / 300:
#   Training Accuracy: 0.9040
#   Training Cost: 7.0692
#   Eval Accuracy: 0.7684
# Epoch 61 / 300:
#   Training Accuracy: 0.9000
#   Training Cost: 7.1041
#   Eval Accuracy: 0.7817
# Epoch 62 / 300:
#   Training Accuracy: 0.9120
#   Training Cost: 7.0565
#   Eval Accuracy: 0.7810
# Epoch 63 / 300:
#   Training Accuracy: 0.8990
#   Training Cost: 7.5772
#   Eval Accuracy: 0.7280
# Epoch 64 / 300:
#   Training Accuracy: 0.8820
#   Training Cost: 8.2231
#   Eval Accuracy: 0.7774
# Epoch 65 / 300:
#   Training Accuracy: 0.9060
#   Training Cost: 7.6340
#   Eval Accuracy: 0.7622
# Epoch 66 / 300:
#   Training Accuracy: 0.8730
#   Training Cost: 8.8809
#   Eval Accuracy: 0.7556
# Epoch 67 / 300:
#   Training Accuracy: 0.8800
#   Training Cost: 8.0031
#   Eval Accuracy: 0.7622
# Epoch 68 / 300:
#   Training Accuracy: 0.8950
#   Training Cost: 7.3358
#   Eval Accuracy: 0.7856
# Epoch 69 / 300:
#   Training Accuracy: 0.9000
#   Training Cost: 7.5968
#   Eval Accuracy: 0.7873
# Epoch 70 / 300:
#   Training Accuracy: 0.8880
#   Training Cost: 8.0300
#   Eval Accuracy: 0.7560
# Epoch 71 / 300:
#   Training Accuracy: 0.8600
#   Training Cost: 10.3008
#   Eval Accuracy: 0.7786
# Epoch 72 / 300:
#   Training Accuracy: 0.8320
#   Training Cost: 11.1229
#   Eval Accuracy: 0.7083
# Epoch 73 / 300:
#   Training Accuracy: 0.8620
#   Training Cost: 9.9076
#   Eval Accuracy: 0.7745
# Epoch 74 / 300:
#   Training Accuracy: 0.8750
#   Training Cost: 10.0686
#   Eval Accuracy: 0.7781
# Epoch 75 / 300:
#   Training Accuracy: 0.8660
#   Training Cost: 9.5385
#   Eval Accuracy: 0.7346
# Epoch 76 / 300:
#   Training Accuracy: 0.8860
#   Training Cost: 8.6548
#   Eval Accuracy: 0.7507
# Epoch 77 / 300:
#   Training Accuracy: 0.8410
#   Training Cost: 11.2280
#   Eval Accuracy: 0.7424
# Epoch 78 / 300:
#   Training Accuracy: 0.8460
#   Training Cost: 10.2250
#   Eval Accuracy: 0.7657
# Epoch 79 / 300:
#   Training Accuracy: 0.8840
#   Training Cost: 8.8151
#   Eval Accuracy: 0.7680
# Epoch 80 / 300:
#   Training Accuracy: 0.8830
#   Training Cost: 9.0006
#   Eval Accuracy: 0.7657
# Epoch 81 / 300:
#   Training Accuracy: 0.9060
#   Training Cost: 8.3444
#   Eval Accuracy: 0.7781
# Epoch 82 / 300:
#   Training Accuracy: 0.8890
#   Training Cost: 8.9679
#   Eval Accuracy: 0.7688
# Epoch 83 / 300:
#   Training Accuracy: 0.9040
#   Training Cost: 7.3203
#   Eval Accuracy: 0.7726
# Epoch 84 / 300:
#   Training Accuracy: 0.9020
#   Training Cost: 7.3484
#   Eval Accuracy: 0.7812
# Epoch 85 / 300:
#   Training Accuracy: 0.9040
#   Training Cost: 7.0611
#   Eval Accuracy: 0.7691
# Epoch 86 / 300:
#   Training Accuracy: 0.8970
#   Training Cost: 7.5638
#   Eval Accuracy: 0.7775
# Epoch 87 / 300:
#   Training Accuracy: 0.9040
#   Training Cost: 7.6581
#   Eval Accuracy: 0.7700
# Epoch 88 / 300:
#   Training Accuracy: 0.9030
#   Training Cost: 7.7126
#   Eval Accuracy: 0.7629
# Epoch 89 / 300:
#   Training Accuracy: 0.9060
#   Training Cost: 7.0126
#   Eval Accuracy: 0.7880
# Epoch 90 / 300:
#   Training Accuracy: 0.9130
#   Training Cost: 8.0883
#   Eval Accuracy: 0.7828
# Epoch 91 / 300:
#   Training Accuracy: 0.8870
#   Training Cost: 8.2105
#   Eval Accuracy: 0.7276
# Epoch 92 / 300:
#   Training Accuracy: 0.8780
#   Training Cost: 9.7865
#   Eval Accuracy: 0.7739
# Epoch 93 / 300:
#   Training Accuracy: 0.8780
#   Training Cost: 10.2448
#   Eval Accuracy: 0.7674
# Epoch 94 / 300:
#   Training Accuracy: 0.8740
#   Training Cost: 9.7425
#   Eval Accuracy: 0.7478
# Epoch 95 / 300:
#   Training Accuracy: 0.8640
#   Training Cost: 10.2048
#   Eval Accuracy: 0.7595
# Epoch 96 / 300:
#   Training Accuracy: 0.8870
#   Training Cost: 8.4471
#   Eval Accuracy: 0.7817
# Epoch 97 / 300:
#   Training Accuracy: 0.8970
#   Training Cost: 9.0701
#   Eval Accuracy: 0.7520
# Epoch 98 / 300:
#   Training Accuracy: 0.8810
#   Training Cost: 9.2541
#   Eval Accuracy: 0.7545
# Epoch 99 / 300:
#   Training Accuracy: 0.8840
#   Training Cost: 8.7080
#   Eval Accuracy: 0.7793
# Epoch 100 / 300:
#   Training Accuracy: 0.9150
#   Training Cost: 7.1821
#   Eval Accuracy: 0.7778
# Epoch 101 / 300:
#   Training Accuracy: 0.9070
#   Training Cost: 6.3413
#   Eval Accuracy: 0.7854
# Epoch 102 / 300:
#   Training Accuracy: 0.9200
#   Training Cost: 6.9312
#   Eval Accuracy: 0.7833
# Epoch 103 / 300:
#   Training Accuracy: 0.9040
#   Training Cost: 7.5653
#   Eval Accuracy: 0.7718
# Epoch 104 / 300:
#   Training Accuracy: 0.9110
#   Training Cost: 7.0213
#   Eval Accuracy: 0.7714
# Epoch 105 / 300:
#   Training Accuracy: 0.9000
#   Training Cost: 8.1103
#   Eval Accuracy: 0.7533
# Epoch 106 / 300:
#   Training Accuracy: 0.9150
#   Training Cost: 7.0780
#   Eval Accuracy: 0.7656
# Epoch 107 / 300:
#   Training Accuracy: 0.8590
#   Training Cost: 9.3960
#   Eval Accuracy: 0.7107
# Epoch 108 / 300:
#   Training Accuracy: 0.8700
#   Training Cost: 9.2326
#   Eval Accuracy: 0.7465
# Epoch 109 / 300:
#   Training Accuracy: 0.9010
#   Training Cost: 6.9868
#   Eval Accuracy: 0.7603
# Epoch 110 / 300:
#   Training Accuracy: 0.9150
#   Training Cost: 6.6383
#   Eval Accuracy: 0.7887
# Epoch 111 / 300:
#   Training Accuracy: 0.9200
#   Training Cost: 6.1196
#   Eval Accuracy: 0.7574
# Epoch 112 / 300:
#   Training Accuracy: 0.9170
#   Training Cost: 6.5483
#   Eval Accuracy: 0.7776
# Epoch 113 / 300:
#   Training Accuracy: 0.9260
#   Training Cost: 6.1925
#   Eval Accuracy: 0.7831
# Epoch 114 / 300:
#   Training Accuracy: 0.9270
#   Training Cost: 5.9815
#   Eval Accuracy: 0.7737
# Epoch 115 / 300:
#   Training Accuracy: 0.9110
#   Training Cost: 6.8323
#   Eval Accuracy: 0.7742
# Epoch 116 / 300:
#   Training Accuracy: 0.9190
#   Training Cost: 6.1255
#   Eval Accuracy: 0.7796
# Epoch 117 / 300:
#   Training Accuracy: 0.8950
#   Training Cost: 8.8772
#   Eval Accuracy: 0.7637
# Epoch 118 / 300:
#   Training Accuracy: 0.9240
#   Training Cost: 6.2607
#   Eval Accuracy: 0.7748
# Epoch 119 / 300:
#   Training Accuracy: 0.9250
#   Training Cost: 5.8708
#   Eval Accuracy: 0.7748
# Epoch 120 / 300:
#   Training Accuracy: 0.9200
#   Training Cost: 5.8266
#   Eval Accuracy: 0.7738
# Epoch 121 / 300:
#   Training Accuracy: 0.9240
#   Training Cost: 5.3259
#   Eval Accuracy: 0.7817
# Epoch 122 / 300:
#   Training Accuracy: 0.9300
#   Training Cost: 5.4692
#   Eval Accuracy: 0.7738
# Epoch 123 / 300:
#   Training Accuracy: 0.9170
#   Training Cost: 5.5808
#   Eval Accuracy: 0.7742
# Epoch 124 / 300:
#   Training Accuracy: 0.9220
#   Training Cost: 5.9442
#   Eval Accuracy: 0.7858
# Epoch 125 / 300:
#   Training Accuracy: 0.9250
#   Training Cost: 5.1013
#   Eval Accuracy: 0.7813
# Epoch 126 / 300:
#   Training Accuracy: 0.9280
#   Training Cost: 5.5325
#   Eval Accuracy: 0.7810
# Epoch 127 / 300:
#   Training Accuracy: 0.9290
#   Training Cost: 5.0848
#   Eval Accuracy: 0.7755
# Epoch 128 / 300:
#   Training Accuracy: 0.9310
#   Training Cost: 5.8140
#   Eval Accuracy: 0.7839
# Epoch 129 / 300:
#   Training Accuracy: 0.9250
#   Training Cost: 5.2874
#   Eval Accuracy: 0.7827
# Epoch 130 / 300:
#   Training Accuracy: 0.9280
#   Training Cost: 4.7843
#   Eval Accuracy: 0.7745
# Epoch 131 / 300:
#   Training Accuracy: 0.9190
#   Training Cost: 5.5074
#   Eval Accuracy: 0.7750
# Epoch 132 / 300:
#   Training Accuracy: 0.9290
#   Training Cost: 4.9584
#   Eval Accuracy: 0.7781
# Epoch 133 / 300:
#   Training Accuracy: 0.9260
#   Training Cost: 5.9835
#   Eval Accuracy: 0.7717
# Epoch 134 / 300:
#   Training Accuracy: 0.9130
#   Training Cost: 6.5036
#   Eval Accuracy: 0.7795
# Epoch 135 / 300:
#   Training Accuracy: 0.9330
#   Training Cost: 5.1873
#   Eval Accuracy: 0.7805
# Epoch 136 / 300:
#   Training Accuracy: 0.9370
#   Training Cost: 4.6929
#   Eval Accuracy: 0.7413
# Epoch 137 / 300:
#   Training Accuracy: 0.9180
#   Training Cost: 6.3928
#   Eval Accuracy: 0.7763
# Epoch 138 / 300:
#   Training Accuracy: 0.9220
#   Training Cost: 5.6860
#   Eval Accuracy: 0.7653
# Epoch 139 / 300:
#   Training Accuracy: 0.9140
#   Training Cost: 6.2629
#   Eval Accuracy: 0.7938
# Epoch 140 / 300:
#   Training Accuracy: 0.9310
#   Training Cost: 5.2839
#   Eval Accuracy: 0.7422
# Epoch 141 / 300:
#   Training Accuracy: 0.8700
#   Training Cost: 7.7575
#   Eval Accuracy: 0.7503
# Epoch 142 / 300:
#   Training Accuracy: 0.9250
#   Training Cost: 5.3640
#   Eval Accuracy: 0.7902
# Epoch 143 / 300:
#   Training Accuracy: 0.9380
#   Training Cost: 4.5513
#   Eval Accuracy: 0.7861
# Epoch 144 / 300:
#   Training Accuracy: 0.9450
#   Training Cost: 4.2620
#   Eval Accuracy: 0.7781
# Epoch 145 / 300:
#   Training Accuracy: 0.9420
#   Training Cost: 4.1821
#   Eval Accuracy: 0.7969
# Epoch 146 / 300:
#   Training Accuracy: 0.9460
#   Training Cost: 3.6971
#   Eval Accuracy: 0.7954
# Epoch 147 / 300:
#   Training Accuracy: 0.9500
#   Training Cost: 3.8566
#   Eval Accuracy: 0.7912
# Epoch 148 / 300:
#   Training Accuracy: 0.9460
#   Training Cost: 3.7459
#   Eval Accuracy: 0.8024
# Epoch 149 / 300:
#   Training Accuracy: 0.9450
#   Training Cost: 3.9551
#   Eval Accuracy: 0.7891
# Epoch 150 / 300:
#   Training Accuracy: 0.9420
#   Training Cost: 4.4627
#   Eval Accuracy: 0.7895
# Epoch 151 / 300:
#   Training Accuracy: 0.9410
#   Training Cost: 4.3270
#   Eval Accuracy: 0.7931
# Epoch 152 / 300:
#   Training Accuracy: 0.9360
#   Training Cost: 4.6072
#   Eval Accuracy: 0.7952
# Epoch 153 / 300:
#   Training Accuracy: 0.9410
#   Training Cost: 4.3701
#   Eval Accuracy: 0.8008
# Epoch 154 / 300:
#   Training Accuracy: 0.9370
#   Training Cost: 3.7060
#   Eval Accuracy: 0.7966
# Epoch 155 / 300:
#   Training Accuracy: 0.9520
#   Training Cost: 3.7382
#   Eval Accuracy: 0.7766
# Epoch 156 / 300:
#   Training Accuracy: 0.9460
#   Training Cost: 3.8881
#   Eval Accuracy: 0.7973
# Epoch 157 / 300:
#   Training Accuracy: 0.9410
#   Training Cost: 3.5151
#   Eval Accuracy: 0.7712
# Epoch 158 / 300:
#   Training Accuracy: 0.9510
#   Training Cost: 3.5927
#   Eval Accuracy: 0.7881
# Epoch 159 / 300:
#   Training Accuracy: 0.9470
#   Training Cost: 3.5004
#   Eval Accuracy: 0.7929
# Epoch 160 / 300:
#   Training Accuracy: 0.9420
#   Training Cost: 3.7004
#   Eval Accuracy: 0.7778
# Epoch 161 / 300:
#   Training Accuracy: 0.9370
#   Training Cost: 4.6554
#   Eval Accuracy: 0.7906
# Epoch 162 / 300:
#   Training Accuracy: 0.9410
#   Training Cost: 4.2268
#   Eval Accuracy: 0.7955
# Epoch 163 / 300:
#   Training Accuracy: 0.9390
#   Training Cost: 4.3698
#   Eval Accuracy: 0.7848
# Epoch 164 / 300:
#   Training Accuracy: 0.9440
#   Training Cost: 3.8312
#   Eval Accuracy: 0.7888
# Epoch 165 / 300:
#   Training Accuracy: 0.9440
#   Training Cost: 4.0910
#   Eval Accuracy: 0.7871
# Epoch 166 / 300:
#   Training Accuracy: 0.9420
#   Training Cost: 3.8969
#   Eval Accuracy: 0.7809
# Epoch 167 / 300:
#   Training Accuracy: 0.9420
#   Training Cost: 3.9055
#   Eval Accuracy: 0.7930
# Epoch 168 / 300:
#   Training Accuracy: 0.9450
#   Training Cost: 3.6004
#   Eval Accuracy: 0.7889
# Epoch 169 / 300:
#   Training Accuracy: 0.9460
#   Training Cost: 3.5895
#   Eval Accuracy: 0.7901
# Epoch 170 / 300:
#   Training Accuracy: 0.9530
#   Training Cost: 3.3262
#   Eval Accuracy: 0.7951
# Epoch 171 / 300:
#   Training Accuracy: 0.9480
#   Training Cost: 3.4480
#   Eval Accuracy: 0.7955
# Epoch 172 / 300:
#   Training Accuracy: 0.9500
#   Training Cost: 3.3514
#   Eval Accuracy: 0.7953
# Epoch 173 / 300:
#   Training Accuracy: 0.9580
#   Training Cost: 3.3951
#   Eval Accuracy: 0.7922
# Epoch 174 / 300:
#   Training Accuracy: 0.9560
#   Training Cost: 3.3542
#   Eval Accuracy: 0.7867
# Epoch 175 / 300:
#   Training Accuracy: 0.9480
#   Training Cost: 3.5033
#   Eval Accuracy: 0.7857
# Epoch 176 / 300:
#   Training Accuracy: 0.9430
#   Training Cost: 3.8934
#   Eval Accuracy: 0.7851
# Epoch 177 / 300:
#   Training Accuracy: 0.9520
#   Training Cost: 3.6922
#   Eval Accuracy: 0.7864
# Epoch 178 / 300:
#   Training Accuracy: 0.9500
#   Training Cost: 3.6146
#   Eval Accuracy: 0.7904
# Epoch 179 / 300:
#   Training Accuracy: 0.9520
#   Training Cost: 3.7323
#   Eval Accuracy: 0.7928
# Epoch 180 / 300:
#   Training Accuracy: 0.9450
#   Training Cost: 3.7775
#   Eval Accuracy: 0.7659
# Epoch 181 / 300:
#   Training Accuracy: 0.9440
#   Training Cost: 3.8706
#   Eval Accuracy: 0.7971
# Epoch 182 / 300:
#   Training Accuracy: 0.9480
#   Training Cost: 3.9628
#   Eval Accuracy: 0.7904
# Epoch 183 / 300:
#   Training Accuracy: 0.9580
#   Training Cost: 3.5481
#   Eval Accuracy: 0.7855
# Epoch 184 / 300:
#   Training Accuracy: 0.9530
#   Training Cost: 3.7873
#   Eval Accuracy: 0.7804
# Epoch 185 / 300:
#   Training Accuracy: 0.9400
#   Training Cost: 4.1222
#   Eval Accuracy: 0.7901
# Epoch 186 / 300:
#   Training Accuracy: 0.9500
#   Training Cost: 3.7191
#   Eval Accuracy: 0.7881
# Epoch 187 / 300:
#   Training Accuracy: 0.9560
#   Training Cost: 3.3877
#   Eval Accuracy: 0.7756
# Epoch 188 / 300:
#   Training Accuracy: 0.9500
#   Training Cost: 3.5284
#   Eval Accuracy: 0.7896
# Epoch 189 / 300:
#   Training Accuracy: 0.9450
#   Training Cost: 3.9048
#   Eval Accuracy: 0.7874
# Epoch 190 / 300:
#   Training Accuracy: 0.9440
#   Training Cost: 4.2845
#   Eval Accuracy: 0.7957
# Epoch 191 / 300:
#   Training Accuracy: 0.9540
#   Training Cost: 3.4404
#   Eval Accuracy: 0.7887
# Epoch 192 / 300:
#   Training Accuracy: 0.9460
#   Training Cost: 3.6729
#   Eval Accuracy: 0.7885
# Epoch 193 / 300:
#   Training Accuracy: 0.9520
#   Training Cost: 3.5177
#   Eval Accuracy: 0.7915
# Epoch 194 / 300:
#   Training Accuracy: 0.9530
#   Training Cost: 3.1009
#   Eval Accuracy: 0.7947
# Epoch 195 / 300:
#   Training Accuracy: 0.9520
#   Training Cost: 3.6495
#   Eval Accuracy: 0.7884
# Epoch 196 / 300:
#   Training Accuracy: 0.9490
#   Training Cost: 3.4377
#   Eval Accuracy: 0.7917
# Epoch 197 / 300:
#   Training Accuracy: 0.9510
#   Training Cost: 3.7394
#   Eval Accuracy: 0.7873
# Epoch 198 / 300:
#   Training Accuracy: 0.9510
#   Training Cost: 3.5613
#   Eval Accuracy: 0.7957
# Epoch 199 / 300:
#   Training Accuracy: 0.9470
#   Training Cost: 3.7486
#   Eval Accuracy: 0.7824
# Epoch 200 / 300:
#   Training Accuracy: 0.9450
#   Training Cost: 3.5598
#   Eval Accuracy: 0.7804
# Epoch 201 / 300:
#   Training Accuracy: 0.9490
#   Training Cost: 3.7624
#   Eval Accuracy: 0.7944
# Epoch 202 / 300:
#   Training Accuracy: 0.9430
#   Training Cost: 3.6210
#   Eval Accuracy: 0.7910
# Epoch 203 / 300:
#   Training Accuracy: 0.9540
#   Training Cost: 3.0817
#   Eval Accuracy: 0.7859
# Epoch 204 / 300:
#   Training Accuracy: 0.9460
#   Training Cost: 3.6891
#   Eval Accuracy: 0.7835
# Epoch 205 / 300:
#   Training Accuracy: 0.9410
#   Training Cost: 3.7928
#   Eval Accuracy: 0.7922
# Epoch 206 / 300:
#   Training Accuracy: 0.9420
#   Training Cost: 4.2243
#   Eval Accuracy: 0.7748
# Epoch 207 / 300:
#   Training Accuracy: 0.9450
#   Training Cost: 3.4378
#   Eval Accuracy: 0.7900
# Epoch 208 / 300:
#   Training Accuracy: 0.9270
#   Training Cost: 5.5519
#   Eval Accuracy: 0.7772
# Epoch 209 / 300:
#   Training Accuracy: 0.9390
#   Training Cost: 4.4925
#   Eval Accuracy: 0.7848
# Epoch 210 / 300:
#   Training Accuracy: 0.9520
#   Training Cost: 3.7517
#   Eval Accuracy: 0.7922
# Epoch 211 / 300:
#   Training Accuracy: 0.9530
#   Training Cost: 3.4610
#   Eval Accuracy: 0.7925
# Epoch 212 / 300:
#   Training Accuracy: 0.9450
#   Training Cost: 4.2619
#   Eval Accuracy: 0.7583
# Epoch 213 / 300:
#   Training Accuracy: 0.8950
#   Training Cost: 8.1620
#   Eval Accuracy: 0.7734
# Epoch 214 / 300:
#   Training Accuracy: 0.9470
#   Training Cost: 4.3427
#   Eval Accuracy: 0.7832
# Epoch 215 / 300:
#   Training Accuracy: 0.9380
#   Training Cost: 4.5475
#   Eval Accuracy: 0.7854
# Epoch 216 / 300:
#   Training Accuracy: 0.9390
#   Training Cost: 5.0416
#   Eval Accuracy: 0.7832
# Epoch 217 / 300:
#   Training Accuracy: 0.9400
#   Training Cost: 4.2384
#   Eval Accuracy: 0.7869
# Epoch 218 / 300:
#   Training Accuracy: 0.9430
#   Training Cost: 4.4915
#   Eval Accuracy: 0.7924
# Epoch 219 / 300:
#   Training Accuracy: 0.9300
#   Training Cost: 4.4850
#   Eval Accuracy: 0.7838
# Epoch 220 / 300:
#   Training Accuracy: 0.9500
#   Training Cost: 3.6381
#   Eval Accuracy: 0.7926
# Epoch 221 / 300:
#   Training Accuracy: 0.9400
#   Training Cost: 4.1023
#   Eval Accuracy: 0.7813
# Epoch 222 / 300:
#   Training Accuracy: 0.9290
#   Training Cost: 5.8681
#   Eval Accuracy: 0.7839
# Epoch 223 / 300:
#   Training Accuracy: 0.9180
#   Training Cost: 5.9886
#   Eval Accuracy: 0.7783
# Epoch 224 / 300:
#   Training Accuracy: 0.9350
#   Training Cost: 5.0483
#   Eval Accuracy: 0.7926
# Epoch 225 / 300:
#   Training Accuracy: 0.9490
#   Training Cost: 3.6046
#   Eval Accuracy: 0.7996
# Epoch 226 / 300:
#   Training Accuracy: 0.9520
#   Training Cost: 3.4668
#   Eval Accuracy: 0.7936
# Epoch 227 / 300:
#   Training Accuracy: 0.9530
#   Training Cost: 3.3711
#   Eval Accuracy: 0.7897
# Epoch 228 / 300:
#   Training Accuracy: 0.9490
#   Training Cost: 3.5098
#   Eval Accuracy: 0.7950
# Epoch 229 / 300:
#   Training Accuracy: 0.9480
#   Training Cost: 4.1271
#   Eval Accuracy: 0.7938
# Epoch 230 / 300:
#   Training Accuracy: 0.9440
#   Training Cost: 3.7824
#   Eval Accuracy: 0.7883
# Epoch 231 / 300:
#   Training Accuracy: 0.9550
#   Training Cost: 3.1493
#   Eval Accuracy: 0.7944
# Epoch 232 / 300:
#   Training Accuracy: 0.9600
#   Training Cost: 3.2659
#   Eval Accuracy: 0.7873
# Epoch 233 / 300:
#   Training Accuracy: 0.9510
#   Training Cost: 3.0859
#   Eval Accuracy: 0.7786
# Epoch 234 / 300:
#   Training Accuracy: 0.9480
#   Training Cost: 3.1987
#   Eval Accuracy: 0.7837
# Epoch 235 / 300:
#   Training Accuracy: 0.9590
#   Training Cost: 3.0301
#   Eval Accuracy: 0.7941
# Epoch 236 / 300:
#   Training Accuracy: 0.9560
#   Training Cost: 3.1769
#   Eval Accuracy: 0.7898
# Epoch 237 / 300:
#   Training Accuracy: 0.9570
#   Training Cost: 2.9998
#   Eval Accuracy: 0.7915
# Epoch 238 / 300:
#   Training Accuracy: 0.9590
#   Training Cost: 2.8834
#   Eval Accuracy: 0.7951
# Epoch 239 / 300:
#   Training Accuracy: 0.9510
#   Training Cost: 3.4950
#   Eval Accuracy: 0.7738
# Epoch 240 / 300:
#   Training Accuracy: 0.9480
#   Training Cost: 3.7714
#   Eval Accuracy: 0.7815
# Epoch 241 / 300:
#   Training Accuracy: 0.9530
#   Training Cost: 3.3653
#   Eval Accuracy: 0.7941
# Epoch 242 / 300:
#   Training Accuracy: 0.9560
#   Training Cost: 3.1644
#   Eval Accuracy: 0.7905
# Epoch 243 / 300:
#   Training Accuracy: 0.9540
#   Training Cost: 3.0248
#   Eval Accuracy: 0.7876
# Epoch 244 / 300:
#   Training Accuracy: 0.9610
#   Training Cost: 2.9740
#   Eval Accuracy: 0.7864
# Epoch 245 / 300:
#   Training Accuracy: 0.9590
#   Training Cost: 2.9978
#   Eval Accuracy: 0.7917
# Epoch 246 / 300:
#   Training Accuracy: 0.9610
#   Training Cost: 2.8048
#   Eval Accuracy: 0.7904
# Epoch 247 / 300:
#   Training Accuracy: 0.9580
#   Training Cost: 3.3745
#   Eval Accuracy: 0.7851
# Epoch 248 / 300:
#   Training Accuracy: 0.9590
#   Training Cost: 3.0451
#   Eval Accuracy: 0.7813
# Epoch 249 / 300:
#   Training Accuracy: 0.9560
#   Training Cost: 3.0412
#   Eval Accuracy: 0.7862
# Epoch 250 / 300:
#   Training Accuracy: 0.9540
#   Training Cost: 3.1991
#   Eval Accuracy: 0.7906
# Epoch 251 / 300:
#   Training Accuracy: 0.9570
#   Training Cost: 3.1088
#   Eval Accuracy: 0.7886
# Epoch 252 / 300:
#   Training Accuracy: 0.9500
#   Training Cost: 3.1812
#   Eval Accuracy: 0.7847
# Epoch 253 / 300:
#   Training Accuracy: 0.9580
#   Training Cost: 3.1526
#   Eval Accuracy: 0.7811
# Epoch 254 / 300:
#   Training Accuracy: 0.9520
#   Training Cost: 3.3159
#   Eval Accuracy: 0.7950
# Epoch 255 / 300:
#   Training Accuracy: 0.9420
#   Training Cost: 3.4653
#   Eval Accuracy: 0.7845
# Epoch 256 / 300:
#   Training Accuracy: 0.9560
#   Training Cost: 3.3112
#   Eval Accuracy: 0.7900
# Epoch 257 / 300:
#   Training Accuracy: 0.9590
#   Training Cost: 3.1173
#   Eval Accuracy: 0.7975
# Epoch 258 / 300:
#   Training Accuracy: 0.9590
#   Training Cost: 2.9439
#   Eval Accuracy: 0.7924
# Epoch 259 / 300:
#   Training Accuracy: 0.9660
#   Training Cost: 2.9647
#   Eval Accuracy: 0.7906
# Epoch 260 / 300:
#   Training Accuracy: 0.9600
#   Training Cost: 3.0187
#   Eval Accuracy: 0.7929
# Epoch 261 / 300:
#   Training Accuracy: 0.9580
#   Training Cost: 2.9405
#   Eval Accuracy: 0.7933
# Epoch 262 / 300:
#   Training Accuracy: 0.9600
#   Training Cost: 3.2132
#   Eval Accuracy: 0.7942
# Epoch 263 / 300:
#   Training Accuracy: 0.9620
#   Training Cost: 2.8756
#   Eval Accuracy: 0.7892
# Epoch 264 / 300:
#   Training Accuracy: 0.9620
#   Training Cost: 2.7934
#   Eval Accuracy: 0.7847
# Epoch 265 / 300:
#   Training Accuracy: 0.9630
#   Training Cost: 2.9079
#   Eval Accuracy: 0.7869
# Epoch 266 / 300:
#   Training Accuracy: 0.9650
#   Training Cost: 2.6018
#   Eval Accuracy: 0.7913
# Epoch 267 / 300:
#   Training Accuracy: 0.9600
#   Training Cost: 2.8992
#   Eval Accuracy: 0.7848
# Epoch 268 / 300:
#   Training Accuracy: 0.9550
#   Training Cost: 2.9808
#   Eval Accuracy: 0.7861
# Epoch 269 / 300:
#   Training Accuracy: 0.9470
#   Training Cost: 3.7557
#   Eval Accuracy: 0.7828
# Epoch 270 / 300:
#   Training Accuracy: 0.9550
#   Training Cost: 3.0513
#   Eval Accuracy: 0.7863
# Epoch 271 / 300:
#   Training Accuracy: 0.9600
#   Training Cost: 3.0067
#   Eval Accuracy: 0.7853
# Epoch 272 / 300:
#   Training Accuracy: 0.9470
#   Training Cost: 3.6527
#   Eval Accuracy: 0.7776
# Epoch 273 / 300:
#   Training Accuracy: 0.9500
#   Training Cost: 3.5902
#   Eval Accuracy: 0.7849
# Epoch 274 / 300:
#   Training Accuracy: 0.9540
#   Training Cost: 2.9039
#   Eval Accuracy: 0.7869
# Epoch 275 / 300:
#   Training Accuracy: 0.9620
#   Training Cost: 2.8853
#   Eval Accuracy: 0.7858
# Epoch 276 / 300:
#   Training Accuracy: 0.9530
#   Training Cost: 2.8922
#   Eval Accuracy: 0.7830
# Epoch 277 / 300:
#   Training Accuracy: 0.9490
#   Training Cost: 3.5722
#   Eval Accuracy: 0.7815
# Epoch 278 / 300:
#   Training Accuracy: 0.9460
#   Training Cost: 3.6920
#   Eval Accuracy: 0.7812
# Epoch 279 / 300:
#   Training Accuracy: 0.9510
#   Training Cost: 3.2926
#   Eval Accuracy: 0.7794
# Epoch 280 / 300:
#   Training Accuracy: 0.9640
#   Training Cost: 3.1892
#   Eval Accuracy: 0.7788
# Epoch 281 / 300:
#   Training Accuracy: 0.9450
#   Training Cost: 3.4332
#   Eval Accuracy: 0.7818
# Epoch 282 / 300:
#   Training Accuracy: 0.9500
#   Training Cost: 3.0296
#   Eval Accuracy: 0.7587
# Epoch 283 / 300:
#   Training Accuracy: 0.9450
#   Training Cost: 3.6500
#   Eval Accuracy: 0.7839
# Epoch 284 / 300:
#   Training Accuracy: 0.9580
#   Training Cost: 3.2832
#   Eval Accuracy: 0.7768
# Epoch 285 / 300:
#   Training Accuracy: 0.9600
#   Training Cost: 2.7231
#   Eval Accuracy: 0.7834
# Epoch 286 / 300:
#   Training Accuracy: 0.9650
#   Training Cost: 2.7061
#   Eval Accuracy: 0.7817
# Epoch 287 / 300:
#   Training Accuracy: 0.9580
#   Training Cost: 2.8828
#   Eval Accuracy: 0.7808
# Epoch 288 / 300:
#   Training Accuracy: 0.9580
#   Training Cost: 2.8317
#   Eval Accuracy: 0.7812
# Epoch 289 / 300:
#   Training Accuracy: 0.9570
#   Training Cost: 2.9633
#   Eval Accuracy: 0.7849
# Epoch 290 / 300:
#   Training Accuracy: 0.9590
#   Training Cost: 3.0168
#   Eval Accuracy: 0.7761
# Epoch 291 / 300:
#   Training Accuracy: 0.9580
#   Training Cost: 2.9560
#   Eval Accuracy: 0.7587
# Epoch 292 / 300:
#   Training Accuracy: 0.9630
#   Training Cost: 2.8123
#   Eval Accuracy: 0.7802
# Epoch 293 / 300:
#   Training Accuracy: 0.9590
#   Training Cost: 2.6549
#   Eval Accuracy: 0.7784
# Epoch 294 / 300:
#   Training Accuracy: 0.9590
#   Training Cost: 2.8780
#   Eval Accuracy: 0.7790
# Epoch 295 / 300:
#   Training Accuracy: 0.9530
#   Training Cost: 2.8950
#   Eval Accuracy: 0.7848
# Epoch 296 / 300:
#   Training Accuracy: 0.9620
#   Training Cost: 2.5695
#   Eval Accuracy: 0.7817
# Epoch 297 / 300:
#   Training Accuracy: 0.9610
#   Training Cost: 2.7776
#   Eval Accuracy: 0.7807
# Epoch 298 / 300:
#   Training Accuracy: 0.9570
#   Training Cost: 2.6634
#   Eval Accuracy: 0.7735
# Epoch 299 / 300:
#   Training Accuracy: 0.9620
#   Training Cost: 2.7872
#   Eval Accuracy: 0.7865
# Epoch 300 / 300:
#   Training Accuracy: 0.9650
#   Training Cost: 2.5974
#   Eval Accuracy: 0.7855

# %%
plt.figure(1)
plt.plot(train_costs, label='training')
plt.plot(eval_costs, label='validation')
plt.legend(loc='best')
plt.ylabel('cost')
plt.xlabel('epochs')
plt.grid(True)

plt.figure(2)
# Plot accuracies here
# START TODO ################ 
plt.plot(train_accuracies, label='training')
plt.plot(eval_accuracies, label='validation')
plt.legend(loc='best')
plt.ylabel('accuracy')
plt.xlabel('epochs')
plt.grid(True)

## Training accuracy converges to 1 but validation accuracy doesn't
## The model doesn't generalize well for the validation data. 
## This is called overfitting on the training data.
# END TODO ##################

plt.show()
