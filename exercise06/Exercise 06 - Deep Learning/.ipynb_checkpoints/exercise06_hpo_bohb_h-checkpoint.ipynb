# %% [markdown]
# # Sixth Exercise (HPO)
#
# This exercise focuses on hyperparameter optimization with neural networks.
#
# We will
# - define hyperparameter-configuration search-spaces
# - train deep learning models with various hyper parameters
# - use random search as a basic hyperparameter optimizer
# - use BOHB as an advanced hyperparameter optimizer
#
# It's in the nature of hyperparameter optimization, that you'll have to train a lot of models.
# Therefore execution time will be longer in this exercise, running the completed notebook takes about 30 minutes on a tutor's 3 year old laptop.

# %% [markdown]
# #### Install HpBandster and torchvision
#
# You need to install two more python packages for this exercise.
#
# - [torchvision](https://pytorch.org/docs/stable/torchvision/) provides utility methods for pytorch.
# - [HpBandSter](https://github.com/automl/HpBandSter) is a fast, parallel implementation of several hyperparameter optimizers.
#    We can define even complex hyperparameter search spaces with [ConfigSpace](https://github.com/automl/ConfigSpace), which comes along HpBandSter as dependency.
#
#
# Install with anaconda/conda
# ```
# conda install torchvision
# conda install hpbandster
# ```
#
# or with plain python
# ```
# pip3 install torchvision
# pip3 install hpbandster
# ```

# %%
import os
from typing import Tuple, List

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
import torchvision
import torchvision.transforms as transforms

import ConfigSpace as CS
import ConfigSpace.hyperparameters as CSH

from ConfigSpace.hyperparameters import CategoricalHyperparameter, \
    UniformFloatHyperparameter, UniformIntegerHyperparameter
from ConfigSpace.conditions import InCondition

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

class Flatten(nn.Module): 
    def forward(self, input):
        self.input_shape = input.shape
        return input.view(input.size(0), -1)

def load_mnist_minibatched(batch_size: int, n_train: int = 8192, n_valid: int = 1024,
                           valid_test_batch_size: int = 1024) -> Tuple[DataLoader, DataLoader, DataLoader]:
    train_dataset = torchvision.datasets.MNIST(
        root='../data', train=True, transform=transforms.ToTensor(), download=True)
    test_dataset = torchvision.datasets.MNIST(
        root='../data', train=False, transform=transforms.ToTensor())

    train_sampler = SubsetRandomSampler(range(n_train))
    validation_sampler = SubsetRandomSampler(range(n_train, n_train+n_valid))

    train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, sampler=train_sampler)
    validation_loader = DataLoader(dataset=train_dataset, batch_size=valid_test_batch_size,
                                   sampler=validation_sampler)
    test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=valid_test_batch_size, 
                                              shuffle=False)
    return train_loader, validation_loader, test_loader


def evaluate_accuracy(model: nn.Module, data_loader: DataLoader, loss_fn) -> float:
    model.eval()
    correct = 0
    loss = 0
    with torch.no_grad():
        for x, y in data_loader:
            output = model(x)
            if(loss_fn!=None):
                loss+=loss_fn(output, y)
            # get the index of the max log-probability
            pred = output.max(1, keepdim=True)[1]
            correct += pred.eq(y.view_as(pred)).sum().item()
    accuracy = correct / len(data_loader.sampler)
    return accuracy, loss

# %% [markdown]
# ## Random Search
#
# Here we get hands on hyperparameter optimization using random search.
#
# ### Model and Hyperparameter Space
#
# First we define a configurable model and a hyperparameter space. You learn how to use *ConfigSpace* to define the hyperparameters, by looking at [this example](https://automl.github.io/SMAC3/stable/quickstart.html#using-smac-in-python-svm).
#
# **Task:** Complete the functions as described in the docstrings.
#
# **Hint:** The `CS.GreaterThanCondition(conditioned_hyperparameter, lefthand_side, righthand_side)` method might be useful.

# %%
from collections import OrderedDict

    
def get_conv_model(num_filters_per_layer: List[int]) -> nn.Module:
    """Builds a deep convolutional model with various number of convolution
       layers for MNIST input using pytorch.

    for each element in num_filters_per_layer:
        convolution (conv_kernel_size, num_filters, stride=1, padding=0)
        relu
        max pool    (pool_kernel_size, stride=1)
    linear
    log softmax
    """
    assert len(num_filters_per_layer) > 0, "len(num_filters_per_layer) should be greater than 0"
    pool_kernel_size = 2
    conv_kernel_size = 3
    h = 28
    w = 28
    layer_count = len(num_filters_per_layer)
    input_channels = 1
    model  = nn.Sequential()
    for i in range(layer_count):
        conv2d = nn.Conv2d(input_channels, num_filters_per_layer[i], conv_kernel_size, stride=1, padding =0)
        rel = nn.ReLU()
        max_pool = nn.MaxPool2d(pool_kernel_size,stride=2)
        input_channels = num_filters_per_layer[i]
        #model.add_module(f"conv{i}",conv2d)
        #model.add_module(f"rel{i}",rel)
        #model.add_module(f"pool{i}",max_pool)
        model.add_module("conv{}".format(conv2d))
        model.add_module("rel{}".format(rel))
        model.add_module("pool{}".format(max_pool))
        #size after conv
        h = (h-conv_kernel_size)//1 + 1
        w = (w-conv_kernel_size)//1 + 1
        #size after pooling
        h = (h-pool_kernel_size)//2 + 1
        w = (w-pool_kernel_size)//2 + 1
    model.add_module("flat",Flatten())
    model.add_module("lin",nn.Linear(h*w*num_filters_per_layer[-1], 10))
    model.add_module("logsoftmax",nn.LogSoftmax(dim=1))
    return model

def get_configspace() -> CS.ConfigurationSpace:
    """ Define a conditional hyperparameter search-space.
    
    hyperparameters:
      lr              from 1e-6 to 1e-0 (log, float)
      num_filters_1   from    2 to    8 (int)
      num_filters_2   from    2 to    8 (int)
      num_conv_layers from    1 to    2 (int)
    
    conditions: 
      include num_filters_2 only if num_conv_layers > 1
    """
    cs = CS.ConfigurationSpace()
    lr = UniformFloatHyperparameter("lr", 1e-6, 1e-0, default_value = 1e-2, log=True)
    cs.add_hyperparameter(lr)
    
    num_filters_1 = UniformIntegerHyperparameter("nf0", 2, 8, default_value=3)
    cs.add_hyperparameter(num_filters_1)
    
    num_conv_layers = UniformIntegerHyperparameter("convs", 1, 2, default_value=1)
    num_filters_2 = UniformIntegerHyperparameter("nf1", 2, 8, default_value=3)
    cs.add_hyperparameters([num_conv_layers, num_filters_2])
    #cs.add_condition(InCondition(child=num_filters_2, parent = num_conv_layers, values=[2]))
    cs.add_condition(CS.GreaterThanCondition(num_filters_2, num_conv_layers, 1))
    return cs
# Out:
#   File "<ipython-input-2-a54a3b200eff>", line 28
#     model.add_module(f"conv{i}",conv2d)
#                               ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Run model with configuration
#
# A single sample from your hyperparameter space is a *Configuration*. You can use the configuration similar to a dictionary, it supports *config.keys(), config.values(), value = config[key], key in config, …* .
# You can iterate a *DataLoader* to access (data, label) batches.
#
# **Note:** If a condition isn't met, the conditional hyperparameter isn't included in the configuration.
#
# **Task:** Complete the function to run a model like defined by the configuration. The function should return the model and the *validation error* for each epoch. You can use *evaluate_accuracy* (defined above), don't forget to switch between train and eval mode.

# %%
def run_conv_model(config: CS.Configuration, epochs: int, train_loader: DataLoader,
                   validation_loader: DataLoader) -> Tuple[nn.Module, List[float]]:    
    """ Run and evaluate a model from get_conv_model with NLLLoss and SGD.
    """
    # retrieve the number of filters from the config and create the model
    lrate = config["lr"]
    num_conv_layers = config["convs"]
    num_filters =[]
    for i in range(num_conv_layers):
        num_filters.append(config[f"nf{i}"])
        
    print(f"sampled config : lr: {lrate} #fitlers: {num_filters} #conv_layers: {num_conv_layers}")
    model = get_conv_model(num_filters)
    
    # define loss and optimizer
    loss_fn = torch.nn.NLLLoss()
    optimizer = torch.optim.SGD(model.parameters(), lr=lrate)
    #scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)
    val_errors = []
    for epoch in range(epochs):
        for x, y in train_loader:
            model.train()
            optimizer.zero_grad()
            output = model(x)
            loss = loss_fn(output,y)
            #print(f"train loss for epoch {epoch} : {loss}")
            loss.backward()
            optimizer.step()
        # compute the validation loss
        accuracy, loss = evaluate_accuracy(model, validation_loader, loss_fn)
        val_errors.append(loss)
        print(f"epoch{epoch} : accracy = {accuracy}, loss = {loss}")
        #scheduler.step()
    return model, val_errors

# %% [markdown]
# Now let's run models with various, random hyperparameter configurations. Don't forget to store all the configuration and validation errors for further evaluation.
#
# **Tipp:** *ConfigSpace* objects have a *.sample_configuration()* function to sample a random configuration.
#
# **Task:** Run *n_random_samples* models for *n_epochs* and store the tuple `(model, config, val_errors)` in `results`.

# %%
n_random_samples = 18
n_epochs = 9
cs = get_configspace()

train_loader, validation_loader, _ = load_mnist_minibatched(batch_size=32, n_train=4096, n_valid=512)
results = []
for i in range(n_random_samples):
    print(f"training model #{i+1}")
    cfg = cs.sample_configuration()
    model, val_errors = run_conv_model(cfg, n_epochs, train_loader, validation_loader)
    results.append((model,cfg,val_errors))
    print("----------------------------------")
# Out:
# training model #1
# sampled config : lr: 0.001579229890368543 #fitlers: [6, 4] #conv_layers: 2
# epoch0 : accracy = 0.072265625, loss = 2.302873134613037
# epoch1 : accracy = 0.076171875, loss = 2.298658609390259
# epoch2 : accracy = 0.087890625, loss = 2.2950520515441895
# epoch3 : accracy = 0.099609375, loss = 2.2915310859680176
# epoch4 : accracy = 0.103515625, loss = 2.2878410816192627
# epoch5 : accracy = 0.119140625, loss = 2.2839088439941406
# epoch6 : accracy = 0.140625, loss = 2.279597282409668
# epoch7 : accracy = 0.15625, loss = 2.2746760845184326
# epoch8 : accracy = 0.177734375, loss = 2.269193410873413
# ----------------------------------
# training model #2
# sampled config : lr: 0.003618863263659829 #fitlers: [8, 6] #conv_layers: 2
# epoch0 : accracy = 0.15625, loss = 2.2806107997894287
# epoch1 : accracy = 0.24609375, loss = 2.243508815765381
# epoch2 : accracy = 0.431640625, loss = 2.166515350341797
# epoch3 : accracy = 0.55078125, loss = 1.9711828231811523
# epoch4 : accracy = 0.638671875, loss = 1.5003139972686768
# epoch5 : accracy = 0.7890625, loss = 0.9719692468643188
# epoch6 : accracy = 0.814453125, loss = 0.7230390310287476
# epoch7 : accracy = 0.845703125, loss = 0.5864896774291992
# epoch8 : accracy = 0.857421875, loss = 0.5228332877159119
# ----------------------------------
# training model #3
# sampled config : lr: 0.010176567427030013 #fitlers: [8, 6] #conv_layers: 2
# epoch0 : accracy = 0.173828125, loss = 2.287238121032715
# epoch1 : accracy = 0.365234375, loss = 2.2375714778900146
# epoch2 : accracy = 0.564453125, loss = 1.9019596576690674
# epoch3 : accracy = 0.77734375, loss = 0.790895938873291
# epoch4 : accracy = 0.806640625, loss = 0.5955700874328613
# epoch5 : accracy = 0.859375, loss = 0.4801456928253174
# epoch6 : accracy = 0.869140625, loss = 0.4580034017562866
# epoch7 : accracy = 0.873046875, loss = 0.43850579857826233
# epoch8 : accracy = 0.84765625, loss = 0.4809555411338806
# ----------------------------------
# training model #4
# sampled config : lr: 0.16824195474326825 #fitlers: [4] #conv_layers: 1
# epoch0 : accracy = 0.890625, loss = 0.3816644549369812
# epoch1 : accracy = 0.900390625, loss = 0.3264256417751312
# epoch2 : accracy = 0.916015625, loss = 0.31460028886795044
# epoch3 : accracy = 0.91796875, loss = 0.2977164387702942
# epoch4 : accracy = 0.9296875, loss = 0.2580074965953827
# epoch5 : accracy = 0.935546875, loss = 0.2493424117565155
# epoch6 : accracy = 0.947265625, loss = 0.21877895295619965
# epoch7 : accracy = 0.94140625, loss = 0.20806533098220825
# epoch8 : accracy = 0.94921875, loss = 0.21479585766792297
# ----------------------------------
# training model #5
# sampled config : lr: 0.04278411529058729 #fitlers: [2] #conv_layers: 1
# epoch0 : accracy = 0.818359375, loss = 0.7060841917991638
# epoch1 : accracy = 0.890625, loss = 0.3807823359966278
# epoch2 : accracy = 0.876953125, loss = 0.40553709864616394
# epoch3 : accracy = 0.90234375, loss = 0.35110512375831604
# epoch4 : accracy = 0.89453125, loss = 0.35876038670539856
# epoch5 : accracy = 0.90625, loss = 0.3296482264995575
# epoch6 : accracy = 0.912109375, loss = 0.34114211797714233
# epoch7 : accracy = 0.912109375, loss = 0.3064959943294525
# epoch8 : accracy = 0.91015625, loss = 0.3407307267189026
# ----------------------------------
# training model #6
# sampled config : lr: 0.0004379982799776149 #fitlers: [7, 3] #conv_layers: 2
# epoch0 : accracy = 0.125, loss = 2.324186086654663
# epoch1 : accracy = 0.123046875, loss = 2.319042205810547
# epoch2 : accracy = 0.126953125, loss = 2.3148508071899414
# epoch3 : accracy = 0.140625, loss = 2.311326742172241
# epoch4 : accracy = 0.1484375, loss = 2.3083198070526123
# epoch5 : accracy = 0.15625, loss = 2.3056674003601074
# epoch6 : accracy = 0.162109375, loss = 2.303295135498047
# epoch7 : accracy = 0.162109375, loss = 2.3011128902435303
# epoch8 : accracy = 0.166015625, loss = 2.299100875854492
# ----------------------------------
# training model #7
# sampled config : lr: 0.8283770976860833 #fitlers: [3, 4] #conv_layers: 2
# epoch0 : accracy = 0.091796875, loss = 2.3090906143188477
# epoch1 : accracy = 0.11328125, loss = 2.308673858642578
# epoch2 : accracy = 0.125, loss = 2.304870843887329
# epoch3 : accracy = 0.125, loss = 2.3014442920684814
# epoch4 : accracy = 0.087890625, loss = 2.304978370666504
# epoch5 : accracy = 0.087890625, loss = 2.3031654357910156
# epoch6 : accracy = 0.11328125, loss = 2.3003361225128174
# epoch7 : accracy = 0.125, loss = 2.2978086471557617
# epoch8 : accracy = 0.11328125, loss = 2.29777455329895
# ----------------------------------
# training model #8
# sampled config : lr: 0.8598385512683512 #fitlers: [2] #conv_layers: 1
# epoch0 : accracy = 0.125, loss = 2.2975220680236816
# epoch1 : accracy = 0.11328125, loss = 2.301499843597412
# epoch2 : accracy = 0.11328125, loss = 2.307631015777588
# epoch3 : accracy = 0.091796875, loss = 2.309675931930542
# epoch4 : accracy = 0.125, loss = 2.3025059700012207
# epoch5 : accracy = 0.11328125, loss = 2.2984066009521484
# epoch6 : accracy = 0.11328125, loss = 2.3029017448425293
# epoch7 : accracy = 0.11328125, loss = 2.3017635345458984
# epoch8 : accracy = 0.11328125, loss = 2.2992119789123535
# ----------------------------------
# training model #9
# sampled config : lr: 0.001955935377414028 #fitlers: [3] #conv_layers: 1
# epoch0 : accracy = 0.380859375, loss = 2.1789889335632324
# epoch1 : accracy = 0.583984375, loss = 2.0323710441589355
# epoch2 : accracy = 0.681640625, loss = 1.817083716392517
# epoch3 : accracy = 0.732421875, loss = 1.5335581302642822
# epoch4 : accracy = 0.7734375, loss = 1.2443960905075073
# epoch5 : accracy = 0.8046875, loss = 1.0051944255828857
# epoch6 : accracy = 0.8203125, loss = 0.8415622115135193
# epoch7 : accracy = 0.837890625, loss = 0.7256186008453369
# epoch8 : accracy = 0.853515625, loss = 0.6427170634269714
# ----------------------------------
# training model #10
# sampled config : lr: 9.005726679487812e-05 #fitlers: [3] #conv_layers: 1
# epoch0 : accracy = 0.125, loss = 2.2972185611724854
# epoch1 : accracy = 0.126953125, loss = 2.296504497528076
# epoch2 : accracy = 0.126953125, loss = 2.2957980632781982
# epoch3 : accracy = 0.126953125, loss = 2.2950973510742188
# epoch4 : accracy = 0.126953125, loss = 2.294404983520508
# epoch5 : accracy = 0.125, loss = 2.2937164306640625
# epoch6 : accracy = 0.126953125, loss = 2.2930352687835693
# epoch7 : accracy = 0.12890625, loss = 2.292358636856079
# epoch8 : accracy = 0.12890625, loss = 2.2916858196258545
# ----------------------------------
# training model #11
# sampled config : lr: 0.12997500952069355 #fitlers: [2, 6] #conv_layers: 2
# epoch0 : accracy = 0.703125, loss = 0.9858176112174988
# epoch1 : accracy = 0.89453125, loss = 0.33128005266189575
# epoch2 : accracy = 0.943359375, loss = 0.20509523153305054
# epoch3 : accracy = 0.93359375, loss = 0.21607254445552826
# epoch4 : accracy = 0.94140625, loss = 0.16285213828086853
# epoch5 : accracy = 0.931640625, loss = 0.19655272364616394
# epoch6 : accracy = 0.953125, loss = 0.1655561625957489
# epoch7 : accracy = 0.947265625, loss = 0.14923088252544403
# epoch8 : accracy = 0.947265625, loss = 0.18096691370010376
# ----------------------------------
# training model #12
# sampled config : lr: 0.023539736822427763 #fitlers: [2] #conv_layers: 1
# epoch0 : accracy = 0.8359375, loss = 0.6765641570091248
# epoch1 : accracy = 0.876953125, loss = 0.4130040109157562
# epoch2 : accracy = 0.89453125, loss = 0.39452365040779114
# epoch3 : accracy = 0.888671875, loss = 0.3543913662433624
# epoch4 : accracy = 0.88671875, loss = 0.39167895913124084
# epoch5 : accracy = 0.91015625, loss = 0.31905972957611084
# epoch6 : accracy = 0.91015625, loss = 0.3389436900615692
# epoch7 : accracy = 0.896484375, loss = 0.35266897082328796
# epoch8 : accracy = 0.90625, loss = 0.32882577180862427
# ----------------------------------
# training model #13
# sampled config : lr: 0.0008443591769490963 #fitlers: [5] #conv_layers: 1
# epoch0 : accracy = 0.068359375, loss = 2.30041241645813
# epoch1 : accracy = 0.11328125, loss = 2.286130905151367
# epoch2 : accracy = 0.16015625, loss = 2.2729055881500244
# epoch3 : accracy = 0.220703125, loss = 2.259610891342163
# epoch4 : accracy = 0.259765625, loss = 2.2460110187530518
# epoch5 : accracy = 0.31640625, loss = 2.2315361499786377
# epoch6 : accracy = 0.37890625, loss = 2.216282367706299
# epoch7 : accracy = 0.447265625, loss = 2.1994173526763916
# epoch8 : accracy = 0.505859375, loss = 2.1804444789886475
# ----------------------------------
# training model #14
# sampled config : lr: 1.3023628071736361e-06 #fitlers: [8, 8] #conv_layers: 2
# epoch0 : accracy = 0.091796875, loss = 2.3110899925231934
# epoch1 : accracy = 0.091796875, loss = 2.311086416244507
# epoch2 : accracy = 0.091796875, loss = 2.3110854625701904
# epoch3 : accracy = 0.091796875, loss = 2.311082124710083
# epoch4 : accracy = 0.091796875, loss = 2.3110790252685547
# epoch5 : accracy = 0.091796875, loss = 2.3110764026641846
# epoch6 : accracy = 0.091796875, loss = 2.3110733032226562
# epoch7 : accracy = 0.091796875, loss = 2.311070680618286
# epoch8 : accracy = 0.091796875, loss = 2.311068296432495
# ----------------------------------
# training model #15
# sampled config : lr: 0.003762125713524839 #fitlers: [6, 7] #conv_layers: 2
# epoch0 : accracy = 0.076171875, loss = 2.3081908226013184
# epoch1 : accracy = 0.072265625, loss = 2.306518077850342
# epoch2 : accracy = 0.099609375, loss = 2.3051810264587402
# epoch3 : accracy = 0.11328125, loss = 2.3040287494659424
# epoch4 : accracy = 0.111328125, loss = 2.3030059337615967
# epoch5 : accracy = 0.115234375, loss = 2.302067995071411
# epoch6 : accracy = 0.11328125, loss = 2.3011958599090576
# epoch7 : accracy = 0.115234375, loss = 2.300349235534668
# epoch8 : accracy = 0.134765625, loss = 2.2995216846466064
# ----------------------------------
# training model #16
# sampled config : lr: 0.00018443062877336562 #fitlers: [2, 4] #conv_layers: 2
# epoch0 : accracy = 0.1328125, loss = 2.3034508228302
# epoch1 : accracy = 0.134765625, loss = 2.3027029037475586
# epoch2 : accracy = 0.134765625, loss = 2.301962375640869
# epoch3 : accracy = 0.138671875, loss = 2.3012208938598633
# epoch4 : accracy = 0.142578125, loss = 2.300478219985962
# epoch5 : accracy = 0.142578125, loss = 2.299734592437744
# epoch6 : accracy = 0.142578125, loss = 2.2989916801452637
# epoch7 : accracy = 0.140625, loss = 2.298246383666992
# epoch8 : accracy = 0.140625, loss = 2.2974987030029297
# ----------------------------------
# training model #17
# sampled config : lr: 0.16172250170504146 #fitlers: [2, 4] #conv_layers: 2
# epoch0 : accracy = 0.861328125, loss = 0.4419357180595398
# epoch1 : accracy = 0.912109375, loss = 0.2863101363182068
# epoch2 : accracy = 0.9296875, loss = 0.2499287873506546
# epoch3 : accracy = 0.9375, loss = 0.21648283302783966
# epoch4 : accracy = 0.94140625, loss = 0.19831372797489166
# epoch5 : accracy = 0.943359375, loss = 0.210926353931427
# epoch6 : accracy = 0.951171875, loss = 0.19746878743171692
# epoch7 : accracy = 0.935546875, loss = 0.23803284764289856
# epoch8 : accracy = 0.943359375, loss = 0.20268571376800537
# ----------------------------------
# training model #18
# sampled config : lr: 7.679811428659774e-06 #fitlers: [4] #conv_layers: 1
# epoch0 : accracy = 0.11328125, loss = 2.3064017295837402
# epoch1 : accracy = 0.11328125, loss = 2.306309700012207
# epoch2 : accracy = 0.11328125, loss = 2.306216239929199
# epoch3 : accracy = 0.11328125, loss = 2.306122064590454
# epoch4 : accracy = 0.11328125, loss = 2.3060309886932373
# epoch5 : accracy = 0.11328125, loss = 2.305938243865967
# epoch6 : accracy = 0.11328125, loss = 2.3058457374572754
# epoch7 : accracy = 0.11328125, loss = 2.3057539463043213
# epoch8 : accracy = 0.11328125, loss = 2.3056607246398926
# ----------------------------------

# %% [markdown]
# ### Evaluate
#
# Now we should evaluate the previous runs. Evaluation in hyperparameter optimization can mean two different things: On the one hand, we might be only interested in the model with the best performance. On the other hand, we might want to find the best hyperparameter configuration to then train a model with these hyper-parameters (but with e.g. more epochs).
#
# **Task:** Print the model and final validation error of the best model in `results`.

# %%
min_loss = 1000
index = 0
for i in range(len(results)):
    model, cfg , val_error = results[i]
    if (val_error[-1] < min_loss):
        min_loss = val_error[-1]
        index = i
        

best_model, best_cfg, best_error = results[index]
lrate =  best_cfg["lr"]
num_conv_layers = best_cfg["convs"]
num_filters =[]
print(f"best model: #{index+1}, error : {best_error[-1]}")
for i in range(num_conv_layers):
    num_filters.append(best_cfg[f"nf{i}"])
print(f"sampled config : lr: {lrate} #fitlers: {num_filters} #conv_layers: {num_conv_layers}")

for idx, m in enumerate(best_model.named_modules()):
    if idx==0: continue
    print(idx, '->', m)
# Out:
# best model: #11, error : 0.18096691370010376
# sampled config : lr: 0.12997500952069355 #fitlers: [2, 6] #conv_layers: 2
# 1 -> ('conv0', Conv2d(1, 2, kernel_size=(3, 3), stride=(1, 1)))
# 2 -> ('rel0', ReLU())
# 3 -> ('pool0', MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False))
# 4 -> ('conv1', Conv2d(2, 6, kernel_size=(3, 3), stride=(1, 1)))
# 5 -> ('rel1', ReLU())
# 6 -> ('pool1', MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False))
# 7 -> ('flat', Flatten())
# 8 -> ('lin', Linear(in_features=150, out_features=10, bias=True))
# 9 -> ('logsoftmax', LogSoftmax())

# %% [markdown]
# Let's further investigate which hyperparameters work well and which don't.
#
# **Task:** Print a scatter plot of learning rate (x) and number of filters (sum over layers, y). Scale the size of the scatter points by the error in the last epoch (10 to 100).

# %%
plt.figure(1)
plt.xscale('log')
plt.xlabel('learning rate')
plt.ylabel('# of filters')
for i in range(len(results)):
    model, cfg , val_error = results[i]   
    lrate =  cfg["lr"]
    num_conv_layers = cfg["convs"]
    num_filters =[]
    for i in range(num_conv_layers):
        num_filters.append(cfg[f"nf{i}"])
    num_filters = np.sum(num_filters)
    plt.scatter(lrate,num_filters,s=50*val_error[-1])

# %% [markdown]
# **Question:** What pattern do you see? Why might it occur?
#
# **Answer:** There's a sweetspot for the learning rate. The error increases noticably for models outside this region. there's no significant change when it comes to number of filters. The best model has one layer, 5 filters and ~96% validation accuracy. This is probably due to the fact that the task at hand isn't very sophisticated.

# %% [markdown]
# After looking at the final error, let's now have a look at the training error.
#
# **Task:** Plot error curves (error per epoch) for all your configurations in one figure.

# %%
plt.figure(num=2, figsize=(6, 8), dpi=80, facecolor='w', edgecolor='k')
plt.xlabel('epochs')
plt.ylabel('validation error')

for i in range(len(results)):
    _, _ , val_error = results[i]   
    plt.plot(val_error)

# %% [markdown]
# **Questions:** How could you detect configurations with a low error earlier/faster? Why could this be problematic?
#
# **Answers:** Models that have a large validation error could be *stopped early* to avoid wasting time. The threshhold has to be chosen very carefully because some good models might have a large error in early epochs.
#
# e.g. in this plot all the models that have an inital error of **>2** either diverge or don't converge as well. However we could also choose 0.8 as the limit for early stopping. This would lead to the orange model doing the full run while the blue model that converges the best, gets stopped.

# %% [markdown]
# ### Your Feedback on Exercise 6.1
#
# Good exercise. It took me ~3-4 hours to do it. I had some trouble working with the DataLoader class. Also the ConfigSpace class has a small bug that kept me busy for a bit. According to the docs "for deactivated parameters, the configuration stores None-values" but if you try to read them, it'll give an error instead of returning a None value.

# %% [markdown]
# ## BOHB
#
# Here we will use the more advanced hyperparameter optimizer [BOHB](https://www.automl.org/blog_bohb/) (Bayesian Optimization with Hyperband).
# Based on [Hyperband](https://arxiv.org/pdf/1603.06560.pdf), BOHB evaluates configurations on your model with increasing budgets. In the context of Deep Learning, budget can be the number of epochs or the number of training samples. In lower budget evaluations, BOHB can look at more configurations. Full budget evaluations avoid missing configurations which are poor at the beginnning but good at the end (and vice versa).
# At the start of a run, BOHB samples configurations randomly. After some time, BOHB then uses a bayesian model (based on Parzen Tree Estimators), sampling only promising configs.
#
# This exercise part is based on the [HpBandSter Examples](https://automl.github.io/HpBandSter/build/html/auto_examples/index.html) and the [HpBandSter Documentation](https://automl.github.io/HpBandSter/). *HpBandSter* provides a fast implementation of *Randomsearch*, *Hyperband* and *BOHB*. The optimization can easily be distributed between multiple cores or even multiple computers.

# %%
import pickle
import logging

from hpbandster.core.worker import Worker
import hpbandster.core.nameserver as hpns
import hpbandster.core.result as hpres
from hpbandster.optimizers import BOHB

logging.getLogger('hpbandster').setLevel(logging.DEBUG)

# %% [markdown]
# ### Implement Worker
#
# The worker defines the hyperparameter problem which we try to optimize.
# *compute(...)* should - for a given configuration and budget - return a loss which the hyperparameter optimizer tries to minimize. In our case, we can use the number of epochs as budget and the validation error as loss.
# As best practice, we define the configuration space also in the worker.
#
# If you need help, you might get some inspiration from the [HpBandSter Pytorch Worker Example](https://automl.github.io/HpBandSter/build/html/auto_examples/example_5_pytorch_worker.html#sphx-glr-auto-examples-example-5-pytorch-worker-py).
#
# **Task:** Complete the methods below.

# %%
class PyTorchWorker(Worker):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self.train_loader, self.validation_loader, self.test_loader =\
            load_mnist_minibatched(batch_size=32, n_train=4096, n_valid=512)

    @staticmethod
    def get_model(config: CS.Configuration) -> nn.Module:
        """Builds a deep convolutional model with various number of convolution
       layers for MNIST input using pytorch.

        for each element in num_filters_per_layer:
            convolution (conv_kernel_size, num_filters, stride=1, padding=0)
            relu
            max pool    (pool_kernel_size, stride=1)
        linear
        log softmax
        """
        pool_kernel_size = 2
        conv_kernel_size = 3
        h = 28
        w = 28
        
        # reading the filter count in each layer
        num_conv_layers = config["num_conv_layers"]
        num_filters_per_layer =[]        
        for i in range(num_conv_layers):
            num_filters_per_layer.append(config[f"num_filters_{i+1}"])
        
        #creating the model, layer by layer
        input_channels = 1
        model  = nn.Sequential()
        for i in range(num_conv_layers):
            conv2d = nn.Conv2d(input_channels, num_filters_per_layer[i], conv_kernel_size, stride=1, padding =0)
            relu = nn.ReLU()
            max_pool = nn.MaxPool2d(pool_kernel_size,stride=2)
            input_channels = num_filters_per_layer[i]
            model.add_module(f"conv{i+1}",conv2d)
            model.add_module(f"rel{i+1}",relu)
            model.add_module(f"pool{i+1}",max_pool)
            #size after conv
            h = (h-conv_kernel_size)//1 + 1
            w = (w-conv_kernel_size)//1 + 1
            #size after pooling
            h = (h-pool_kernel_size)//2 + 1
            w = (w-pool_kernel_size)//2 + 1
        model.add_module("flat",Flatten())
        model.add_module("lin",nn.Linear(h*w*num_filters_per_layer[-1], 10))
        model.add_module("logsoftmax",nn.LogSoftmax(dim=1))
        return model
        
    @staticmethod
    def get_configspace() -> CS.Configuration:
        """ Define a conditional hyperparameter search-space.
    
        hyperparameters:
          num_filters_1   from    4 to   32 (int)
          num_filters_2   from    4 to   32 (int)
          num_filters_3   from    4 to   32 (int)
          num_conv_layers from    1 to    3 (int)
          lr              from 1e-6 to 1e-1 (float, log)
          sgd_momentum    from 0.00 to 0.99 (float)
          optimizer            Adam or  SGD (categoric)
          
        conditions: 
          include num_filters_2 only if num_conv_layers > 1
          include num_filters_3 only if num_conv_layers > 2
          include sgd_momentum  only if       optimizer = SGD
        """
        cs = CS.ConfigurationSpace()
        #learning rate
        lr = UniformFloatHyperparameter("lr", 1e-6, 1e-1, default_value = 1e-2, log=True)
        cs.add_hyperparameter(lr)
        
        #optimizer
        momentum = UniformFloatHyperparameter("momentum", 0, 0.99, default_value = 0.5)
        optimizer = CategoricalHyperparameter("optim", ["Adam","SGD"], default_value="SGD")
        cs.add_hyperparameters([optimizer, momentum])
        cs.add_condition(InCondition(child=momentum, parent=optimizer, values=["SGD"]))
        
        #conv layer parameters
        num_conv_layers = UniformIntegerHyperparameter("num_conv_layers", 1, 3, default_value=2)
        num_filters_1 = UniformIntegerHyperparameter("num_filters_1", 4, 32, default_value=6)
        num_filters_2 = UniformIntegerHyperparameter("num_filters_2", 4, 32, default_value=6)
        num_filters_3 = UniformIntegerHyperparameter("num_filters_3", 4, 32, default_value=6)
        cs.add_hyperparameters([num_conv_layers, num_filters_1, num_filters_2, num_filters_3])
        cs.add_condition(CS.GreaterThanCondition(num_filters_2, num_conv_layers, 1))
        cs.add_condition(CS.GreaterThanCondition(num_filters_3, num_conv_layers, 2))
        return cs

    def compute(self, config: CS.Configuration, budget: float, working_directory: str,
                *args, **kwargs) -> float:
        """Evaluate a function with the given config and budget and return a loss.
        
        Bohb tries to minimize the returned loss.
        
        In our case the function is the training and validation of a model,
        the budget is the number of epochs and the loss is the validation error.
        """
        model = self.get_model(config)
        
        #setting up the optimizer
        lrate = config["lr"]
        optim = config["optim"]
        optimizer = torch.optim.Adam(model.parameters(), lr = lrate)
        if(optim == "SGD"):
            mom = config["momentum"]
            optimizer = torch.optim.SGD(model.parameters(), lr = lrate, momentum = mom)
        loss_fn = torch.nn.NLLLoss()
        
        #training
        epochs = int(budget)
        for epoch in range(epochs):
            for x, y in self.train_loader:
                model.train()
                optimizer.zero_grad()
                output = model(x)
                loss = loss_fn(output,y)
                loss.backward()
                optimizer.step()
            #compute the validation loss
            #accuracy, loss = evaluate_accuracy(model, validation_loader, loss_fn)
            #val_errors.append(loss)
            #print(f"epoch{epoch} : accracy = {accuracy}, loss = {loss}")
        
        #i changed the evaluate_accuracy function. now it returns loss as well, hence the _ and None
        train_accuracy, _ = evaluate_accuracy(model, self.train_loader, None)
        validation_accuracy, _ = evaluate_accuracy(model, self.validation_loader, None)
        test_accuracy, _ = evaluate_accuracy(model, self.test_loader, None)
        
        return ({
                'loss': 1 - validation_accuracy,  # remember: HpBandSter minimizes the loss!
                'info': {'test_accuracy': test_accuracy,
                         'train_accuracy': train_accuracy,
                         'valid_accuracy': validation_accuracy,
                         'model': str(model)}
                })

# %% [markdown]
# It's best practice to do a quick sanity check of our worker with a low budget:

# %%
working_dir = os.curdir
# minimum budget that BOHB uses
min_budget = 1
# largest budget BOHB will use
max_budget = 9

# %%
import warnings

#it was giving me a lot fo warnings for log_softmax

worker = PyTorchWorker(run_id='0')
cs = worker.get_configspace()

config = cs.sample_configuration().get_dictionary()
print(config)

res = worker.compute(config=config, budget=min_budget, working_directory=working_dir)
print(res)
# Out:
# {'lr': 2.9131521970906648e-06, 'num_conv_layers': 2, 'num_filters_1': 29, 'optim': 'SGD', 'momentum': 0.7589976875960607, 'num_filters_2': 17}
# {'loss': 0.875, 'info': {'test_accuracy': 0.1028, 'train_accuracy': 0.108154296875, 'valid_accuracy': 0.125, 'model': 'Sequential(\n  (conv1): Conv2d(1, 29, kernel_size=(3, 3), stride=(1, 1))\n  (rel1): ReLU()\n  (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv2): Conv2d(29, 17, kernel_size=(3, 3), stride=(1, 1))\n  (rel2): ReLU()\n  (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=425, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}}

# %% [markdown]
# ### Run BOHB
#
# We now run the hyperparameter search with BOHB and the worker which we defined above and save the result to disk.
# Try to understand what happens. *HpBandSter* allows to start additional workers on the same or remote devices to parallelize the executions, that's why we need to setup some network stuff (nameserver, nic, host, port, …). If you're interested, you can check this out in the [HpBandSter Examples](https://automl.github.io/HpBandSter/build/html/auto_examples/index.html), but it is beyond the scope of this exercise.
#
# **Note:** The code below will try 60 different configurations. Some of them are executed at multiple budgets, which results in about 80 model training. Therefore it might take a while (15-45 minutes on a laptop). If you are interested in how BOHB works, checkout [BOHB (Falkner et al. 2018)](http://proceedings.mlr.press/v80/falkner18a.html).
#
# **Note 2:** You can see the progress in the debug output below. The configuration identifier (called `config_id` in the docs) is a three-tuple `(current iteration, resampling in case of error, sample)`.

# %%
result_file = os.path.join(working_dir, 'bohb_result.pkl')
nic_name = 'lo'
port = 0
run_id = 'bohb_run_1'
n_bohb_iterations = 12

# %%
try:
    # Start a nameserver
    host = '127.0.0.1'#hpns.nic_name_to_host(nic_name)
    ns = hpns.NameServer(run_id=run_id, host=host, port=port,
                         working_directory=working_dir)
    ns_host, ns_port = ns.start()

    # Start local worker
    w = PyTorchWorker(run_id=run_id, host=host, nameserver=ns_host,
                      nameserver_port=ns_port, timeout=120)
    w.run(background=True)

    # Run an optimizer
    bohb = BOHB(configspace=worker.get_configspace(),
                run_id=run_id,
                host=host,
                nameserver=ns_host,
                nameserver_port=ns_port,
                min_budget=min_budget, max_budget=max_budget)
    
    result = bohb.run(n_iterations=n_bohb_iterations)
    print("Write result to file {}".format(result_file))
    with open(result_file, 'wb') as f:
        pickle.dump(result, f)
finally:
    bohb.shutdown(shutdown_workers=True)
    ns.shutdown()
# Out:
# 14:12:38 WORKER: Connected to nameserver <Pyro4.core.Proxy at 0x22757c51ac8; connected IPv4; for PYRO:Pyro.NameServer@127.0.0.1:51593>
# 14:12:38 wait_for_workers trying to get the condition
# 14:12:38 DISPATCHER: started the 'discover_worker' thread
# 14:12:38 WORKER: No dispatcher found. Waiting for one to initiate contact.
# 14:12:38 DISPATCHER: started the 'job_runner' thread
# 14:12:38 WORKER: start listening for jobs
# 14:12:38 DISPATCHER: Pyro daemon running on 127.0.0.1:51599
# 14:12:38 DISPATCHER: Starting worker discovery
# 14:12:38 DISPATCHER: Found 1 potential workers, 0 currently in the pool.
# 14:12:38 DISPATCHER: discovered new worker, hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:12:38 HBMASTER: number of workers changed to 1
# 14:12:38 Enough workers to start this run!
# 14:12:38 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 14:12:38 adjust_queue_size: lock accquired
# 14:12:38 HBMASTER: starting run at 1543583558.1273866
# 14:12:38 HBMASTER: adjusted queue size to (0, 1)
# 14:12:38 DISPATCHER: Finished worker discovery
# 14:12:38 start sampling a new configuration.
# 14:12:38 DISPATCHER: Trying to submit another job.
# 14:12:38 done sampling a new configuration.
# 14:12:38 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 14:12:38 HBMASTER: schedule new run for iteration 0
# 14:12:38 HBMASTER: trying submitting job (0, 0, 0) to dispatcher
# 14:12:38 HBMASTER: submitting job (0, 0, 0) to dispatcher
# 14:12:38 DISPATCHER: trying to submit job (0, 0, 0)
# 14:12:38 DISPATCHER: trying to notify the job_runner thread.
# 14:12:38 HBMASTER: job (0, 0, 0) submitted to dispatcher
# 14:12:38 DISPATCHER: Trying to submit another job.
# 14:12:38 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 14:12:38 DISPATCHER: starting job (0, 0, 0) on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:12:38 DISPATCHER: job (0, 0, 0) dispatched on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:12:38 WORKER: start processing job (0, 0, 0)
# 14:12:38 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 14:12:38 WORKER: args: ()
# 14:12:38 WORKER: kwargs: {'config': {'lr': 0.009242722791700719, 'num_conv_layers': 3, 'num_filters_1': 22, 'optim': 'SGD', 'momentum': 0.25714485457545416, 'num_filters_2': 23, 'num_filters_3': 16}, 'budget': 1.0, 'working_directory': '.'}
# 14:12:50 WORKER: done with job (0, 0, 0), trying to register it.
# 14:12:50 WORKER: registered result for job (0, 0, 0) with dispatcher
# 14:12:50 DISPATCHER: job (0, 0, 0) finished
# 14:12:50 DISPATCHER: register_result: lock acquired
# 14:12:50 DISPATCHER: job (0, 0, 0) on hpbandster.run_bohb_run_1.worker.MSI.1170820484 finished
# 14:12:50 job_id: (0, 0, 0)
# kwargs: {'config': {'lr': 0.009242722791700719, 'num_conv_layers': 3, 'num_filters_1': 22, 'optim': 'SGD', 'momentum': 0.25714485457545416, 'num_filters_2': 23, 'num_filters_3': 16}, 'budget': 1.0, 'working_directory': '.'}
# result: {'loss': 0.90625, 'info': {'test_accuracy': 0.0979, 'train_accuracy': 0.102783203125, 'valid_accuracy': 0.09375, 'model': 'Sequential(\n  (conv1): Conv2d(1, 22, kernel_size=(3, 3), stride=(1, 1))\n  (rel1): ReLU()\n  (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv2): Conv2d(22, 23, kernel_size=(3, 3), stride=(1, 1))\n  (rel2): ReLU()\n  (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv3): Conv2d(23, 16, kernel_size=(3, 3), stride=(1, 1))\n  (rel3): ReLU()\n  (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=16, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}}
# exception: None
#
# 14:12:50 job_callback for (0, 0, 0) started
# 14:12:50 DISPATCHER: Trying to submit another job.
# 14:12:50 job_callback for (0, 0, 0) got condition
# 14:12:50 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 14:12:50 Only 1 run(s) for budget 1.000000 available, need more than 9 -> can't build model!
# 14:12:50 HBMASTER: Trying to run another job!
# 14:12:50 job_callback for (0, 0, 0) finished
# 14:12:50 start sampling a new configuration.
# 14:12:50 done sampling a new configuration.
# 14:12:50 HBMASTER: schedule new run for iteration 0
# 14:12:50 HBMASTER: trying submitting job (0, 0, 1) to dispatcher
# 14:12:50 HBMASTER: submitting job (0, 0, 1) to dispatcher
# 14:12:50 DISPATCHER: trying to submit job (0, 0, 1)
# 14:12:50 DISPATCHER: trying to notify the job_runner thread.
# 14:12:50 HBMASTER: job (0, 0, 1) submitted to dispatcher
# 14:12:50 DISPATCHER: Trying to submit another job.
# 14:12:50 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 14:12:50 DISPATCHER: starting job (0, 0, 1) on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:12:50 DISPATCHER: job (0, 0, 1) dispatched on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:12:50 WORKER: start processing job (0, 0, 1)
# 14:12:50 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 14:12:50 WORKER: args: ()
# 14:12:50 WORKER: kwargs: {'config': {'lr': 0.003656404685600867, 'num_conv_layers': 2, 'num_filters_1': 6, 'optim': 'SGD', 'momentum': 0.534373246126249, 'num_filters_2': 8}, 'budget': 1.0, 'working_directory': '.'}
# 14:12:56 WORKER: done with job (0, 0, 1), trying to register it.
# 14:12:56 WORKER: registered result for job (0, 0, 1) with dispatcher
# 14:12:56 DISPATCHER: job (0, 0, 1) finished
# 14:12:56 DISPATCHER: register_result: lock acquired
# 14:12:56 DISPATCHER: job (0, 0, 1) on hpbandster.run_bohb_run_1.worker.MSI.1170820484 finished
# 14:12:56 job_id: (0, 0, 1)
# kwargs: {'config': {'lr': 0.003656404685600867, 'num_conv_layers': 2, 'num_filters_1': 6, 'optim': 'SGD', 'momentum': 0.534373246126249, 'num_filters_2': 8}, 'budget': 1.0, 'working_directory': '.'}
# result: {'loss': 0.798828125, 'info': {'test_accuracy': 0.1915, 'train_accuracy': 0.19775390625, 'valid_accuracy': 0.201171875, 'model': 'Sequential(\n  (conv1): Conv2d(1, 6, kernel_size=(3, 3), stride=(1, 1))\n  (rel1): ReLU()\n  (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv2): Conv2d(6, 8, kernel_size=(3, 3), stride=(1, 1))\n  (rel2): ReLU()\n  (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=200, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}}
# exception: None
#
# 14:12:56 job_callback for (0, 0, 1) started
# 14:12:56 DISPATCHER: Trying to submit another job.
# 14:12:56 job_callback for (0, 0, 1) got condition
# 14:12:56 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 14:12:56 Only 2 run(s) for budget 1.000000 available, need more than 9 -> can't build model!
# 14:12:56 HBMASTER: Trying to run another job!
# 14:12:56 job_callback for (0, 0, 1) finished
# 14:12:56 start sampling a new configuration.
# 14:12:56 done sampling a new configuration.
# 14:12:56 HBMASTER: schedule new run for iteration 0
# 14:12:56 HBMASTER: trying submitting job (0, 0, 2) to dispatcher
# 14:12:56 HBMASTER: submitting job (0, 0, 2) to dispatcher
# 14:12:56 DISPATCHER: trying to submit job (0, 0, 2)
# 14:12:56 DISPATCHER: trying to notify the job_runner thread.
# 14:12:56 HBMASTER: job (0, 0, 2) submitted to dispatcher
# 14:12:56 DISPATCHER: Trying to submit another job.
# 14:12:56 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 14:12:56 DISPATCHER: starting job (0, 0, 2) on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:12:56 DISPATCHER: job (0, 0, 2) dispatched on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:12:56 WORKER: start processing job (0, 0, 2)
# 14:12:56 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 14:12:56 WORKER: args: ()
# 14:12:56 WORKER: kwargs: {'config': {'lr': 8.242858299559516e-05, 'num_conv_layers': 3, 'num_filters_1': 23, 'optim': 'Adam', 'num_filters_2': 32, 'num_filters_3': 6}, 'budget': 1.0, 'working_directory': '.'}
# 14:13:09 WORKER: done with job (0, 0, 2), trying to register it.
# 14:13:09 WORKER: registered result for job (0, 0, 2) with dispatcher
# 14:13:09 DISPATCHER: job (0, 0, 2) finished
# 14:13:09 DISPATCHER: register_result: lock acquired
# 14:13:09 DISPATCHER: job (0, 0, 2) on hpbandster.run_bohb_run_1.worker.MSI.1170820484 finished
# 14:13:09 job_id: (0, 0, 2)
# kwargs: {'config': {'lr': 8.242858299559516e-05, 'num_conv_layers': 3, 'num_filters_1': 23, 'optim': 'Adam', 'num_filters_2': 32, 'num_filters_3': 6}, 'budget': 1.0, 'working_directory': '.'}
# result: {'loss': 0.91796875, 'info': {'test_accuracy': 0.0892, 'train_accuracy': 0.087890625, 'valid_accuracy': 0.08203125, 'model': 'Sequential(\n  (conv1): Conv2d(1, 23, kernel_size=(3, 3), stride=(1, 1))\n  (rel1): ReLU()\n  (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv2): Conv2d(23, 32, kernel_size=(3, 3), stride=(1, 1))\n  (rel2): ReLU()\n  (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv3): Conv2d(32, 6, kernel_size=(3, 3), stride=(1, 1))\n  (rel3): ReLU()\n  (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=6, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}}
# exception: None
#
# 14:13:09 job_callback for (0, 0, 2) started
# 14:13:09 DISPATCHER: Trying to submit another job.
# 14:13:09 job_callback for (0, 0, 2) got condition
# 14:13:09 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 14:13:09 Only 3 run(s) for budget 1.000000 available, need more than 9 -> can't build model!
# 14:13:09 HBMASTER: Trying to run another job!
# 14:13:09 job_callback for (0, 0, 2) finished
# 14:13:09 start sampling a new configuration.
# 14:13:09 done sampling a new configuration.
# 14:13:09 HBMASTER: schedule new run for iteration 0
# 14:13:09 HBMASTER: trying submitting job (0, 0, 3) to dispatcher
# 14:13:09 HBMASTER: submitting job (0, 0, 3) to dispatcher
# 14:13:09 DISPATCHER: trying to submit job (0, 0, 3)
# 14:13:09 DISPATCHER: trying to notify the job_runner thread.
# 14:13:09 HBMASTER: job (0, 0, 3) submitted to dispatcher
# 14:13:09 DISPATCHER: Trying to submit another job.
# 14:13:09 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 14:13:09 DISPATCHER: starting job (0, 0, 3) on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:13:09 DISPATCHER: job (0, 0, 3) dispatched on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:13:09 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 14:13:09 WORKER: start processing job (0, 0, 3)
# 14:13:09 WORKER: args: ()
# 14:13:09 WORKER: kwargs: {'config': {'lr': 0.00024278009979006987, 'num_conv_layers': 3, 'num_filters_1': 29, 'optim': 'Adam', 'num_filters_2': 13, 'num_filters_3': 21}, 'budget': 1.0, 'working_directory': '.'}
# 14:13:21 WORKER: done with job (0, 0, 3), trying to register it.
# 14:13:21 WORKER: registered result for job (0, 0, 3) with dispatcher
# 14:13:21 DISPATCHER: job (0, 0, 3) finished
# 14:13:21 DISPATCHER: register_result: lock acquired
# 14:13:21 DISPATCHER: job (0, 0, 3) on hpbandster.run_bohb_run_1.worker.MSI.1170820484 finished
# 14:13:21 job_id: (0, 0, 3)
# kwargs: {'config': {'lr': 0.00024278009979006987, 'num_conv_layers': 3, 'num_filters_1': 29, 'optim': 'Adam', 'num_filters_2': 13, 'num_filters_3': 21}, 'budget': 1.0, 'working_directory': '.'}
# result: {'loss': 0.513671875, 'info': {'test_accuracy': 0.4585, 'train_accuracy': 0.4677734375, 'valid_accuracy': 0.486328125, 'model': 'Sequential(\n  (conv1): Conv2d(1, 29, kernel_size=(3, 3), stride=(1, 1))\n  (rel1): ReLU()\n  (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv2): Conv2d(29, 13, kernel_size=(3, 3), stride=(1, 1))\n  (rel2): ReLU()\n  (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv3): Conv2d(13, 21, kernel_size=(3, 3), stride=(1, 1))\n  (rel3): ReLU()\n  (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=21, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}}
# exception: None
#
# 14:13:21 job_callback for (0, 0, 3) started
# 14:13:21 DISPATCHER: Trying to submit another job.
# 14:13:21 job_callback for (0, 0, 3) got condition
# 14:13:21 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 14:13:21 Only 4 run(s) for budget 1.000000 available, need more than 9 -> can't build model!
# 14:13:21 HBMASTER: Trying to run another job!
# 14:13:21 job_callback for (0, 0, 3) finished
# 14:13:21 start sampling a new configuration.
# 14:13:21 done sampling a new configuration.
# 14:13:21 HBMASTER: schedule new run for iteration 0
# 14:13:21 HBMASTER: trying submitting job (0, 0, 4) to dispatcher
# 14:13:21 HBMASTER: submitting job (0, 0, 4) to dispatcher
# 14:13:21 DISPATCHER: trying to submit job (0, 0, 4)
# 14:13:21 DISPATCHER: trying to notify the job_runner thread.
# 14:13:21 HBMASTER: job (0, 0, 4) submitted to dispatcher
# 14:13:21 DISPATCHER: Trying to submit another job.
# 14:13:21 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 14:13:21 DISPATCHER: starting job (0, 0, 4) on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:13:21 DISPATCHER: job (0, 0, 4) dispatched on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:13:21 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 14:13:21 WORKER: start processing job (0, 0, 4)
# 14:13:21 WORKER: args: ()
# 14:13:21 WORKER: kwargs: {'config': {'lr': 0.0012325042423770019, 'num_conv_layers': 3, 'num_filters_1': 12, 'optim': 'SGD', 'momentum': 0.7081234493188815, 'num_filters_2': 7, 'num_filters_3': 11}, 'budget': 1.0, 'working_directory': '.'}
# 14:13:29 WORKER: done with job (0, 0, 4), trying to register it.
# 14:13:29 WORKER: registered result for job (0, 0, 4) with dispatcher
# 14:13:29 DISPATCHER: job (0, 0, 4) finished
# 14:13:29 DISPATCHER: register_result: lock acquired
# 14:13:29 DISPATCHER: job (0, 0, 4) on hpbandster.run_bohb_run_1.worker.MSI.1170820484 finished
# 14:13:29 job_id: (0, 0, 4)
# kwargs: {'config': {'lr': 0.0012325042423770019, 'num_conv_layers': 3, 'num_filters_1': 12, 'optim': 'SGD', 'momentum': 0.7081234493188815, 'num_filters_2': 7, 'num_filters_3': 11}, 'budget': 1.0, 'working_directory': '.'}
# result: {'loss': 0.890625, 'info': {'test_accuracy': 0.101, 'train_accuracy': 0.09765625, 'valid_accuracy': 0.109375, 'model': 'Sequential(\n  (conv1): Conv2d(1, 12, kernel_size=(3, 3), stride=(1, 1))\n  (rel1): ReLU()\n  (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv2): Conv2d(12, 7, kernel_size=(3, 3), stride=(1, 1))\n  (rel2): ReLU()\n  (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv3): Conv2d(7, 11, kernel_size=(3, 3), stride=(1, 1))\n  (rel3): ReLU()\n  (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=11, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}}
# exception: None
#
# 14:13:29 job_callback for (0, 0, 4) started
# 14:13:29 DISPATCHER: Trying to submit another job.
# 14:13:29 job_callback for (0, 0, 4) got condition
# 14:13:29 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 14:13:29 Only 5 run(s) for budget 1.000000 available, need more than 9 -> can't build model!
# 14:13:29 HBMASTER: Trying to run another job!
# 14:13:29 job_callback for (0, 0, 4) finished
# 14:13:29 start sampling a new configuration.
# 14:13:29 done sampling a new configuration.
# 14:13:29 HBMASTER: schedule new run for iteration 0
# 14:13:29 HBMASTER: trying submitting job (0, 0, 5) to dispatcher
# 14:13:29 HBMASTER: submitting job (0, 0, 5) to dispatcher
# 14:13:29 DISPATCHER: trying to submit job (0, 0, 5)
# 14:13:29 DISPATCHER: trying to notify the job_runner thread.
# 14:13:29 HBMASTER: job (0, 0, 5) submitted to dispatcher
# 14:13:29 DISPATCHER: Trying to submit another job.
# 14:13:29 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 14:13:29 DISPATCHER: starting job (0, 0, 5) on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:13:29 DISPATCHER: job (0, 0, 5) dispatched on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:13:29 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 14:13:29 WORKER: start processing job (0, 0, 5)
# 14:13:29 WORKER: args: ()
# 14:13:29 WORKER: kwargs: {'config': {'lr': 0.00018022254905203627, 'num_conv_layers': 2, 'num_filters_1': 18, 'optim': 'SGD', 'momentum': 0.27813976484319924, 'num_filters_2': 31}, 'budget': 1.0, 'working_directory': '.'}
# 14:13:38 DISPATCHER: Starting worker discovery
# 14:13:38 DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# 14:13:38 DISPATCHER: Finished worker discovery
# 14:13:40 WORKER: done with job (0, 0, 5), trying to register it.
# 14:13:40 WORKER: registered result for job (0, 0, 5) with dispatcher
# 14:13:40 DISPATCHER: job (0, 0, 5) finished
# 14:13:40 DISPATCHER: register_result: lock acquired
# 14:13:40 DISPATCHER: job (0, 0, 5) on hpbandster.run_bohb_run_1.worker.MSI.1170820484 finished
# 14:13:40 job_id: (0, 0, 5)
# kwargs: {'config': {'lr': 0.00018022254905203627, 'num_conv_layers': 2, 'num_filters_1': 18, 'optim': 'SGD', 'momentum': 0.27813976484319924, 'num_filters_2': 31}, 'budget': 1.0, 'working_directory': '.'}
# result: {'loss': 0.88671875, 'info': {'test_accuracy': 0.1126, 'train_accuracy': 0.10107421875, 'valid_accuracy': 0.11328125, 'model': 'Sequential(\n  (conv1): Conv2d(1, 18, kernel_size=(3, 3), stride=(1, 1))\n  (rel1): ReLU()\n  (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv2): Conv2d(18, 31, kernel_size=(3, 3), stride=(1, 1))\n  (rel2): ReLU()\n  (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=775, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}}
# exception: None
#
# 14:13:40 job_callback for (0, 0, 5) started
# 14:13:40 DISPATCHER: Trying to submit another job.
# 14:13:40 job_callback for (0, 0, 5) got condition
# 14:13:40 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 14:13:40 Only 6 run(s) for budget 1.000000 available, need more than 9 -> can't build model!
# 14:13:40 HBMASTER: Trying to run another job!
# 14:13:40 job_callback for (0, 0, 5) finished
# 14:13:40 start sampling a new configuration.
# 14:13:40 done sampling a new configuration.
# 14:13:40 HBMASTER: schedule new run for iteration 0
# 14:13:40 HBMASTER: trying submitting job (0, 0, 6) to dispatcher
# 14:13:40 HBMASTER: submitting job (0, 0, 6) to dispatcher
# 14:13:40 DISPATCHER: trying to submit job (0, 0, 6)
# 14:13:40 DISPATCHER: trying to notify the job_runner thread.
# 14:13:40 HBMASTER: job (0, 0, 6) submitted to dispatcher
# 14:13:40 DISPATCHER: Trying to submit another job.
# 14:13:40 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 14:13:40 DISPATCHER: starting job (0, 0, 6) on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:13:40 DISPATCHER: job (0, 0, 6) dispatched on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:13:40 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 14:13:40 WORKER: start processing job (0, 0, 6)
# 14:13:40 WORKER: args: ()
# 14:13:40 WORKER: kwargs: {'config': {'lr': 1.0270599484136482e-05, 'num_conv_layers': 3, 'num_filters_1': 6, 'optim': 'Adam', 'num_filters_2': 8, 'num_filters_3': 22}, 'budget': 1.0, 'working_directory': '.'}
# 14:13:46 WORKER: done with job (0, 0, 6), trying to register it.
# 14:13:46 WORKER: registered result for job (0, 0, 6) with dispatcher
# 14:13:46 DISPATCHER: job (0, 0, 6) finished
# 14:13:46 DISPATCHER: register_result: lock acquired
# 14:13:46 DISPATCHER: job (0, 0, 6) on hpbandster.run_bohb_run_1.worker.MSI.1170820484 finished
# 14:13:46 job_id: (0, 0, 6)
# kwargs: {'config': {'lr': 1.0270599484136482e-05, 'num_conv_layers': 3, 'num_filters_1': 6, 'optim': 'Adam', 'num_filters_2': 8, 'num_filters_3': 22}, 'budget': 1.0, 'working_directory': '.'}
# result: {'loss': 0.908203125, 'info': {'test_accuracy': 0.0958, 'train_accuracy': 0.101318359375, 'valid_accuracy': 0.091796875, 'model': 'Sequential(\n  (conv1): Conv2d(1, 6, kernel_size=(3, 3), stride=(1, 1))\n  (rel1): ReLU()\n  (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv2): Conv2d(6, 8, kernel_size=(3, 3), stride=(1, 1))\n  (rel2): ReLU()\n  (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv3): Conv2d(8, 22, kernel_size=(3, 3), stride=(1, 1))\n  (rel3): ReLU()\n  (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=22, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}}
# exception: None
#
# 14:13:46 job_callback for (0, 0, 6) started
# 14:13:46 DISPATCHER: Trying to submit another job.
# 14:13:46 job_callback for (0, 0, 6) got condition
# 14:13:46 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 14:13:46 Only 7 run(s) for budget 1.000000 available, need more than 9 -> can't build model!
# 14:13:46 HBMASTER: Trying to run another job!
# 14:13:46 job_callback for (0, 0, 6) finished
# 14:13:46 start sampling a new configuration.
# 14:13:46 done sampling a new configuration.
# 14:13:46 HBMASTER: schedule new run for iteration 0
# 14:13:46 HBMASTER: trying submitting job (0, 0, 7) to dispatcher
# 14:13:46 HBMASTER: submitting job (0, 0, 7) to dispatcher
# 14:13:46 DISPATCHER: trying to submit job (0, 0, 7)
# 14:13:46 DISPATCHER: trying to notify the job_runner thread.
# 14:13:46 HBMASTER: job (0, 0, 7) submitted to dispatcher
# 14:13:46 DISPATCHER: Trying to submit another job.
# 14:13:46 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 14:13:46 DISPATCHER: starting job (0, 0, 7) on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:13:46 DISPATCHER: job (0, 0, 7) dispatched on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:13:46 WORKER: start processing job (0, 0, 7)
# 14:13:46 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 14:13:46 WORKER: args: ()
# 14:13:46 WORKER: kwargs: {'config': {'lr': 3.695183541022445e-05, 'num_conv_layers': 1, 'num_filters_1': 23, 'optim': 'Adam'}, 'budget': 1.0, 'working_directory': '.'}
# 14:13:55 WORKER: done with job (0, 0, 7), trying to register it.
# 14:13:55 WORKER: registered result for job (0, 0, 7) with dispatcher
# 14:13:55 DISPATCHER: job (0, 0, 7) finished
# 14:13:55 DISPATCHER: register_result: lock acquired
# 14:13:55 DISPATCHER: job (0, 0, 7) on hpbandster.run_bohb_run_1.worker.MSI.1170820484 finished
# 14:13:55 job_id: (0, 0, 7)
# kwargs: {'config': {'lr': 3.695183541022445e-05, 'num_conv_layers': 1, 'num_filters_1': 23, 'optim': 'Adam'}, 'budget': 1.0, 'working_directory': '.'}
# result: {'loss': 0.294921875, 'info': {'test_accuracy': 0.6736, 'train_accuracy': 0.677490234375, 'valid_accuracy': 0.705078125, 'model': 'Sequential(\n  (conv1): Conv2d(1, 23, kernel_size=(3, 3), stride=(1, 1))\n  (rel1): ReLU()\n  (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=3887, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}}
# exception: None
#
# 14:13:55 job_callback for (0, 0, 7) started
# 14:13:55 DISPATCHER: Trying to submit another job.
# 14:13:55 job_callback for (0, 0, 7) got condition
# 14:13:55 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 14:13:55 HBMASTER: Trying to run another job!
# 14:13:55 job_callback for (0, 0, 7) finished
# 14:13:55 start sampling a new configuration.
# 14:13:55 done sampling a new configuration.
# 14:13:55 HBMASTER: schedule new run for iteration 0
# 14:13:55 HBMASTER: trying submitting job (0, 0, 8) to dispatcher
# 14:13:55 HBMASTER: submitting job (0, 0, 8) to dispatcher
# 14:13:55 DISPATCHER: trying to submit job (0, 0, 8)
# 14:13:55 DISPATCHER: trying to notify the job_runner thread.
# 14:13:55 HBMASTER: job (0, 0, 8) submitted to dispatcher
# 14:13:55 DISPATCHER: Trying to submit another job.
# 14:13:55 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 14:13:55 DISPATCHER: starting job (0, 0, 8) on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:13:55 DISPATCHER: job (0, 0, 8) dispatched on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:13:55 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 14:13:55 WORKER: start processing job (0, 0, 8)
# 14:13:55 WORKER: args: ()
# 14:13:55 WORKER: kwargs: {'config': {'lr': 0.0001403605686257867, 'num_conv_layers': 3, 'num_filters_1': 32, 'optim': 'SGD', 'momentum': 0.25449928162858954, 'num_filters_2': 16, 'num_filters_3': 27}, 'budget': 1.0, 'working_directory': '.'}
# 14:14:10 WORKER: done with job (0, 0, 8), trying to register it.
# 14:14:10 WORKER: registered result for job (0, 0, 8) with dispatcher
# 14:14:10 DISPATCHER: job (0, 0, 8) finished
# 14:14:10 DISPATCHER: register_result: lock acquired
# 14:14:10 DISPATCHER: job (0, 0, 8) on hpbandster.run_bohb_run_1.worker.MSI.1170820484 finished
# 14:14:10 job_id: (0, 0, 8)
# kwargs: {'config': {'lr': 0.0001403605686257867, 'num_conv_layers': 3, 'num_filters_1': 32, 'optim': 'SGD', 'momentum': 0.25449928162858954, 'num_filters_2': 16, 'num_filters_3': 27}, 'budget': 1.0, 'working_directory': '.'}
# result: {'loss': 0.921875, 'info': {'test_accuracy': 0.0712, 'train_accuracy': 0.0771484375, 'valid_accuracy': 0.078125, 'model': 'Sequential(\n  (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))\n  (rel1): ReLU()\n  (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv2): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1))\n  (rel2): ReLU()\n  (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv3): Conv2d(16, 27, kernel_size=(3, 3), stride=(1, 1))\n  (rel3): ReLU()\n  (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=27, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}}
# exception: None
#
# 14:14:10 job_callback for (0, 0, 8) started
# 14:14:10 DISPATCHER: Trying to submit another job.
# 14:14:10 job_callback for (0, 0, 8) got condition
# 14:14:10 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 14:14:10 HBMASTER: Trying to run another job!
# 14:14:10 job_callback for (0, 0, 8) finished
# 14:14:10 ITERATION: Advancing config (0, 0, 1) to next budget 3.000000
# 14:14:10 ITERATION: Advancing config (0, 0, 3) to next budget 3.000000
# 14:14:10 ITERATION: Advancing config (0, 0, 7) to next budget 3.000000
# 14:14:10 HBMASTER: schedule new run for iteration 0
# 14:14:10 HBMASTER: trying submitting job (0, 0, 1) to dispatcher
# 14:14:10 HBMASTER: submitting job (0, 0, 1) to dispatcher
# 14:14:10 DISPATCHER: trying to submit job (0, 0, 1)
# 14:14:10 DISPATCHER: trying to notify the job_runner thread.
# 14:14:10 HBMASTER: job (0, 0, 1) submitted to dispatcher
# 14:14:10 DISPATCHER: Trying to submit another job.
# 14:14:10 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 14:14:10 DISPATCHER: starting job (0, 0, 1) on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:14:10 DISPATCHER: job (0, 0, 1) dispatched on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:14:10 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 14:14:10 WORKER: start processing job (0, 0, 1)
# 14:14:10 WORKER: args: ()
# 14:14:10 WORKER: kwargs: {'config': {'lr': 0.003656404685600867, 'num_conv_layers': 2, 'num_filters_1': 6, 'optim': 'SGD', 'momentum': 0.534373246126249, 'num_filters_2': 8}, 'budget': 3.0, 'working_directory': '.'}
# 14:14:20 WORKER: done with job (0, 0, 1), trying to register it.
# 14:14:20 WORKER: registered result for job (0, 0, 1) with dispatcher
# 14:14:20 DISPATCHER: job (0, 0, 1) finished
# 14:14:20 DISPATCHER: register_result: lock acquired
# 14:14:20 DISPATCHER: job (0, 0, 1) on hpbandster.run_bohb_run_1.worker.MSI.1170820484 finished
# 14:14:20 job_id: (0, 0, 1)
# kwargs: {'config': {'lr': 0.003656404685600867, 'num_conv_layers': 2, 'num_filters_1': 6, 'optim': 'SGD', 'momentum': 0.534373246126249, 'num_filters_2': 8}, 'budget': 3.0, 'working_directory': '.'}
# result: {'loss': 0.25390625, 'info': {'test_accuracy': 0.7368, 'train_accuracy': 0.7392578125, 'valid_accuracy': 0.74609375, 'model': 'Sequential(\n  (conv1): Conv2d(1, 6, kernel_size=(3, 3), stride=(1, 1))\n  (rel1): ReLU()\n  (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv2): Conv2d(6, 8, kernel_size=(3, 3), stride=(1, 1))\n  (rel2): ReLU()\n  (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=200, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}}
# exception: None
#
# 14:14:20 job_callback for (0, 0, 1) started
# 14:14:20 DISPATCHER: Trying to submit another job.
# 14:14:20 job_callback for (0, 0, 1) got condition
# 14:14:20 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 14:14:20 Only 1 run(s) for budget 3.000000 available, need more than 9 -> can't build model!
# 14:14:20 HBMASTER: Trying to run another job!
# 14:14:20 job_callback for (0, 0, 1) finished
# 14:14:20 HBMASTER: schedule new run for iteration 0
# 14:14:20 HBMASTER: trying submitting job (0, 0, 3) to dispatcher
# 14:14:20 HBMASTER: submitting job (0, 0, 3) to dispatcher
# 14:14:20 DISPATCHER: trying to submit job (0, 0, 3)
# 14:14:20 DISPATCHER: trying to notify the job_runner thread.
# 14:14:20 HBMASTER: job (0, 0, 3) submitted to dispatcher
# 14:14:20 DISPATCHER: Trying to submit another job.
# 14:14:20 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 14:14:20 DISPATCHER: starting job (0, 0, 3) on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:14:20 DISPATCHER: job (0, 0, 3) dispatched on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:14:20 WORKER: start processing job (0, 0, 3)
# 14:14:20 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 14:14:20 WORKER: args: ()
# 14:14:20 WORKER: kwargs: {'config': {'lr': 0.00024278009979006987, 'num_conv_layers': 3, 'num_filters_1': 29, 'optim': 'Adam', 'num_filters_2': 13, 'num_filters_3': 21}, 'budget': 3.0, 'working_directory': '.'}
# 14:14:38 DISPATCHER: Starting worker discovery
# 14:14:38 DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# 14:14:38 DISPATCHER: Finished worker discovery
# 14:14:44 WORKER: done with job (0, 0, 3), trying to register it.
# 14:14:44 WORKER: registered result for job (0, 0, 3) with dispatcher
# 14:14:44 DISPATCHER: job (0, 0, 3) finished
# 14:14:44 DISPATCHER: register_result: lock acquired
# 14:14:44 DISPATCHER: job (0, 0, 3) on hpbandster.run_bohb_run_1.worker.MSI.1170820484 finished
# 14:14:44 job_id: (0, 0, 3)
# kwargs: {'config': {'lr': 0.00024278009979006987, 'num_conv_layers': 3, 'num_filters_1': 29, 'optim': 'Adam', 'num_filters_2': 13, 'num_filters_3': 21}, 'budget': 3.0, 'working_directory': '.'}
# result: {'loss': 0.212890625, 'info': {'test_accuracy': 0.754, 'train_accuracy': 0.767822265625, 'valid_accuracy': 0.787109375, 'model': 'Sequential(\n  (conv1): Conv2d(1, 29, kernel_size=(3, 3), stride=(1, 1))\n  (rel1): ReLU()\n  (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv2): Conv2d(29, 13, kernel_size=(3, 3), stride=(1, 1))\n  (rel2): ReLU()\n  (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv3): Conv2d(13, 21, kernel_size=(3, 3), stride=(1, 1))\n  (rel3): ReLU()\n  (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=21, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}}
# exception: None
#
# 14:14:44 job_callback for (0, 0, 3) started
# 14:14:44 DISPATCHER: Trying to submit another job.
# 14:14:44 job_callback for (0, 0, 3) got condition
# 14:14:44 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 14:14:44 Only 2 run(s) for budget 3.000000 available, need more than 9 -> can't build model!
# 14:14:44 HBMASTER: Trying to run another job!
# 14:14:44 job_callback for (0, 0, 3) finished
# 14:14:44 HBMASTER: schedule new run for iteration 0
# 14:14:44 HBMASTER: trying submitting job (0, 0, 7) to dispatcher
# 14:14:44 HBMASTER: submitting job (0, 0, 7) to dispatcher
# 14:14:44 DISPATCHER: trying to submit job (0, 0, 7)
# 14:14:44 DISPATCHER: trying to notify the job_runner thread.
# 14:14:44 HBMASTER: job (0, 0, 7) submitted to dispatcher
# 14:14:44 DISPATCHER: Trying to submit another job.
# 14:14:44 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 14:14:44 DISPATCHER: starting job (0, 0, 7) on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:14:44 DISPATCHER: job (0, 0, 7) dispatched on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:14:44 WORKER: start processing job (0, 0, 7)
# 14:14:44 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 14:14:44 WORKER: args: ()
# 14:14:44 WORKER: kwargs: {'config': {'lr': 3.695183541022445e-05, 'num_conv_layers': 1, 'num_filters_1': 23, 'optim': 'Adam'}, 'budget': 3.0, 'working_directory': '.'}
# 14:14:59 WORKER: done with job (0, 0, 7), trying to register it.
# 14:14:59 WORKER: registered result for job (0, 0, 7) with dispatcher
# 14:14:59 DISPATCHER: job (0, 0, 7) finished
# 14:14:59 DISPATCHER: register_result: lock acquired
# 14:14:59 DISPATCHER: job (0, 0, 7) on hpbandster.run_bohb_run_1.worker.MSI.1170820484 finished
# 14:14:59 job_id: (0, 0, 7)
# kwargs: {'config': {'lr': 3.695183541022445e-05, 'num_conv_layers': 1, 'num_filters_1': 23, 'optim': 'Adam'}, 'budget': 3.0, 'working_directory': '.'}
# result: {'loss': 0.17578125, 'info': {'test_accuracy': 0.7979, 'train_accuracy': 0.79931640625, 'valid_accuracy': 0.82421875, 'model': 'Sequential(\n  (conv1): Conv2d(1, 23, kernel_size=(3, 3), stride=(1, 1))\n  (rel1): ReLU()\n  (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=3887, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}}
# exception: None
#
# 14:14:59 job_callback for (0, 0, 7) started
# 14:14:59 DISPATCHER: Trying to submit another job.
# 14:14:59 job_callback for (0, 0, 7) got condition
# 14:14:59 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 14:14:59 Only 3 run(s) for budget 3.000000 available, need more than 9 -> can't build model!
# 14:14:59 HBMASTER: Trying to run another job!
# 14:14:59 job_callback for (0, 0, 7) finished
# 14:14:59 ITERATION: Advancing config (0, 0, 7) to next budget 9.000000
# 14:14:59 HBMASTER: schedule new run for iteration 0
# 14:14:59 HBMASTER: trying submitting job (0, 0, 7) to dispatcher
# 14:14:59 HBMASTER: submitting job (0, 0, 7) to dispatcher
# 14:14:59 DISPATCHER: trying to submit job (0, 0, 7)
# 14:14:59 DISPATCHER: trying to notify the job_runner thread.
# 14:14:59 HBMASTER: job (0, 0, 7) submitted to dispatcher
# 14:14:59 DISPATCHER: Trying to submit another job.
# 14:14:59 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 14:14:59 DISPATCHER: starting job (0, 0, 7) on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:14:59 DISPATCHER: job (0, 0, 7) dispatched on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:14:59 WORKER: start processing job (0, 0, 7)
# 14:14:59 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 14:14:59 WORKER: args: ()
# 14:14:59 WORKER: kwargs: {'config': {'lr': 3.695183541022445e-05, 'num_conv_layers': 1, 'num_filters_1': 23, 'optim': 'Adam'}, 'budget': 9.0, 'working_directory': '.'}
# 14:15:31 WORKER: done with job (0, 0, 7), trying to register it.
# 14:15:31 WORKER: registered result for job (0, 0, 7) with dispatcher
# 14:15:31 DISPATCHER: job (0, 0, 7) finished
# 14:15:31 DISPATCHER: register_result: lock acquired
# 14:15:31 DISPATCHER: job (0, 0, 7) on hpbandster.run_bohb_run_1.worker.MSI.1170820484 finished
# 14:15:31 job_id: (0, 0, 7)
# kwargs: {'config': {'lr': 3.695183541022445e-05, 'num_conv_layers': 1, 'num_filters_1': 23, 'optim': 'Adam'}, 'budget': 9.0, 'working_directory': '.'}
# result: {'loss': 0.126953125, 'info': {'test_accuracy': 0.8619, 'train_accuracy': 0.867919921875, 'valid_accuracy': 0.873046875, 'model': 'Sequential(\n  (conv1): Conv2d(1, 23, kernel_size=(3, 3), stride=(1, 1))\n  (rel1): ReLU()\n  (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=3887, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}}
# exception: None
#
# 14:15:31 job_callback for (0, 0, 7) started
# 14:15:31 DISPATCHER: Trying to submit another job.
# 14:15:31 job_callback for (0, 0, 7) got condition
# 14:15:31 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 14:15:31 Only 1 run(s) for budget 9.000000 available, need more than 9 -> can't build model!
# 14:15:31 HBMASTER: Trying to run another job!
# 14:15:31 job_callback for (0, 0, 7) finished
# 14:15:31 start sampling a new configuration.
# 14:15:31 done sampling a new configuration.
# 14:15:31 HBMASTER: schedule new run for iteration 1
# 14:15:31 HBMASTER: trying submitting job (1, 0, 0) to dispatcher
# 14:15:31 HBMASTER: submitting job (1, 0, 0) to dispatcher
# 14:15:31 DISPATCHER: trying to submit job (1, 0, 0)
# 14:15:31 DISPATCHER: trying to notify the job_runner thread.
# 14:15:31 HBMASTER: job (1, 0, 0) submitted to dispatcher
# 14:15:31 DISPATCHER: Trying to submit another job.
# 14:15:31 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 14:15:32 DISPATCHER: starting job (1, 0, 0) on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:15:32 DISPATCHER: job (1, 0, 0) dispatched on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:15:32 WORKER: start processing job (1, 0, 0)
# 14:15:32 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 14:15:32 WORKER: args: ()
# 14:15:32 WORKER: kwargs: {'config': {'lr': 0.0002935080817448183, 'num_conv_layers': 2, 'num_filters_1': 25, 'optim': 'SGD', 'momentum': 0.10909118292006122, 'num_filters_2': 8}, 'budget': 3.0, 'working_directory': '.'}
# 14:15:38 DISPATCHER: Starting worker discovery
# 14:15:38 DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# 14:15:38 DISPATCHER: Finished worker discovery
# 14:15:51 WORKER: done with job (1, 0, 0), trying to register it.
# 14:15:51 WORKER: registered result for job (1, 0, 0) with dispatcher
# 14:15:51 DISPATCHER: job (1, 0, 0) finished
# 14:15:51 DISPATCHER: register_result: lock acquired
# 14:15:51 DISPATCHER: job (1, 0, 0) on hpbandster.run_bohb_run_1.worker.MSI.1170820484 finished
# 14:15:51 job_id: (1, 0, 0)
# kwargs: {'config': {'lr': 0.0002935080817448183, 'num_conv_layers': 2, 'num_filters_1': 25, 'optim': 'SGD', 'momentum': 0.10909118292006122, 'num_filters_2': 8}, 'budget': 3.0, 'working_directory': '.'}
# result: {'loss': 0.8828125, 'info': {'test_accuracy': 0.1128, 'train_accuracy': 0.1103515625, 'valid_accuracy': 0.1171875, 'model': 'Sequential(\n  (conv1): Conv2d(1, 25, kernel_size=(3, 3), stride=(1, 1))\n  (rel1): ReLU()\n  (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv2): Conv2d(25, 8, kernel_size=(3, 3), stride=(1, 1))\n  (rel2): ReLU()\n  (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=200, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}}
# exception: None
#
# 14:15:51 job_callback for (1, 0, 0) started
# 14:15:51 DISPATCHER: Trying to submit another job.
# 14:15:51 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 14:15:51 job_callback for (1, 0, 0) got condition
# 14:15:51 Only 4 run(s) for budget 3.000000 available, need more than 9 -> can't build model!
# 14:15:51 HBMASTER: Trying to run another job!
# 14:15:51 job_callback for (1, 0, 0) finished
# 14:15:51 start sampling a new configuration.
# 14:15:51 done sampling a new configuration.
# 14:15:51 HBMASTER: schedule new run for iteration 1
# 14:15:51 HBMASTER: trying submitting job (1, 0, 1) to dispatcher
# 14:15:51 HBMASTER: submitting job (1, 0, 1) to dispatcher
# 14:15:51 DISPATCHER: trying to submit job (1, 0, 1)
# 14:15:51 DISPATCHER: trying to notify the job_runner thread.
# 14:15:51 HBMASTER: job (1, 0, 1) submitted to dispatcher
# 14:15:51 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 14:15:51 DISPATCHER: Trying to submit another job.
# 14:15:51 DISPATCHER: starting job (1, 0, 1) on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:15:51 DISPATCHER: job (1, 0, 1) dispatched on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:15:51 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 14:15:51 WORKER: start processing job (1, 0, 1)
# 14:15:51 WORKER: args: ()
# 14:15:51 WORKER: kwargs: {'config': {'lr': 7.306964041183663e-05, 'num_conv_layers': 2, 'num_filters_1': 11, 'optim': 'Adam', 'num_filters_2': 31}, 'budget': 3.0, 'working_directory': '.'}
# 14:16:06 WORKER: done with job (1, 0, 1), trying to register it.
# 14:16:06 WORKER: registered result for job (1, 0, 1) with dispatcher
# 14:16:06 DISPATCHER: job (1, 0, 1) finished
# 14:16:06 DISPATCHER: register_result: lock acquired
# 14:16:06 DISPATCHER: job (1, 0, 1) on hpbandster.run_bohb_run_1.worker.MSI.1170820484 finished
# 14:16:06 job_id: (1, 0, 1)
# kwargs: {'config': {'lr': 7.306964041183663e-05, 'num_conv_layers': 2, 'num_filters_1': 11, 'optim': 'Adam', 'num_filters_2': 31}, 'budget': 3.0, 'working_directory': '.'}
# result: {'loss': 0.19921875, 'info': {'test_accuracy': 0.7701, 'train_accuracy': 0.77099609375, 'valid_accuracy': 0.80078125, 'model': 'Sequential(\n  (conv1): Conv2d(1, 11, kernel_size=(3, 3), stride=(1, 1))\n  (rel1): ReLU()\n  (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv2): Conv2d(11, 31, kernel_size=(3, 3), stride=(1, 1))\n  (rel2): ReLU()\n  (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=775, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}}
# exception: None
# 14:16:06 job_callback for (1, 0, 1) started
# 14:16:06 DISPATCHER: Trying to submit another job.
# 14:16:06 job_callback for (1, 0, 1) got condition
# 14:16:06 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 14:16:06 Only 5 run(s) for budget 3.000000 available, need more than 9 -> can't build model!
# 14:16:06 HBMASTER: Trying to run another job!
# 14:16:06 job_callback for (1, 0, 1) finished
# 14:16:06 start sampling a new configuration.
# 14:16:06 done sampling a new configuration.
# 14:16:06 HBMASTER: schedule new run for iteration 1
# 14:16:06 HBMASTER: trying submitting job (1, 0, 2) to dispatcher
# 14:16:06 HBMASTER: submitting job (1, 0, 2) to dispatcher
# 14:16:06 DISPATCHER: trying to submit job (1, 0, 2)
# 14:16:06 DISPATCHER: trying to notify the job_runner thread.
# 14:16:06 HBMASTER: job (1, 0, 2) submitted to dispatcher
# 14:16:06 DISPATCHER: Trying to submit another job.
# 14:16:06 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 14:16:06 DISPATCHER: starting job (1, 0, 2) on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:16:06 DISPATCHER: job (1, 0, 2) dispatched on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:16:06 WORKER: start processing job (1, 0, 2)
# 14:16:06 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 14:16:06 WORKER: args: ()
# 14:16:06 WORKER: kwargs: {'config': {'lr': 0.0025786594541727867, 'num_conv_layers': 1, 'num_filters_1': 19, 'optim': 'Adam'}, 'budget': 3.0, 'working_directory': '.'}
# 14:16:19 WORKER: done with job (1, 0, 2), trying to register it.
# 14:16:19 WORKER: registered result for job (1, 0, 2) with dispatcher
# 14:16:19 DISPATCHER: job (1, 0, 2) finished
# 14:16:19 DISPATCHER: register_result: lock acquired
# 14:16:19 DISPATCHER: job (1, 0, 2) on hpbandster.run_bohb_run_1.worker.MSI.1170820484 finished
# 14:16:19 job_id: (1, 0, 2)
# kwargs: {'config': {'lr': 0.0025786594541727867, 'num_conv_layers': 1, 'num_filters_1': 19, 'optim': 'Adam'}, 'budget': 3.0, 'working_directory': '.'}
# result: {'loss': 0.0625, 'info': {'test_accuracy': 0.9251, 'train_accuracy': 0.957275390625, 'valid_accuracy': 0.9375, 'model': 'Sequential(\n  (conv1): Conv2d(1, 19, kernel_size=(3, 3), stride=(1, 1))\n  (rel1): ReLU()\n  (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=3211, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}}
# exception: None
#
# 14:16:19 job_callback for (1, 0, 2) started
# 14:16:19 DISPATCHER: Trying to submit another job.
# 14:16:19 job_callback for (1, 0, 2) got condition
# 14:16:19 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 14:16:19 Only 6 run(s) for budget 3.000000 available, need more than 9 -> can't build model!
# 14:16:19 HBMASTER: Trying to run another job!
# 14:16:19 job_callback for (1, 0, 2) finished
# 14:16:19 ITERATION: Advancing config (1, 0, 2) to next budget 9.000000
# 14:16:19 HBMASTER: schedule new run for iteration 1
# 14:16:19 HBMASTER: trying submitting job (1, 0, 2) to dispatcher
# 14:16:19 HBMASTER: submitting job (1, 0, 2) to dispatcher
# 14:16:19 DISPATCHER: trying to submit job (1, 0, 2)
# 14:16:19 DISPATCHER: trying to notify the job_runner thread.
# 14:16:19 HBMASTER: job (1, 0, 2) submitted to dispatcher
# 14:16:19 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 14:16:19 DISPATCHER: Trying to submit another job.
# 14:16:19 DISPATCHER: starting job (1, 0, 2) on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:16:19 DISPATCHER: job (1, 0, 2) dispatched on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:16:19 WORKER: start processing job (1, 0, 2)
# 14:16:19 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 14:16:19 WORKER: args: ()
# 14:16:19 WORKER: kwargs: {'config': {'lr': 0.0025786594541727867, 'num_conv_layers': 1, 'num_filters_1': 19, 'optim': 'Adam'}, 'budget': 9.0, 'working_directory': '.'}
# 14:16:38 DISPATCHER: Starting worker discovery
# 14:16:38 DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# 14:16:38 DISPATCHER: Finished worker discovery
# 14:16:49 WORKER: done with job (1, 0, 2), trying to register it.
# 14:16:49 WORKER: registered result for job (1, 0, 2) with dispatcher
# 14:16:49 DISPATCHER: job (1, 0, 2) finished
# 14:16:49 DISPATCHER: register_result: lock acquired
# 14:16:49 DISPATCHER: job (1, 0, 2) on hpbandster.run_bohb_run_1.worker.MSI.1170820484 finished
# 14:16:49 job_id: (1, 0, 2)
# kwargs: {'config': {'lr': 0.0025786594541727867, 'num_conv_layers': 1, 'num_filters_1': 19, 'optim': 'Adam'}, 'budget': 9.0, 'working_directory': '.'}
# result: {'loss': 0.044921875, 'info': {'test_accuracy': 0.956, 'train_accuracy': 0.998046875, 'valid_accuracy': 0.955078125, 'model': 'Sequential(\n  (conv1): Conv2d(1, 19, kernel_size=(3, 3), stride=(1, 1))\n  (rel1): ReLU()\n  (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=3211, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}}
# exception: None
#
# 14:16:50 job_callback for (1, 0, 2) started
# 14:16:50 DISPATCHER: Trying to submit another job.
# 14:16:50 job_callback for (1, 0, 2) got condition
# 14:16:50 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 14:16:50 Only 2 run(s) for budget 9.000000 available, need more than 9 -> can't build model!
# 14:16:50 HBMASTER: Trying to run another job!
# 14:16:50 job_callback for (1, 0, 2) finished
# 14:16:50 start sampling a new configuration.
# 14:16:50 done sampling a new configuration.
# 14:16:50 HBMASTER: schedule new run for iteration 2
# 14:16:50 HBMASTER: trying submitting job (2, 0, 0) to dispatcher
# 14:16:50 HBMASTER: submitting job (2, 0, 0) to dispatcher
# 14:16:50 DISPATCHER: trying to submit job (2, 0, 0)
# 14:16:50 DISPATCHER: trying to notify the job_runner thread.
# 14:16:50 HBMASTER: job (2, 0, 0) submitted to dispatcher
# 14:16:50 DISPATCHER: Trying to submit another job.
# 14:16:50 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 14:16:50 DISPATCHER: starting job (2, 0, 0) on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:16:50 DISPATCHER: job (2, 0, 0) dispatched on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:16:50 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# ...
# 14:33:38 DISPATCHER: Starting worker discovery
# 14:33:38 DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# 14:33:38 DISPATCHER: Finished worker discovery
# 14:34:03 WORKER: done with job (10, 0, 1), trying to register it.
# 14:34:03 WORKER: registered result for job (10, 0, 1) with dispatcher
# 14:34:03 DISPATCHER: job (10, 0, 1) finished
# 14:34:03 DISPATCHER: register_result: lock acquired
# 14:34:03 DISPATCHER: job (10, 0, 1) on hpbandster.run_bohb_run_1.worker.MSI.1170820484 finished
# 14:34:03 job_id: (10, 0, 1)
# kwargs: {'config': {'lr': 7.056679160622249e-06, 'num_conv_layers': 3, 'num_filters_1': 29, 'optim': 'SGD', 'momentum': 0.6633882107900064, 'num_filters_2': 26, 'num_filters_3': 31}, 'budget': 3.0, 'working_directory': '.'}
# result: {'loss': 0.916015625, 'info': {'test_accuracy': 0.0976, 'train_accuracy': 0.09423828125, 'valid_accuracy': 0.083984375, 'model': 'Sequential(\n  (conv1): Conv2d(1, 29, kernel_size=(3, 3), stride=(1, 1))\n  (rel1): ReLU()\n  (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv2): Conv2d(29, 26, kernel_size=(3, 3), stride=(1, 1))\n  (rel2): ReLU()\n  (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv3): Conv2d(26, 31, kernel_size=(3, 3), stride=(1, 1))\n  (rel3): ReLU()\n  (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=31, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}}
# exception: None
#
# 14:34:03 job_callback for (10, 0, 1) started
# 14:34:03 DISPATCHER: Trying to submit another job.
# 14:34:03 job_callback for (10, 0, 1) got condition
# 14:34:03 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 14:34:03 HBMASTER: Trying to run another job!
# 14:34:03 job_callback for (10, 0, 1) finished
# 14:34:03 start sampling a new configuration.
# 14:34:03 best_vector: [0.7921884679687643, 0.0838903392588867, 0.8390917571592568, 0, 0.9492971871812239, 0.7740417740013719, 0.9362513210828319], 4.306841072622143e-34, 23.218873952810338, 0.0
# 14:34:03 done sampling a new configuration.
# 14:34:03 HBMASTER: schedule new run for iteration 10
# 14:34:03 HBMASTER: trying submitting job (10, 0, 2) to dispatcher
# 14:34:03 HBMASTER: submitting job (10, 0, 2) to dispatcher
# 14:34:03 DISPATCHER: trying to submit job (10, 0, 2)
# 14:34:03 DISPATCHER: trying to notify the job_runner thread.
# 14:34:03 HBMASTER: job (10, 0, 2) submitted to dispatcher
# 14:34:03 DISPATCHER: Trying to submit another job.
# 14:34:03 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 14:34:03 DISPATCHER: starting job (10, 0, 2) on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:34:03 DISPATCHER: job (10, 0, 2) dispatched on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:34:03 WORKER: start processing job (10, 0, 2)
# 14:34:03 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 14:34:03 WORKER: args: ()
# 14:34:03 WORKER: kwargs: {'config': {'lr': 0.009139918850734455, 'num_conv_layers': 1, 'num_filters_1': 28, 'optim': 'Adam'}, 'budget': 3.0, 'working_directory': '.'}
# 14:34:21 WORKER: done with job (10, 0, 2), trying to register it.
# 14:34:21 WORKER: registered result for job (10, 0, 2) with dispatcher
# 14:34:21 DISPATCHER: job (10, 0, 2) finished
# 14:34:21 DISPATCHER: register_result: lock acquired
# 14:34:21 DISPATCHER: job (10, 0, 2) on hpbandster.run_bohb_run_1.worker.MSI.1170820484 finished
# 14:34:21 job_id: (10, 0, 2)
# kwargs: {'config': {'lr': 0.009139918850734455, 'num_conv_layers': 1, 'num_filters_1': 28, 'optim': 'Adam'}, 'budget': 3.0, 'working_directory': '.'}
# result: {'loss': 0.046875, 'info': {'test_accuracy': 0.9564, 'train_accuracy': 0.99365234375, 'valid_accuracy': 0.953125, 'model': 'Sequential(\n  (conv1): Conv2d(1, 28, kernel_size=(3, 3), stride=(1, 1))\n  (rel1): ReLU()\n  (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=4732, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}}
# exception: None
#
# 14:34:21 job_callback for (10, 0, 2) started
# 14:34:21 DISPATCHER: Trying to submit another job.
# 14:34:21 job_callback for (10, 0, 2) got condition
# 14:34:21 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 14:34:21 HBMASTER: Trying to run another job!
# 14:34:21 job_callback for (10, 0, 2) finished
# 14:34:21 ITERATION: Advancing config (10, 0, 2) to next budget 9.000000
# 14:34:21 HBMASTER: schedule new run for iteration 10
# 14:34:21 HBMASTER: trying submitting job (10, 0, 2) to dispatcher
# 14:34:21 HBMASTER: submitting job (10, 0, 2) to dispatcher
# 14:34:21 DISPATCHER: trying to submit job (10, 0, 2)
# 14:34:21 DISPATCHER: trying to notify the job_runner thread.
# 14:34:21 HBMASTER: job (10, 0, 2) submitted to dispatcher
# 14:34:21 DISPATCHER: Trying to submit another job.
# 14:34:21 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 14:34:21 DISPATCHER: starting job (10, 0, 2) on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:34:21 DISPATCHER: job (10, 0, 2) dispatched on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:34:21 WORKER: start processing job (10, 0, 2)
# 14:34:21 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 14:34:21 WORKER: args: ()
# 14:34:21 WORKER: kwargs: {'config': {'lr': 0.009139918850734455, 'num_conv_layers': 1, 'num_filters_1': 28, 'optim': 'Adam'}, 'budget': 9.0, 'working_directory': '.'}
# 14:34:38 DISPATCHER: Starting worker discovery
# 14:34:38 DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# 14:34:38 DISPATCHER: Finished worker discovery
# 14:35:00 WORKER: done with job (10, 0, 2), trying to register it.
# 14:35:00 WORKER: registered result for job (10, 0, 2) with dispatcher
# 14:35:00 DISPATCHER: job (10, 0, 2) finished
# 14:35:00 DISPATCHER: register_result: lock acquired
# 14:35:00 DISPATCHER: job (10, 0, 2) on hpbandster.run_bohb_run_1.worker.MSI.1170820484 finished
# 14:35:00 job_id: (10, 0, 2)
# kwargs: {'config': {'lr': 0.009139918850734455, 'num_conv_layers': 1, 'num_filters_1': 28, 'optim': 'Adam'}, 'budget': 9.0, 'working_directory': '.'}
# result: {'loss': 0.0390625, 'info': {'test_accuracy': 0.9635, 'train_accuracy': 1.0, 'valid_accuracy': 0.9609375, 'model': 'Sequential(\n  (conv1): Conv2d(1, 28, kernel_size=(3, 3), stride=(1, 1))\n  (rel1): ReLU()\n  (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=4732, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}}
# exception: None
#
# 14:35:00 job_callback for (10, 0, 2) started
# 14:35:00 DISPATCHER: Trying to submit another job.
# 14:35:00 job_callback for (10, 0, 2) got condition
# 14:35:00 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 14:35:00 done building a new model for budget 9.000000 based on 8/14 split
# Best loss for this budget:0.031250
#
#
#
#
#
# 14:35:00 HBMASTER: Trying to run another job!
# 14:35:00 job_callback for (10, 0, 2) finished
# 14:35:00 start sampling a new configuration.
# 14:35:00 done sampling a new configuration.
# 14:35:00 HBMASTER: schedule new run for iteration 11
# 14:35:00 HBMASTER: trying submitting job (11, 0, 0) to dispatcher
# 14:35:00 HBMASTER: submitting job (11, 0, 0) to dispatcher
# 14:35:00 DISPATCHER: trying to submit job (11, 0, 0)
# 14:35:00 DISPATCHER: trying to notify the job_runner thread.
# 14:35:00 HBMASTER: job (11, 0, 0) submitted to dispatcher
# 14:35:00 DISPATCHER: Trying to submit another job.
# 14:35:00 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 14:35:00 DISPATCHER: starting job (11, 0, 0) on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:35:00 DISPATCHER: job (11, 0, 0) dispatched on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:35:00 WORKER: start processing job (11, 0, 0)
# 14:35:00 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 14:35:00 WORKER: args: ()
# 14:35:00 WORKER: kwargs: {'config': {'lr': 1.0378617936481863e-05, 'num_conv_layers': 1, 'num_filters_1': 5, 'optim': 'Adam'}, 'budget': 9.0, 'working_directory': '.'}
# 14:35:16 WORKER: done with job (11, 0, 0), trying to register it.
# 14:35:16 WORKER: registered result for job (11, 0, 0) with dispatcher
# 14:35:16 DISPATCHER: job (11, 0, 0) finished
# 14:35:16 DISPATCHER: register_result: lock acquired
# 14:35:16 DISPATCHER: job (11, 0, 0) on hpbandster.run_bohb_run_1.worker.MSI.1170820484 finished
# 14:35:16 job_id: (11, 0, 0)
# kwargs: {'config': {'lr': 1.0378617936481863e-05, 'num_conv_layers': 1, 'num_filters_1': 5, 'optim': 'Adam'}, 'budget': 9.0, 'working_directory': '.'}
# result: {'loss': 0.359375, 'info': {'test_accuracy': 0.5943, 'train_accuracy': 0.605224609375, 'valid_accuracy': 0.640625, 'model': 'Sequential(\n  (conv1): Conv2d(1, 5, kernel_size=(3, 3), stride=(1, 1))\n  (rel1): ReLU()\n  (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=845, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}}
# exception: None
#
# 14:35:16 job_callback for (11, 0, 0) started
# 14:35:16 DISPATCHER: Trying to submit another job.
# 14:35:16 job_callback for (11, 0, 0) got condition
# 14:35:16 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 14:35:16 done building a new model for budget 9.000000 based on 8/15 split
# Best loss for this budget:0.031250
#
#
#
#
#
# 14:35:16 HBMASTER: Trying to run another job!
# 14:35:16 job_callback for (11, 0, 0) finished
# 14:35:16 start sampling a new configuration.
# 14:35:16 best_vector: [0.7233110288173037, 0.15722570565869967, 0.7796976238256192, 0, 0.8639743723419981, 0.42286095914423283, 0.38192296993375474], 8.663988733892158e-34, 11.542027935564573, 5.055009709451189e-44
# 14:35:16 done sampling a new configuration.
# 14:35:16 HBMASTER: schedule new run for iteration 11
# 14:35:16 HBMASTER: trying submitting job (11, 0, 1) to dispatcher
# 14:35:16 HBMASTER: submitting job (11, 0, 1) to dispatcher
# 14:35:16 DISPATCHER: trying to submit job (11, 0, 1)
# 14:35:16 DISPATCHER: trying to notify the job_runner thread.
# 14:35:16 HBMASTER: job (11, 0, 1) submitted to dispatcher
# 14:35:16 DISPATCHER: Trying to submit another job.
# 14:35:16 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 14:35:16 DISPATCHER: starting job (11, 0, 1) on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:35:16 DISPATCHER: job (11, 0, 1) dispatched on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:35:16 WORKER: start processing job (11, 0, 1)
# 14:35:16 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 14:35:16 WORKER: args: ()
# 14:35:16 WORKER: kwargs: {'config': {'lr': 0.004135758243705329, 'num_conv_layers': 1, 'num_filters_1': 26, 'optim': 'Adam'}, 'budget': 9.0, 'working_directory': '.'}
# 14:35:38 DISPATCHER: Starting worker discovery
# 14:35:38 DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# 14:35:38 DISPATCHER: Finished worker discovery
# 14:35:55 WORKER: done with job (11, 0, 1), trying to register it.
# 14:35:55 WORKER: registered result for job (11, 0, 1) with dispatcher
# 14:35:55 DISPATCHER: job (11, 0, 1) finished
# 14:35:55 DISPATCHER: register_result: lock acquired
# 14:35:55 DISPATCHER: job (11, 0, 1) on hpbandster.run_bohb_run_1.worker.MSI.1170820484 finished
# 14:35:55 job_id: (11, 0, 1)
# kwargs: {'config': {'lr': 0.004135758243705329, 'num_conv_layers': 1, 'num_filters_1': 26, 'optim': 'Adam'}, 'budget': 9.0, 'working_directory': '.'}
# result: {'loss': 0.041015625, 'info': {'test_accuracy': 0.9615, 'train_accuracy': 1.0, 'valid_accuracy': 0.958984375, 'model': 'Sequential(\n  (conv1): Conv2d(1, 26, kernel_size=(3, 3), stride=(1, 1))\n  (rel1): ReLU()\n  (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=4394, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}}
# exception: None
#
# 14:35:55 job_callback for (11, 0, 1) started
# 14:35:55 DISPATCHER: Trying to submit another job.
# 14:35:55 job_callback for (11, 0, 1) got condition
# 14:35:55 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 14:35:55 done building a new model for budget 9.000000 based on 8/16 split
# Best loss for this budget:0.031250
#
#
#
#
#
# 14:35:55 HBMASTER: Trying to run another job!
# 14:35:55 job_callback for (11, 0, 1) finished
# 14:35:55 start sampling a new configuration.
# 14:35:55 done sampling a new configuration.
# 14:35:55 HBMASTER: schedule new run for iteration 11
# 14:35:55 HBMASTER: trying submitting job (11, 0, 2) to dispatcher
# 14:35:55 HBMASTER: submitting job (11, 0, 2) to dispatcher
# 14:35:55 DISPATCHER: trying to submit job (11, 0, 2)
# 14:35:55 DISPATCHER: trying to notify the job_runner thread.
# 14:35:55 HBMASTER: job (11, 0, 2) submitted to dispatcher
# 14:35:55 DISPATCHER: Trying to submit another job.
# 14:35:55 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 14:35:55 DISPATCHER: starting job (11, 0, 2) on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:35:55 DISPATCHER: job (11, 0, 2) dispatched on hpbandster.run_bohb_run_1.worker.MSI.1170820484
# 14:35:55 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 14:35:55 WORKER: start processing job (11, 0, 2)
# 14:35:55 WORKER: args: ()
# 14:35:55 WORKER: kwargs: {'config': {'lr': 0.00016368718680930694, 'num_conv_layers': 3, 'num_filters_1': 20, 'optim': 'SGD', 'momentum': 0.4641197365404576, 'num_filters_2': 23, 'num_filters_3': 14}, 'budget': 9.0, 'working_directory': '.'}
# 14:36:38 DISPATCHER: Starting worker discovery
# 14:36:38 DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# 14:36:38 DISPATCHER: Finished worker discovery
# 14:36:40 WORKER: done with job (11, 0, 2), trying to register it.
# 14:36:40 WORKER: registered result for job (11, 0, 2) with dispatcher
# 14:36:40 DISPATCHER: job (11, 0, 2) finished
# 14:36:40 DISPATCHER: register_result: lock acquired
# 14:36:40 DISPATCHER: job (11, 0, 2) on hpbandster.run_bohb_run_1.worker.MSI.1170820484 finished
# 14:36:40 job_id: (11, 0, 2)
# kwargs: {'config': {'lr': 0.00016368718680930694, 'num_conv_layers': 3, 'num_filters_1': 20, 'optim': 'SGD', 'momentum': 0.4641197365404576, 'num_filters_2': 23, 'num_filters_3': 14}, 'budget': 9.0, 'working_directory': '.'}
# result: {'loss': 0.88671875, 'info': {'test_accuracy': 0.0982, 'train_accuracy': 0.106201171875, 'valid_accuracy': 0.11328125, 'model': 'Sequential(\n  (conv1): Conv2d(1, 20, kernel_size=(3, 3), stride=(1, 1))\n  (rel1): ReLU()\n  (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv2): Conv2d(20, 23, kernel_size=(3, 3), stride=(1, 1))\n  (rel2): ReLU()\n  (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv3): Conv2d(23, 14, kernel_size=(3, 3), stride=(1, 1))\n  (rel3): ReLU()\n  (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=14, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}}
# exception: None
#
# 14:36:40 job_callback for (11, 0, 2) started
# 14:36:40 DISPATCHER: Trying to submit another job.
# 14:36:40 job_callback for (11, 0, 2) got condition
# 14:36:40 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 14:36:40 done building a new model for budget 9.000000 based on 8/17 split
# Best loss for this budget:0.031250
#
#
#
#
#
# 14:36:40 HBMASTER: Trying to run another job!
# 14:36:40 job_callback for (11, 0, 2) finished
# 14:36:40 HBMASTER: shutdown initiated, shutdown_workers = True
# 14:36:40 WORKER: shutting down now!
# Write result to file .\bohb_result.pkl
# 14:36:41 DISPATCHER: Dispatcher shutting down
# 14:36:41 DISPATCHER: Trying to submit another job.
# 14:36:41 DISPATCHER: job_runner shutting down
# 14:36:41 DISPATCHER: discover_workers shutting down
# 14:36:41 DISPATCHER: 'discover_worker' thread exited
# 14:36:41 DISPATCHER: 'job_runner' thread exited
# 14:36:41 DISPATCHER: shut down complete
# 14:38:40 WORKER: shutting down now!

# %% [markdown]
# ### Evaluate result
#
# The result object which we dumped to disk contains all the runs with the different configurations.
# Here we will analyse it further. The [HpBandSter Analysis Example](https://automl.github.io/HpBandSter/build/html/auto_examples/plot_example_6_analysis.html) is there, if you need help.

# %%
#  load a saved result object if necessary
with open(result_file, 'rb') as f:
    result = pickle.load(f)

# %% [markdown]
# **Task:** Print the model of the best run, evaluated on the largest budget, with it's final validation error. *Tipp:* Have a look at the [HpBandSter Result Docs](https://automl.github.io/HpBandSter/build/html/core/result.html).

# %%
inc_id = result.get_incumbent_id()

inc_runs = result.get_runs_by_id(inc_id)
inc_run = inc_runs[-1]

inc_config = id2conf[inc_id]['config']
inc_val_acc = inc_run.info['valid_accuracy']
inc_val_loss = inc_run.loss
model_ = inc_run.info['model']
print('Best found configuration:')
print(inc_config)
print('validation accuracy: %.4f, final validation loss:%.5f'%(inc_val_acc, inc_val_loss))
print(model_)
# Out:
# Best found configuration:
# {'lr': 0.018404195218174567, 'num_conv_layers': 1, 'num_filters_1': 24, 'optim': 'Adam'}
# validation accuracy: 0.9688, final validation loss:0.03125
# Sequential(
#   (conv1): Conv2d(1, 24, kernel_size=(3, 3), stride=(1, 1))
#   (rel1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (flat): Flatten()
#   (lin): Linear(in_features=4056, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax()
# )

# %% [markdown]
# We can gain deeper insight through plotting results. Thanks to the [HpBandSter Visualization Module](https://automl.github.io/HpBandSter/build/html/core/visualization.html) plotting is a one-liner.

# %%
import hpbandster.visualization as hpvis

all_runs = result.get_all_runs()
id2conf = result.get_id2config_mapping()

# %% [markdown]
# First let's see, if we really can evaluate more configurations when makeing use of low budget runs.
#
# **Task:** Plot the finished runs over time. How many runs per minute did finish for the individual budgets (only approximately)?
#
# **Answer:**
# * budget 9: avg of 0.8 runs per minute
# * budget 3: avg of 1,1 runs per minute
# * budget 1: avg of 1,8 runs per minute
#
# on average more configs evaluated with lower budgets

# %%
hpvis.finished_runs_over_time(all_runs)
warnings.filterwarnings("ignore")
# Out:
# 15:09:49 update_title_pos
# 15:09:49 update_title_pos
# 15:09:49 update_title_pos
# 15:09:49 update_title_pos
# 15:09:49 update_title_pos

# %% [markdown]
# Evaluating configurations on lower budgets doesn't make sense - even if they are faster - if the performance ranking isn't consistent from low to high budget. This means, that the loss rankings for configurations should correlate. In simplified terms: The best configuration after one epoch should also be the best after nine epochs, the second best should stay the second best and so on.
#
# **Task:** Plot correlations of rankings across budgets. Are the correlations high enough?
#
# **Answer:** the spearnman correlation values are all close to 1, which means for a higher budget of the same config, we get a better (lower) loss.

# %%
hpvis.correlation_across_budgets(result)
# Out:
# 15:09:54 locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x000002273A19C588>
# 15:09:54 Using auto colorbar locator on colorbar
# 15:09:54 locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x000002273A19C588>
# 15:09:54 Setting pcolormesh
# (<Figure size 432x288 with 2 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x2273a13e0b8>)
# 15:09:54 update_title_pos
# 15:09:54 not adjusting title pos because title was already placed manually: 1.050000
# 15:09:54 update_title_pos
# 15:09:54 update_title_pos
# 15:09:54 title position was updated manually, not adjusting
# 15:09:54 update_title_pos
# 15:09:54 update_title_pos
# 15:09:54 title position was updated manually, not adjusting
# 15:09:54 update_title_pos
# 15:09:54 update_title_pos
# 15:09:54 title position was updated manually, not adjusting
# 15:09:54 update_title_pos
# 15:09:54 update_title_pos
# 15:09:54 title position was updated manually, not adjusting
# 15:09:54 update_title_pos

# %% [markdown]
# We usually assume, that training on a higher budget (number of epochs) and sampling more configurations can lead to better results. Let's check this.
#
# **Task:** Plot the losses over time. Do our assumptions hold true? Why?
#
# **Answer:** as we increase the budget, we notice that the loss typically goes down. There are still outliers that despite having a high budget (3 or 9) still have a high loss value but the majority are under 0.2 loss.

# %%
hpvis.losses_over_time(all_runs)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x2273a1c7588>)
# 15:15:13 update_title_pos
# 15:15:13 update_title_pos
# 15:15:13 update_title_pos
# 15:15:13 update_title_pos
# 15:15:13 update_title_pos

# %% [markdown]
# Remember that BOHB uses a model after some time to improve the configuation sampling. We can check, if the BO-sampled configurations work better than the random-sampled.
#
# **Task:** Plot loss histograms for all budgets only with BO-sampled and only with random-sampled configurations (6 histograms). Is the BO-sampling useful?
#
# **Answer:** apparently yes. The BO model clearly tries to sample the optimal part of the hyperspace. The number of high-loss configurations decreases as the budget goes up. For the highest budget, all of the sampled configurations have a loss smaller than 0.1

# %%
hpvis.performance_histogram_model_vs_random(all_runs, id2conf)
# Out:
# (<Figure size 432x288 with 6 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002273D2BC978>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002273DFDFD68>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x000002273E005F98>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002273E032550>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x000002273E4977F0>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002273E4BBD68>]],
#        dtype=object))
# 15:19:30 update_title_pos
# 15:19:30 update_title_pos
# 15:19:30 update_title_pos
# 15:19:30 update_title_pos
# 15:19:30 update_title_pos
# 15:19:30 update_title_pos
# 15:19:30 update_title_pos
# 15:19:30 update_title_pos
# 15:19:30 update_title_pos
# 15:19:30 update_title_pos
# 15:19:30 update_title_pos
# 15:19:30 update_title_pos
# 15:19:30 update_title_pos
# 15:19:30 update_title_pos
# 15:19:30 update_title_pos
# 15:19:30 update_title_pos
# 15:19:30 update_title_pos
# 15:19:31 update_title_pos
# 15:19:31 update_title_pos
# 15:19:31 update_title_pos
# 15:19:31 update_title_pos
# 15:19:31 update_title_pos
# 15:19:31 update_title_pos
# 15:19:31 update_title_pos
# 15:19:31 update_title_pos
# 15:19:31 update_title_pos
# 15:19:31 update_title_pos
# 15:19:31 update_title_pos
# 15:19:31 update_title_pos
# 15:19:31 update_title_pos

# %% [markdown]
# ### Your Feedback on Exercise 6.2
#
# ![good exercise](http://m.memegen.com/m0cqyr.jpg)
#
# It took me ~2 hours to debug, run and look up functions for BOHB.
