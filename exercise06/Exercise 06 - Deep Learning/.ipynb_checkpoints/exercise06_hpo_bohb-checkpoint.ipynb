# %% [markdown]
# # Sixth Exercise (HPO)
#
# This exercise focuses on hyperparameter optimization with neural networks.
#
# We will
# - define hyperparameter-configuration search-spaces
# - train deep learning models with various hyper parameters
# - use random search as a basic hyperparameter optimizer
# - use BOHB as an advanced hyperparameter optimizer
#
# It's in the nature of hyperparameter optimization, that you'll have to train a lot of models.
# Therefore execution time will be longer in this exercise, running the completed notebook takes about 30 minutes on a tutor's 3 year old laptop.

# %% [markdown]
# #### Install HpBandster and torchvision
#
# You need to install two more python packages for this exercise.
#
# - [torchvision](https://pytorch.org/docs/stable/torchvision/) provides utility methods for pytorch.
# - [HpBandSter](https://github.com/automl/HpBandSter) is a fast, parallel implementation of several hyperparameter optimizers.
#    We can define even complex hyperparameter search spaces with [ConfigSpace](https://github.com/automl/ConfigSpace), which comes along HpBandSter as dependency.
#
#
# Install with anaconda/conda
# ```
# conda install torchvision
# conda install hpbandster
# ```
#
# or with plain python
# ```
# pip3 install torchvision
# pip3 install hpbandster
# ```

# %%
import os
from typing import Tuple, List

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
import torchvision
import torchvision.transforms as transforms

import ConfigSpace as CS
import ConfigSpace.hyperparameters as CSH

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

def load_mnist_minibatched(batch_size: int, n_train: int = 8192, n_valid: int = 1024,
                           valid_test_batch_size: int = 1024) -> Tuple[DataLoader, DataLoader, DataLoader]:
    train_dataset = torchvision.datasets.MNIST(
        root='../data', train=True, transform=transforms.ToTensor(), download=True)
    test_dataset = torchvision.datasets.MNIST(
        root='../data', train=False, transform=transforms.ToTensor())

    train_sampler = SubsetRandomSampler(range(n_train))
    validation_sampler = SubsetRandomSampler(range(n_train, n_train+n_valid))

    train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, sampler=train_sampler)
    validation_loader = DataLoader(dataset=train_dataset, batch_size=valid_test_batch_size,
                                   sampler=validation_sampler)
    test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=valid_test_batch_size, 
                                              shuffle=False)
    return train_loader, validation_loader, test_loader

# Added third argument: loss_fn, and return along with accuracy (by default it only returns accuracy)
def evaluate_accuracy(model: nn.Module, data_loader: DataLoader, loss_fn) -> float:
    model.eval()
    correct = 0
    loss = 0
    with torch.no_grad():
        for x, y in data_loader:
            output = model(x)
            if(loss_fn!=None):
                loss += loss_fn(output, y)
            # get the index of the max log-probability
            pred = output.max(1, keepdim=True)[1]
            correct += pred.eq(y.view_as(pred)).sum().item()
    accuracy = correct / len(data_loader.sampler)
    return accuracy, loss

# %% [markdown]
# ## Random Search
#
# Here we get hands on hyperparameter optimization using random search.
#
# ### Model and Hyperparameter Space
#
# First we define a configurable model and a hyperparameter space. You learn how to use *ConfigSpace* to define the hyperparameters, by looking at [this example](https://automl.github.io/SMAC3/stable/quickstart.html#using-smac-in-python-svm).
#
# **Task:** Complete the functions as described in the docstrings.
#
# **Hint:** The `CS.GreaterThanCondition(conditioned_hyperparameter, lefthand_side, righthand_side)` method might be useful.

# %%
from collections import OrderedDict

# New class added to flat inputs
class Flatten(nn.Module): 
    def forward(self, input):
        self.input_shape = input.shape
        return input.view(input.size(0), -1)

def get_conv_model(num_filters_per_layer: List[int]) -> nn.Module:
    """Builds a deep convolutional model with various number of convolution
       layers for MNIST input using pytorch.
    
    for each element in num_filters_per_layer:
        convolution (conv_kernel_size, num_filters, stride=1, padding=0)
        relu
        max pool    (pool_kernel_size, stride=1)
    linear
    log softmax
    """
    assert len(num_filters_per_layer) > 0, "len(num_filters_per_layer) should be greater than 0"
    pool_kernel_size = 2
    conv_kernel_size = 3
    
    # START TODO ################
    
    # To create a model, first we set sizes (28 x 28 pix), number of layers and input channels (greyscale)
    height = 28
    width = 28
    layer_count = len(num_filters_per_layer)
    input_channels = 1
    
    # Initialize model. Later in the for-loop we add the modules
    model  = nn.Sequential()
    
    # Iterate over the number of conv2d layers. After that always ReLU + Pooling
    for i in range(layer_count):
        
        # 1. Conv2D for each filter -> (in_channels, out_channels == number of kernels/filters, kernel_size, stride=1, padding=0)
        conv2d = nn.Conv2d(input_channels, num_filters_per_layer[i], conv_kernel_size, stride=1, padding =0)
        
        # 2. ReLU Activation function
        rel = nn.ReLU()
        
        # 3. Max pooling to reduce dimensionality and make representation more manageable
        max_pool = nn.MaxPool2d(pool_kernel_size, stride=2)
        
        # 4. Update input channels for the next layer 
        # The number of output channels (or number of kernels) of the 1st layer, will be the number of input channels of the 2nd
        input_channels = num_filters_per_layer[i]
        
        # 5. Add modules to model
        model.add_module("conv{}".format(i), conv2d)
        model.add_module("rel{}".format(i), rel)
        model.add_module("pool{}".format(i), max_pool)
        
        # 6. Update output sizes after applying convolution
        conv_height = ((height - conv_kernel_size)//1) + 1
        conv_width = ((width - conv_kernel_size))//1 + 1
        
        # 7. Update output sizes after pooling
        height = ((conv_height - pool_kernel_size))//2 + 1
        width = ((conv_width - pool_kernel_size))//2 + 1
    
    # Once we have the model created, we apply linear and softmax layers to the output for multiclass classification
    model.add_module("flat", Flatten())
    model.add_module("lin", nn.Linear(height*width*num_filters_per_layer[-1], 10))
    model.add_module("logsoftmax",nn.LogSoftmax(dim=1))
    
    return model
    # End TODO ################

def get_configspace() -> CS.ConfigurationSpace:
    """ Define a conditional hyperparameter search-space.
    
    hyperparameters:
      lr              from 1e-6 to 1e-0 (log, float)
      num_filters_1   from    2 to    8 (int)
      num_filters_2   from    2 to    8 (int)
      num_conv_layers from    1 to    2 (int)
    
    conditions: 
      include num_filters_2 only if num_conv_layers > 1
    """
    cs = CS.ConfigurationSpace()
    # START TODO ################
    
    # Hyperparameters described above
    lr = UniformFloatHyperparameter("learning_rate", 1e-6, 1e-0, default_value = 1e-2, log=True)
    num_filters_1 = UniformIntegerHyperparameter("number_filters_1", 2, 8, default_value=3)
    num_filters_2 = UniformIntegerHyperparameter("number_filters_2", 2, 8, default_value=3)
    num_conv_layers = UniformIntegerHyperparameter("number_conv2D", 1, 2, default_value=1)

    # Add hyperparameters
    cs.add_hyperparameter(lr)
    cs.add_hyperparameter(num_filters_1)
    cs.add_hyperparameters([num_conv_layers, num_filters_2])
    
    # Add conditions
    cs.add_condition(CS.GreaterThanCondition(num_filters_2, num_conv_layers, 1))

    # End TODO ################
    return cs

# %% [markdown]
# ### Run model with configuration
#
# A single sample from your hyperparameter space is a *Configuration*. You can use the configuration similar to a dictionary, it supports *config.keys(), config.values(), value = config[key], key in config, …* .
# You can iterate a *DataLoader* to access (data, label) batches.
#
# **Note:** If a condition isn't met, the conditional hyperparameter isn't included in the configuration.
#
# **Task:** Complete the function to run a model like defined by the configuration. The function should return the model and the *validation error* for each epoch. You can use *evaluate_accuracy* (defined above), don't forget to switch between train and eval mode.

# %%
def run_conv_model(config: CS.Configuration, epochs: int, train_loader: DataLoader,
                   validation_loader: DataLoader) -> Tuple[nn.Module, List[float]]:    
    """ Run and evaluate a model from get_conv_model with NLLLoss and SGD.
    """
    # START TODO ################
    # retrieve the number of filters from the config and create the model
    
    # Save hyperparameters from the configuration space
    learning_rate = config["learning_rate"]
    num_conv_layers = config["number_conv2D"]
    num_filters =[]
    
    for i in range(num_conv_layers):
        num_filters.append(config["number_filters_{}".format(i+1)])
        
    print("[Config space] lr: {:.5f} - Number of filters: {} - Number of conv2D layers: {}".format(learning_rate, num_filters, num_conv_layers))
    model = get_conv_model(num_filters)
    
    # define loss and optimizer
    loss_fn = torch.nn.NLLLoss()
    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
    
    # train the model for `epochs` and save the validation error for each epoch in   
    val_errors = []
    for epoch in range(epochs):
        for x_train, y_train in train_loader:
            model.train()
            optimizer.zero_grad()
            y_output = model(x_train)
            loss = loss_fn(y_output,y_train)
            #print(f"train loss for epoch {epoch} : {loss}")
            loss.backward()
            optimizer.step()
        
        # Evaluate on validation set 
        # Here we modified the "evaluate_accuracy" funtion to return both, loss and accuracy
        accuracy, loss = evaluate_accuracy(model, validation_loader, loss_fn)
        val_errors.append(loss)
        print("epoch #{} : accuracy = {:.5f}, loss = {:.5f}".format(epoch, accuracy, loss))
    
    # End TODO ################
    return model, val_errors

# %% [markdown]
# Now let's run models with various, random hyperparameter configurations. Don't forget to store all the configuration and validation errors for further evaluation.
#
# **Tipp:** *ConfigSpace* objects have a *.sample_configuration()* function to sample a random configuration.
#
# **Task:** Run *n_random_samples* models for *n_epochs* and store the tuple `(model, config, val_errors)` in `results`.

# %%
# Some imports to make it work
from ConfigSpace.hyperparameters import CategoricalHyperparameter, UniformFloatHyperparameter, UniformIntegerHyperparameter
from ConfigSpace.conditions import InCondition

n_random_samples = 18
n_epochs = 9
cs = get_configspace()
train_loader, validation_loader, _ = load_mnist_minibatched(batch_size=32, n_train=4096, n_valid=512)

# START TODO ################

results = []
for i in range(n_random_samples):
    print("Training model #{}".format(i+1))
    
    cfg = cs.sample_configuration()
    model, val_errors = run_conv_model(cfg, n_epochs, train_loader, validation_loader)
    results.append((model,cfg,val_errors))
    print("---")

# End TODO ################
# Out:
# Training model #1
# [Config space] lr: 0.00191 - Number of filters: [8] - Number of conv2D layers: 1
# epoch #0 : accuracy = 0.42383, loss = 2.22511
# epoch #1 : accuracy = 0.69336, loss = 2.09693
# epoch #2 : accuracy = 0.73242, loss = 1.90259
# epoch #3 : accuracy = 0.76758, loss = 1.62691
# epoch #4 : accuracy = 0.79492, loss = 1.32177
# epoch #5 : accuracy = 0.82031, loss = 1.06312
# epoch #6 : accuracy = 0.83398, loss = 0.87725
# epoch #7 : accuracy = 0.84570, loss = 0.74856
# epoch #8 : accuracy = 0.86133, loss = 0.66163
# ---
# Training model #2
# [Config space] lr: 0.58966 - Number of filters: [4, 6] - Number of conv2D layers: 2
# epoch #0 : accuracy = 0.12500, loss = 2.29768
# epoch #1 : accuracy = 0.11328, loss = 2.29829
# epoch #2 : accuracy = 0.11328, loss = 2.30167
# epoch #3 : accuracy = 0.12500, loss = 2.30404
# epoch #4 : accuracy = 0.12500, loss = 2.29905
# epoch #5 : accuracy = 0.11328, loss = 2.29952
# epoch #6 : accuracy = 0.11328, loss = 2.29883
# epoch #7 : accuracy = 0.11328, loss = 2.30151
# epoch #8 : accuracy = 0.11328, loss = 2.30420
# ---
# Training model #3
# [Config space] lr: 0.00252 - Number of filters: [2, 4] - Number of conv2D layers: 2
# epoch #0 : accuracy = 0.05273, loss = 2.30146
# epoch #1 : accuracy = 0.05469, loss = 2.30085
# epoch #2 : accuracy = 0.07227, loss = 2.30032
# epoch #3 : accuracy = 0.08008, loss = 2.29990
# epoch #4 : accuracy = 0.08789, loss = 2.29948
# epoch #5 : accuracy = 0.09375, loss = 2.29906
# epoch #6 : accuracy = 0.10156, loss = 2.29861
# epoch #7 : accuracy = 0.11133, loss = 2.29812
# epoch #8 : accuracy = 0.11133, loss = 2.29755
# ---
# Training model #4
# [Config space] lr: 0.00021 - Number of filters: [5, 2] - Number of conv2D layers: 2
# epoch #0 : accuracy = 0.10938, loss = 2.30537
# epoch #1 : accuracy = 0.10938, loss = 2.30459
# epoch #2 : accuracy = 0.10938, loss = 2.30385
# epoch #3 : accuracy = 0.10938, loss = 2.30314
# epoch #4 : accuracy = 0.10938, loss = 2.30246
# epoch #5 : accuracy = 0.10938, loss = 2.30182
# epoch #6 : accuracy = 0.10938, loss = 2.30120
# epoch #7 : accuracy = 0.10938, loss = 2.30062
# epoch #8 : accuracy = 0.10938, loss = 2.30007
# ---
# Training model #5
# [Config space] lr: 0.00296 - Number of filters: [2, 6] - Number of conv2D layers: 2
# epoch #0 : accuracy = 0.09180, loss = 2.30594
# epoch #1 : accuracy = 0.15625, loss = 2.29356
# epoch #2 : accuracy = 0.20898, loss = 2.27912
# epoch #3 : accuracy = 0.24609, loss = 2.26145
# epoch #4 : accuracy = 0.25977, loss = 2.23546
# epoch #5 : accuracy = 0.31250, loss = 2.19314
# epoch #6 : accuracy = 0.38672, loss = 2.11714
# epoch #7 : accuracy = 0.47070, loss = 1.97113
# epoch #8 : accuracy = 0.55469, loss = 1.69768
# ---
# Training model #6
# [Config space] lr: 0.00089 - Number of filters: [2] - Number of conv2D layers: 1
# epoch #0 : accuracy = 0.10352, loss = 2.30966
# epoch #1 : accuracy = 0.10547, loss = 2.30767
# epoch #2 : accuracy = 0.11328, loss = 2.30567
# epoch #3 : accuracy = 0.11914, loss = 2.30360
# epoch #4 : accuracy = 0.12305, loss = 2.30140
# epoch #5 : accuracy = 0.12500, loss = 2.29903
# epoch #6 : accuracy = 0.12891, loss = 2.29639
# epoch #7 : accuracy = 0.13281, loss = 2.29340
# epoch #8 : accuracy = 0.14258, loss = 2.28998
# ---
# Training model #7
# [Config space] lr: 0.00224 - Number of filters: [8, 4] - Number of conv2D layers: 2
# epoch #0 : accuracy = 0.09961, loss = 2.29138
# epoch #1 : accuracy = 0.13086, loss = 2.28568
# epoch #2 : accuracy = 0.19336, loss = 2.27905
# epoch #3 : accuracy = 0.23633, loss = 2.27109
# epoch #4 : accuracy = 0.27539, loss = 2.26128
# epoch #5 : accuracy = 0.30859, loss = 2.24858
# epoch #6 : accuracy = 0.32812, loss = 2.23244
# epoch #7 : accuracy = 0.34570, loss = 2.21063
# epoch #8 : accuracy = 0.34961, loss = 2.18026
# ---
# Training model #8
# [Config space] lr: 0.00005 - Number of filters: [3, 5] - Number of conv2D layers: 2
# epoch #0 : accuracy = 0.08594, loss = 2.30664
# epoch #1 : accuracy = 0.08594, loss = 2.30644
# epoch #2 : accuracy = 0.08398, loss = 2.30625
# epoch #3 : accuracy = 0.08398, loss = 2.30606
# epoch #4 : accuracy = 0.08398, loss = 2.30586
# epoch #5 : accuracy = 0.08398, loss = 2.30567
# epoch #6 : accuracy = 0.08398, loss = 2.30548
# epoch #7 : accuracy = 0.08398, loss = 2.30529
# epoch #8 : accuracy = 0.08398, loss = 2.30511
# ---
# Training model #9
# [Config space] lr: 0.00017 - Number of filters: [2, 6] - Number of conv2D layers: 2
# epoch #0 : accuracy = 0.09180, loss = 2.31889
# epoch #1 : accuracy = 0.09180, loss = 2.31840
# epoch #2 : accuracy = 0.09180, loss = 2.31792
# epoch #3 : accuracy = 0.09180, loss = 2.31746
# epoch #4 : accuracy = 0.09180, loss = 2.31701
# epoch #5 : accuracy = 0.09180, loss = 2.31658
# epoch #6 : accuracy = 0.09180, loss = 2.31615
# epoch #7 : accuracy = 0.09180, loss = 2.31574
# epoch #8 : accuracy = 0.09180, loss = 2.31534
# ---
# Training model #10
# [Config space] lr: 0.00442 - Number of filters: [8] - Number of conv2D layers: 1
# epoch #0 : accuracy = 0.63477, loss = 2.08669
# epoch #1 : accuracy = 0.77930, loss = 1.52773
# epoch #2 : accuracy = 0.84766, loss = 0.91528
# epoch #3 : accuracy = 0.87109, loss = 0.64721
# epoch #4 : accuracy = 0.88086, loss = 0.53262
# epoch #5 : accuracy = 0.87500, loss = 0.46432
# epoch #6 : accuracy = 0.88672, loss = 0.42972
# epoch #7 : accuracy = 0.89648, loss = 0.40349
# epoch #8 : accuracy = 0.88477, loss = 0.38602
# ---
# Training model #11
# [Config space] lr: 0.34197 - Number of filters: [5] - Number of conv2D layers: 1
# epoch #0 : accuracy = 0.90820, loss = 0.27579
# epoch #1 : accuracy = 0.92969, loss = 0.23942
# epoch #2 : accuracy = 0.94141, loss = 0.18621
# epoch #3 : accuracy = 0.94141, loss = 0.17823
# epoch #4 : accuracy = 0.95312, loss = 0.16182
# epoch #5 : accuracy = 0.94531, loss = 0.19747
# epoch #6 : accuracy = 0.94922, loss = 0.20799
# epoch #7 : accuracy = 0.95898, loss = 0.17547
# epoch #8 : accuracy = 0.95312, loss = 0.19790
# ---
# Training model #12
# [Config space] lr: 0.00000 - Number of filters: [6, 8] - Number of conv2D layers: 2
# epoch #0 : accuracy = 0.08594, loss = 2.30858
# epoch #1 : accuracy = 0.08594, loss = 2.30856
# epoch #2 : accuracy = 0.08594, loss = 2.30855
# epoch #3 : accuracy = 0.08594, loss = 2.30854
# epoch #4 : accuracy = 0.08594, loss = 2.30852
# epoch #5 : accuracy = 0.08594, loss = 2.30851
# epoch #6 : accuracy = 0.08594, loss = 2.30850
# epoch #7 : accuracy = 0.08594, loss = 2.30848
# epoch #8 : accuracy = 0.08594, loss = 2.30847
# ---
# Training model #13
# [Config space] lr: 0.78803 - Number of filters: [7, 3] - Number of conv2D layers: 2
# epoch #0 : accuracy = 0.11328, loss = 2.29853
# epoch #1 : accuracy = 0.09180, loss = 2.30052
# epoch #2 : accuracy = 0.11328, loss = 2.30071
# epoch #3 : accuracy = 0.11328, loss = 2.30079
# epoch #4 : accuracy = 0.11328, loss = 2.30506
# epoch #5 : accuracy = 0.12500, loss = 2.30127
# epoch #6 : accuracy = 0.09180, loss = 2.30153
# epoch #7 : accuracy = 0.12500, loss = 2.29882
# epoch #8 : accuracy = 0.11328, loss = 2.30139
# ---
# Training model #14
# [Config space] lr: 0.00224 - Number of filters: [8, 5] - Number of conv2D layers: 2
# epoch #0 : accuracy = 0.11914, loss = 2.30070
# epoch #1 : accuracy = 0.12109, loss = 2.29577
# epoch #2 : accuracy = 0.12891, loss = 2.28995
# epoch #3 : accuracy = 0.12500, loss = 2.28215
# epoch #4 : accuracy = 0.13867, loss = 2.27092
# epoch #5 : accuracy = 0.18555, loss = 2.25484
# epoch #6 : accuracy = 0.23438, loss = 2.23101
# epoch #7 : accuracy = 0.33008, loss = 2.19349
# epoch #8 : accuracy = 0.46094, loss = 2.13241
# ---
# Training model #15
# [Config space] lr: 0.00018 - Number of filters: [4] - Number of conv2D layers: 1
# epoch #0 : accuracy = 0.09375, loss = 2.29944
# epoch #1 : accuracy = 0.10742, loss = 2.28944
# epoch #2 : accuracy = 0.12305, loss = 2.27949
# epoch #3 : accuracy = 0.13867, loss = 2.26954
# epoch #4 : accuracy = 0.18164, loss = 2.25954
# epoch #5 : accuracy = 0.22070, loss = 2.24942
# epoch #6 : accuracy = 0.26172, loss = 2.23913
# epoch #7 : accuracy = 0.30469, loss = 2.22863
# epoch #8 : accuracy = 0.34375, loss = 2.21788
# ---
# Training model #16
# [Config space] lr: 0.02369 - Number of filters: [3] - Number of conv2D layers: 1
# epoch #0 : accuracy = 0.75391, loss = 1.42170
# epoch #1 : accuracy = 0.86328, loss = 0.48091
# epoch #2 : accuracy = 0.87891, loss = 0.39309
# epoch #3 : accuracy = 0.89453, loss = 0.38907
# epoch #4 : accuracy = 0.88672, loss = 0.37285
# epoch #5 : accuracy = 0.90430, loss = 0.33730
# epoch #6 : accuracy = 0.90039, loss = 0.34684
# epoch #7 : accuracy = 0.91406, loss = 0.33166
# epoch #8 : accuracy = 0.91016, loss = 0.35097
# ---
# Training model #17
# [Config space] lr: 0.19950 - Number of filters: [7] - Number of conv2D layers: 1
# epoch #0 : accuracy = 0.83594, loss = 0.50158
# epoch #1 : accuracy = 0.89258, loss = 0.34419
# epoch #2 : accuracy = 0.91992, loss = 0.29466
# epoch #3 : accuracy = 0.90234, loss = 0.35588
# epoch #4 : accuracy = 0.94141, loss = 0.23771
# epoch #5 : accuracy = 0.93555, loss = 0.22783
# epoch #6 : accuracy = 0.93945, loss = 0.23131
# epoch #7 : accuracy = 0.94336, loss = 0.24009
# epoch #8 : accuracy = 0.95312, loss = 0.22979
# ---
# Training model #18
# [Config space] lr: 0.00004 - Number of filters: [4, 6] - Number of conv2D layers: 2
# epoch #0 : accuracy = 0.07422, loss = 2.32341
# epoch #1 : accuracy = 0.07422, loss = 2.32313
# epoch #2 : accuracy = 0.07422, loss = 2.32285
# epoch #3 : accuracy = 0.07422, loss = 2.32258
# epoch #4 : accuracy = 0.07422, loss = 2.32230
# epoch #5 : accuracy = 0.07422, loss = 2.32203
# epoch #6 : accuracy = 0.07422, loss = 2.32176
# epoch #7 : accuracy = 0.07422, loss = 2.32149
# epoch #8 : accuracy = 0.07422, loss = 2.32123
# ---

# %% [markdown]
# ### Evaluate
#
# Now we should evaluate the previous runs. Evaluation in hyperparameter optimization can mean two different things: On the one hand, we might be only interested in the model with the best performance. On the other hand, we might want to find the best hyperparameter configuration to then train a model with these hyper-parameters (but with e.g. more epochs).
#
# **Task:** Print the model and final validation error of the best model in `results`.

# %%
# START TODO ################

# We create a threshold that we update always being the lower found error, in order to find the minimum loss
loss_threshold = 300
best_idx = 0

for i in range(len(results)):
    model, cfg , val_error = results[i]
    if (val_error[-1] < loss_threshold):
        loss_threshold = val_error[-1]
        best_idx = i        

# best_idx contains the best result index
best_result = results[best_idx]

# Retrieve hyperparameters from best resulting config space
best_model, best_cfg, best_error = best_result
learning_rate =  best_cfg["learning_rate"]
num_conv_layers = best_cfg["number_conv2D"]
num_filters =[]

# Print Config space
print("Best model: #{}, loss : {:.5f}".format((best_idx + 1), best_error[-1]))
for i in range(num_conv_layers):
    num_filters.append(best_cfg["number_filters_{}".format(i+1)])
print("[Config space] lr: {:.5f} - Number of filters: {} - Number of conv2D layers: {}".format(learning_rate, num_filters, num_conv_layers))
print("===========================================================================================")

# We print the modules of such model
for idx, m in enumerate(best_model.named_modules()):
    if idx != 0:
        print('Module', idx, ':', m)

# END TODO ################
# Out:
# Best model: #11, loss : 0.19790
# [Config space] lr: 0.34197 - Number of filters: [5] - Number of conv2D layers: 1
# ===========================================================================================
# Module 1 : ('conv0', Conv2d(1, 5, kernel_size=(3, 3), stride=(1, 1)))
# Module 2 : ('rel0', ReLU())
# Module 3 : ('pool0', MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False))
# Module 4 : ('flat', Flatten())
# Module 5 : ('lin', Linear(in_features=845, out_features=10, bias=True))
# Module 6 : ('logsoftmax', LogSoftmax())

# %% [markdown]
# Let's further investigate which hyperparameters work well and which don't.
#
# **Task:** Print a scatter plot of learning rate (x) and number of filters (sum over layers, y). Scale the size of the scatter points by the error in the last epoch (10 to 100).

# %%
# START TODO ################

plt.figure(1)
plt.xscale('log')
plt.xlabel('Learning rate')
plt.ylabel('Number of filters')

for i in range(len(results)):
    model, cfg , val_error = results[i]   
    learning_rate =  cfg["learning_rate"]
    num_conv_layers = cfg["number_conv2D"]
    num_filters =[]
    for i in range(num_conv_layers):
        num_filters.append(cfg["number_filters_{}".format(i+1)])
    num_filters = np.sum(num_filters)
        
    plt.scatter(learning_rate, num_filters, s = 50*val_error[-1], edgecolors="black")
    plt.axvline(x=0.004)  
    plt.axvline(x=0.4)   
    
# END TODO ################

# %% [markdown]
# **Question:** What pattern do you see? Why might it occur?
#
# **Answer:**
#
# The bigger the point, the more error introduces such learning rate for the corresponding number of filters.
# It is clear that for the lower region (learning rates lower than 10^-2), errors are ofter larger, regardless of the number of filters. Instead, in the area between both blue lines we can find the best configurations.
#
# If we go straigh to the right, we can find as well large error configurations, probably caused by a too large learning rate which diverges and overfits, along with a too low number of filters.

# %% [markdown]
# After looking at the final error, let's now have a look at the training error.
#
# **Task:** Plot error curves (error per epoch) for all your configurations in one figure.

# %%
# START TODO ################

plt.figure(2, figsize=(10,5))
plt.xlabel('Epochs')
plt.ylabel('Validation Error')

for i in range(len(results)):
    _, _ , val_error = results[i]   
    plt.plot(val_error)
    
# END TODO ################

# %% [markdown]
# **Questions:** How could you detect configurations with a low error earlier/faster? Why could this be problematic?
#
# **Answers:**
#
# One way would be using "early stopping", for those models which have a large validation error that does not decrease in time. We could save training time by stopping them, but it requires constant perception of the training process, or in the other hand, to set a threshold.
#
# However, a wrong threshold could also introduces some other problems, like to stop a model, which we believe is bad, simply because the validation errors are high at the beginning. It can happen that this error decreases  quite in further epochs.
#
# An example is in the plot itself. The <font color='blue'>blue model</font> starts having a large validation error but ends up being on of the best among others.

# %% [markdown]
# ### Your Feedback on Exercise 6.1
#
# I liked the practical approach of this exercise, and how to start seeing the real consequences of modifying the hyperparameters of a model.
#
# The configuration space setup was the most difficult part for me, it was te first time I worked with it. I like also that we start working with PyTorch, I think after the "stress" of the first exercises, this makes everything a little bit easier, and additionally we can have the knowledge of an important Deep Learning framework.
#
# This part took us around 2 days, working half-day each.

# %% [markdown]
# ## BOHB
#
# Here we will use the more advanced hyperparameter optimizer [BOHB](https://www.automl.org/blog_bohb/) (Bayesian Optimization with Hyperband).
# Based on [Hyperband](https://arxiv.org/pdf/1603.06560.pdf), BOHB evaluates configurations on your model with increasing budgets. In the context of Deep Learning, budget can be the number of epochs or the number of training samples. In lower budget evaluations, BOHB can look at more configurations. Full budget evaluations avoid missing configurations which are poor at the beginnning but good at the end (and vice versa).
# At the start of a run, BOHB samples configurations randomly. After some time, BOHB then uses a bayesian model (based on Parzen Tree Estimators), sampling only promising configs.
#
# This exercise part is based on the [HpBandSter Examples](https://automl.github.io/HpBandSter/build/html/auto_examples/index.html) and the [HpBandSter Documentation](https://automl.github.io/HpBandSter/). *HpBandSter* provides a fast implementation of *Randomsearch*, *Hyperband* and *BOHB*. The optimization can easily be distributed between multiple cores or even multiple computers.

# %%
import pickle
import logging

from hpbandster.core.worker import Worker
import hpbandster.core.nameserver as hpns
import hpbandster.core.result as hpres
from hpbandster.optimizers import BOHB

logging.getLogger('hpbandster').setLevel(logging.DEBUG)

# %% [markdown]
# ### Implement Worker
#
# The worker defines the hyperparameter problem which we try to optimize.
# *compute(...)* should - for a given configuration and budget - return a loss which the hyperparameter optimizer tries to minimize. In our case, we can use the number of epochs as budget and the validation error as loss.
# As best practice, we define the configuration space also in the worker.
#
# If you need help, you might get some inspiration from the [HpBandSter Pytorch Worker Example](https://automl.github.io/HpBandSter/build/html/auto_examples/example_5_pytorch_worker.html#sphx-glr-auto-examples-example-5-pytorch-worker-py).
#
# **Task:** Complete the methods below.

# %%
class PyTorchWorker(Worker):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self.train_loader, self.validation_loader, self.test_loader =\
            load_mnist_minibatched(batch_size=32, n_train=4096, n_valid=512)

    @staticmethod
    def get_model(config: CS.Configuration) -> nn.Module:
        """ Define a configurable convolution model.
            
        See description of get_conv_model above for more details on the model.
        """
        # START TODO ################
        #raise NotImplementedError
  
        pool_kernel_size = 2
        conv_kernel_size = 3
        height = 28
        width = 28
        
        # For each conv2D layer we save the number of kernels
        num_conv_layers = config["num_conv_layers"]
        num_filters_per_layer =[]        
        for i in range(num_conv_layers):
            num_filters_per_layer.append(config["num_filters_{}".format(i+1)])
        
        # This part is exactly like the first one, to create the model with the modules
        
        # Initialize model. Later in the for-loop we add the modules
        model  = nn.Sequential()
        input_channels = 1

        # Iterate over the number of conv2d layers. After that always ReLU + Pooling
        for i in range(num_conv_layers):
            
            # 1. Conv2D for each filter -> (in_channels, out_channels == number of kernels/filters, kernel_size, stride=1, padding=0)
            conv2d = nn.Conv2d(input_channels, num_filters_per_layer[i], conv_kernel_size, stride=1, padding =0)            
            
            # 2. ReLU Activation function
            rel = nn.ReLU()
            
            # 3. Max pooling to reduce dimensionality and make representation more manageable
            max_pool = nn.MaxPool2d(pool_kernel_size, stride=2)            
            
            # 4. Update input channels for the next layer 
            # The number of output channels (or number of kernels) of the 1st layer, will be the number of input channels of the 2nd
            input_channels = num_filters_per_layer[i]            
            
            # 5. Add modules to model
            model.add_module("conv{}".format(i), conv2d)
            model.add_module("rel{}".format(i), rel)
            model.add_module("pool{}".format(i), max_pool)
            
            # 6. Update output sizes after applying convolution
            conv_height = ((height - conv_kernel_size)//1) + 1
            conv_width = ((width - conv_kernel_size))//1 + 1
        
            # 7. Update output sizes after pooling
            height = ((conv_height - pool_kernel_size))//2 + 1
            width = ((conv_width - pool_kernel_size))//2 + 1
            
        # Once we have the model created, we apply linear and softmax layers to the output for multiclass classification
        model.add_module("flat", Flatten())
        model.add_module("lin", nn.Linear(height*width*num_filters_per_layer[-1], 10))
        model.add_module("logsoftmax",nn.LogSoftmax(dim=1))
        
        return model  
    
        # END TODO ################
        
    @staticmethod
    def get_configspace() -> CS.Configuration:
        """ Define a conditional hyperparameter search-space.
    
        hyperparameters:
          num_filters_1   from    4 to   32 (int)
          num_filters_2   from    4 to   32 (int)
          num_filters_3   from    4 to   32 (int)
          num_conv_layers from    1 to    3 (int)
          lr              from 1e-6 to 1e-1 (float, log)
          sgd_momentum    from 0.00 to 0.99 (float)
          optimizer            Adam or  SGD (categoric)
          
        conditions: 
          include num_filters_2 only if num_conv_layers > 1
          include num_filters_3 only if num_conv_layers > 2
          include sgd_momentum  only if       optimizer = SGD
        """
        # START TODO ################
        #raise NotImplementedError
        
        # Also, like in the first part, we create the hyperparameters and Config space
        cs = CS.ConfigurationSpace()
        
        # Learning rate
        lr = UniformFloatHyperparameter("lr", 1e-6, 1e-1, default_value = 1e-2, log=True)
        
        # Optimizer hyperparameters
        momentum = UniformFloatHyperparameter("cs_momentum", 0, 0.99, default_value = 0.5)
        optimizer = CategoricalHyperparameter("cs_optimizer", ["Adam","SGD"], default_value="SGD")
        
        # Conv2D hyperparameters
        num_conv_layers = UniformIntegerHyperparameter("num_conv_layers", 1, 3, default_value=2)
        num_filters_1 = UniformIntegerHyperparameter("num_filters_1", 4, 32, default_value=6)
        num_filters_2 = UniformIntegerHyperparameter("num_filters_2", 4, 32, default_value=6)
        num_filters_3 = UniformIntegerHyperparameter("num_filters_3", 4, 32, default_value=6)
        
        # Adding hyperparameters
        cs.add_hyperparameter(lr)      
        cs.add_hyperparameters([optimizer, momentum])
        cs.add_hyperparameters([num_conv_layers, num_filters_1, num_filters_2, num_filters_3])

        # Adding conditions
        cs.add_condition(InCondition(child=momentum, parent=optimizer, values=["SGD"])) # <- Belongs to Optimizer
        cs.add_condition(CS.GreaterThanCondition(num_filters_2, num_conv_layers, 1))
        cs.add_condition(CS.GreaterThanCondition(num_filters_3, num_conv_layers, 2))
        
        return cs

        # END TODO ################

    def compute(self, config: CS.Configuration, budget: float, working_directory: str,
                *args, **kwargs) -> float:
        """Evaluate a function with the given config and budget and return a loss.
        
        Bohb tries to minimize the returned loss.
        
        In our case the function is the training and validation of a model,
        the budget is the number of epochs and the loss is the validation error.
        """
        model = self.get_model(config)
        
        # START TODO ################
        
        learning_rate = config["lr"]
        opt = config["cs_optimizer"]
        optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)
        if(opt == "SGD"):
            momentum = config["cs_momentum"]
            optimizer = torch.optim.SGD(model.parameters(), lr = learning_rate, momentum = momentum)
        loss_fn = torch.nn.NLLLoss()
        
        # We start training here
        epochs = int(budget)
        for epoch in range(epochs):
            for x_train, y_train in self.train_loader:
                model.train()
                optimizer.zero_grad()
                y_output = model(x_train)
                loss = loss_fn(y_output, y_train)
                loss.backward()
                optimizer.step() 

        # END TODO ################
        
        train_accuracy, _ = evaluate_accuracy(model, self.train_loader, None)
        validation_accuracy, _ = evaluate_accuracy(model, self.validation_loader, None)
        test_accuracy, _ = evaluate_accuracy(model, self.test_loader, None)
        
        return ({
                'loss': 1 - validation_accuracy,  # remember: HpBandSter minimizes the loss!
                'info': {'test_accuracy': test_accuracy,
                         'train_accuracy': train_accuracy,
                         'valid_accuracy': validation_accuracy,
                         'model': str(model)}
                })

# %% [markdown]
# It's best practice to do a quick sanity check of our worker with a low budget:

# %%
working_dir = os.curdir
# minimum budget that BOHB uses
min_budget = 1
# largest budget BOHB will use
max_budget = 9

# %%
worker = PyTorchWorker(run_id='0')
cs = worker.get_configspace()

config = cs.sample_configuration().get_dictionary()
print(config)

res = worker.compute(config=config, budget=min_budget, working_directory=working_dir)
print(res)
# Out:
# {'num_filters_2': 9, 'cs_optimizer': 'Adam', 'num_filters_3': 20, 'num_filters_1': 14, 'lr': 6.965447440594796e-05, 'num_conv_layers': 3}
# {'info': {'test_accuracy': 0.1007, 'train_accuracy': 0.09765625, 'valid_accuracy': 0.109375, 'model': 'Sequential(\n  (conv0): Conv2d(1, 14, kernel_size=(3, 3), stride=(1, 1))\n  (rel0): ReLU()\n  (pool0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv1): Conv2d(14, 9, kernel_size=(3, 3), stride=(1, 1))\n  (rel1): ReLU()\n  (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv2): Conv2d(9, 20, kernel_size=(3, 3), stride=(1, 1))\n  (rel2): ReLU()\n  (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=20, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}, 'loss': 0.890625}

# %% [markdown]
# ### Run BOHB
#
# We now run the hyperparameter search with BOHB and the worker which we defined above and save the result to disk.
# Try to understand what happens. *HpBandSter* allows to start additional workers on the same or remote devices to parallelize the executions, that's why we need to setup some network stuff (nameserver, nic, host, port, …). If you're interested, you can check this out in the [HpBandSter Examples](https://automl.github.io/HpBandSter/build/html/auto_examples/index.html), but it is beyond the scope of this exercise.
#
# **Note:** The code below will try 60 different configurations. Some of them are executed at multiple budgets, which results in about 80 model training. Therefore it might take a while (15-45 minutes on a laptop). If you are interested in how BOHB works, checkout [BOHB (Falkner et al. 2018)](http://proceedings.mlr.press/v80/falkner18a.html).
#
# **Note 2:** You can see the progress in the debug output below. The configuration identifier (called `config_id` in the docs) is a three-tuple `(current iteration, resampling in case of error, sample)`.

# %%
result_file = os.path.join(working_dir, 'bohb_result.pkl')
nic_name = 'lo'
port = 0
run_id = 'bohb_run_1'
n_bohb_iterations = 12

# %%
try:
    # Start a nameserver
    host = hpns.nic_name_to_host(nic_name)
    ns = hpns.NameServer(run_id=run_id, host=host, port=port,
                         working_directory=working_dir)
    ns_host, ns_port = ns.start()

    # Start local worker
    w = PyTorchWorker(run_id=run_id, host=host, nameserver=ns_host,
                      nameserver_port=ns_port, timeout=120)
    w.run(background=True)

    # Run an optimizer
    bohb = BOHB(configspace=worker.get_configspace(),
                run_id=run_id,
                host=host,
                nameserver=ns_host,
                nameserver_port=ns_port,
                min_budget=min_budget, max_budget=max_budget)
    
    result = bohb.run(n_iterations=n_bohb_iterations)
    print("Write result to file {}".format(result_file))
    with open(result_file, 'wb') as f:
        pickle.dump(result, f)
finally:
    bohb.shutdown(shutdown_workers=True)
    ns.shutdown()
# Out:
# 17:07:31 wait_for_workers trying to get the condition
# 17:07:31 WORKER: Connected to nameserver <Pyro4.core.Proxy at 0x7fc978a74518; connected IPv4; for PYRO:Pyro.NameServer@127.0.0.1:43023>
# 17:07:31 DISPATCHER: started the 'discover_worker' thread
# 17:07:31 WORKER: No dispatcher found. Waiting for one to initiate contact.
# 17:07:31 DISPATCHER: started the 'job_runner' thread
# 17:07:31 WORKER: start listening for jobs
# 17:07:31 DISPATCHER: Pyro daemon running on 127.0.0.1:43237
# 17:07:31 DISPATCHER: Starting worker discovery
# 17:07:31 DISPATCHER: Found 1 potential workers, 0 currently in the pool.
# 17:07:31 DISPATCHER: discovered new worker, hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:07:31 HBMASTER: number of workers changed to 1
# 17:07:31 Enough workers to start this run!
# 17:07:31 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 17:07:31 adjust_queue_size: lock accquired
# 17:07:31 HBMASTER: starting run at 1543766851.9366667
# 17:07:31 HBMASTER: adjusted queue size to (0, 1)
# 17:07:31 DISPATCHER: Finished worker discovery
# 17:07:31 start sampling a new configuration.
# 17:07:31 DISPATCHER: Trying to submit another job.
# 17:07:31 done sampling a new configuration.
# 17:07:31 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 17:07:31 HBMASTER: schedule new run for iteration 0
# 17:07:31 HBMASTER: trying submitting job (0, 0, 0) to dispatcher
# 17:07:31 HBMASTER: submitting job (0, 0, 0) to dispatcher
# 17:07:31 DISPATCHER: trying to submit job (0, 0, 0)
# 17:07:31 DISPATCHER: trying to notify the job_runner thread.
# 17:07:31 HBMASTER: job (0, 0, 0) submitted to dispatcher
# 17:07:31 DISPATCHER: Trying to submit another job.
# 17:07:31 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 17:07:31 DISPATCHER: starting job (0, 0, 0) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:07:31 DISPATCHER: job (0, 0, 0) dispatched on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:07:31 WORKER: start processing job (0, 0, 0)
# 17:07:31 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 17:07:31 WORKER: args: ()
# 17:07:31 WORKER: kwargs: {'budget': 1.0, 'config': {'num_conv_layers': 1, 'num_filters_1': 15, 'lr': 0.009115504957477365, 'cs_optimizer': 'Adam'}, 'working_directory': '.'}
# 17:07:33 WORKER: done with job (0, 0, 0), trying to register it.
# 17:07:33 WORKER: registered result for job (0, 0, 0) with dispatcher
# 17:07:33 DISPATCHER: job (0, 0, 0) finished
# 17:07:33 DISPATCHER: register_result: lock acquired
# 17:07:33 DISPATCHER: job (0, 0, 0) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184 finished
# 17:07:33 job_id: (0, 0, 0)
# kwargs: {'budget': 1.0, 'config': {'num_conv_layers': 1, 'num_filters_1': 15, 'lr': 0.009115504957477365, 'cs_optimizer': 'Adam'}, 'working_directory': '.'}
# result: {'info': {'test_accuracy': 0.9102, 'train_accuracy': 0.935302734375, 'valid_accuracy': 0.921875, 'model': 'Sequential(\n  (conv0): Conv2d(1, 15, kernel_size=(3, 3), stride=(1, 1))\n  (rel0): ReLU()\n  (pool0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=2535, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}, 'loss': 0.078125}
# exception: None
#
# 17:07:33 job_callback for (0, 0, 0) started
# 17:07:33 DISPATCHER: Trying to submit another job.
# 17:07:33 job_callback for (0, 0, 0) got condition
# 17:07:33 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 17:07:33 Only 1 run(s) for budget 1.000000 available, need more than 9 -> can't build model!
# 17:07:34 HBMASTER: Trying to run another job!
# 17:07:34 job_callback for (0, 0, 0) finished
# 17:07:34 start sampling a new configuration.
# 17:07:34 done sampling a new configuration.
# 17:07:34 HBMASTER: schedule new run for iteration 0
# 17:07:34 HBMASTER: trying submitting job (0, 0, 1) to dispatcher
# 17:07:34 HBMASTER: submitting job (0, 0, 1) to dispatcher
# 17:07:34 DISPATCHER: trying to submit job (0, 0, 1)
# 17:07:34 DISPATCHER: trying to notify the job_runner thread.
# 17:07:34 HBMASTER: job (0, 0, 1) submitted to dispatcher
# 17:07:34 DISPATCHER: Trying to submit another job.
# 17:07:34 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 17:07:34 DISPATCHER: starting job (0, 0, 1) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:07:34 DISPATCHER: job (0, 0, 1) dispatched on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:07:34 WORKER: start processing job (0, 0, 1)
# 17:07:34 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 17:07:34 WORKER: args: ()
# 17:07:34 WORKER: kwargs: {'budget': 1.0, 'config': {'cs_momentum': 0.962411679116496, 'num_filters_2': 23, 'cs_optimizer': 'SGD', 'num_filters_3': 19, 'num_filters_1': 30, 'lr': 0.0003918739911308217, 'num_conv_layers': 3}, 'working_directory': '.'}
# 17:07:38 WORKER: done with job (0, 0, 1), trying to register it.
# 17:07:38 DISPATCHER: job (0, 0, 1) finished
# 17:07:38 WORKER: registered result for job (0, 0, 1) with dispatcher
# 17:07:38 DISPATCHER: register_result: lock acquired
# 17:07:38 DISPATCHER: job (0, 0, 1) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184 finished
# 17:07:38 job_id: (0, 0, 1)
# kwargs: {'budget': 1.0, 'config': {'cs_momentum': 0.962411679116496, 'num_filters_2': 23, 'cs_optimizer': 'SGD', 'num_filters_3': 19, 'num_filters_1': 30, 'lr': 0.0003918739911308217, 'num_conv_layers': 3}, 'working_directory': '.'}
# result: {'info': {'test_accuracy': 0.0795, 'train_accuracy': 0.077880859375, 'valid_accuracy': 0.0859375, 'model': 'Sequential(\n  (conv0): Conv2d(1, 30, kernel_size=(3, 3), stride=(1, 1))\n  (rel0): ReLU()\n  (pool0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv1): Conv2d(30, 23, kernel_size=(3, 3), stride=(1, 1))\n  (rel1): ReLU()\n  (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv2): Conv2d(23, 19, kernel_size=(3, 3), stride=(1, 1))\n  (rel2): ReLU()\n  (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=19, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}, 'loss': 0.9140625}
# exception: None
#
# 17:07:38 job_callback for (0, 0, 1) started
# 17:07:38 DISPATCHER: Trying to submit another job.
# 17:07:38 job_callback for (0, 0, 1) got condition
# 17:07:38 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 17:07:38 Only 2 run(s) for budget 1.000000 available, need more than 9 -> can't build model!
# 17:07:38 HBMASTER: Trying to run another job!
# 17:07:38 job_callback for (0, 0, 1) finished
# 17:07:38 start sampling a new configuration.
# 17:07:38 done sampling a new configuration.
# 17:07:38 HBMASTER: schedule new run for iteration 0
# 17:07:38 HBMASTER: trying submitting job (0, 0, 2) to dispatcher
# 17:07:38 HBMASTER: submitting job (0, 0, 2) to dispatcher
# 17:07:38 DISPATCHER: trying to submit job (0, 0, 2)
# 17:07:38 DISPATCHER: trying to notify the job_runner thread.
# 17:07:38 HBMASTER: job (0, 0, 2) submitted to dispatcher
# 17:07:38 DISPATCHER: Trying to submit another job.
# 17:07:38 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 17:07:38 DISPATCHER: starting job (0, 0, 2) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:07:38 DISPATCHER: job (0, 0, 2) dispatched on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:07:38 WORKER: start processing job (0, 0, 2)
# 17:07:38 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 17:07:38 WORKER: args: ()
# 17:07:38 WORKER: kwargs: {'budget': 1.0, 'config': {'num_filters_2': 18, 'num_conv_layers': 2, 'num_filters_1': 5, 'lr': 0.002342517850671262, 'cs_optimizer': 'Adam'}, 'working_directory': '.'}
# 17:07:40 WORKER: done with job (0, 0, 2), trying to register it.
# 17:07:40 WORKER: registered result for job (0, 0, 2) with dispatcher
# 17:07:40 DISPATCHER: job (0, 0, 2) finished
# 17:07:40 DISPATCHER: register_result: lock acquired
# 17:07:40 DISPATCHER: job (0, 0, 2) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184 finished
# 17:07:40 job_id: (0, 0, 2)
# kwargs: {'budget': 1.0, 'config': {'num_filters_2': 18, 'num_conv_layers': 2, 'num_filters_1': 5, 'lr': 0.002342517850671262, 'cs_optimizer': 'Adam'}, 'working_directory': '.'}
# result: {'info': {'test_accuracy': 0.8847, 'train_accuracy': 0.8974609375, 'valid_accuracy': 0.900390625, 'model': 'Sequential(\n  (conv0): Conv2d(1, 5, kernel_size=(3, 3), stride=(1, 1))\n  (rel0): ReLU()\n  (pool0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv1): Conv2d(5, 18, kernel_size=(3, 3), stride=(1, 1))\n  (rel1): ReLU()\n  (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=450, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}, 'loss': 0.099609375}
# exception: None
#
# 17:07:40 job_callback for (0, 0, 2) started
# 17:07:40 DISPATCHER: Trying to submit another job.
# 17:07:40 job_callback for (0, 0, 2) got condition
# 17:07:40 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 17:07:40 Only 3 run(s) for budget 1.000000 available, need more than 9 -> can't build model!
# 17:07:40 HBMASTER: Trying to run another job!
# 17:07:40 job_callback for (0, 0, 2) finished
# 17:07:40 start sampling a new configuration.
# 17:07:40 done sampling a new configuration.
# 17:07:40 HBMASTER: schedule new run for iteration 0
# 17:07:40 HBMASTER: trying submitting job (0, 0, 3) to dispatcher
# 17:07:40 HBMASTER: submitting job (0, 0, 3) to dispatcher
# 17:07:40 DISPATCHER: trying to submit job (0, 0, 3)
# 17:07:40 DISPATCHER: trying to notify the job_runner thread.
# 17:07:40 HBMASTER: job (0, 0, 3) submitted to dispatcher
# 17:07:40 DISPATCHER: Trying to submit another job.
# 17:07:40 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 17:07:40 DISPATCHER: starting job (0, 0, 3) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:07:40 DISPATCHER: job (0, 0, 3) dispatched on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:07:40 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 17:07:40 WORKER: start processing job (0, 0, 3)
# 17:07:40 WORKER: args: ()
# 17:07:40 WORKER: kwargs: {'budget': 1.0, 'config': {'cs_momentum': 0.7382207220938947, 'num_filters_2': 32, 'cs_optimizer': 'SGD', 'num_filters_3': 17, 'num_filters_1': 27, 'lr': 0.00848903975386481, 'num_conv_layers': 3}, 'working_directory': '.'}
# 17:07:44 WORKER: done with job (0, 0, 3), trying to register it.
# 17:07:44 WORKER: registered result for job (0, 0, 3) with dispatcher
# 17:07:44 DISPATCHER: job (0, 0, 3) finished
# 17:07:44 DISPATCHER: register_result: lock acquired
# 17:07:44 DISPATCHER: job (0, 0, 3) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184 finished
# 17:07:44 job_id: (0, 0, 3)
# kwargs: {'budget': 1.0, 'config': {'cs_momentum': 0.7382207220938947, 'num_filters_2': 32, 'cs_optimizer': 'SGD', 'num_filters_3': 17, 'num_filters_1': 27, 'lr': 0.00848903975386481, 'num_conv_layers': 3}, 'working_directory': '.'}
# result: {'info': {'test_accuracy': 0.1838, 'train_accuracy': 0.17724609375, 'valid_accuracy': 0.185546875, 'model': 'Sequential(\n  (conv0): Conv2d(1, 27, kernel_size=(3, 3), stride=(1, 1))\n  (rel0): ReLU()\n  (pool0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv1): Conv2d(27, 32, kernel_size=(3, 3), stride=(1, 1))\n  (rel1): ReLU()\n  (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv2): Conv2d(32, 17, kernel_size=(3, 3), stride=(1, 1))\n  (rel2): ReLU()\n  (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=17, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}, 'loss': 0.814453125}
# exception: None
#
# 17:07:44 job_callback for (0, 0, 3) started
# 17:07:44 DISPATCHER: Trying to submit another job.
# 17:07:44 job_callback for (0, 0, 3) got condition
# 17:07:44 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 17:07:44 Only 4 run(s) for budget 1.000000 available, need more than 9 -> can't build model!
# 17:07:44 HBMASTER: Trying to run another job!
# 17:07:44 job_callback for (0, 0, 3) finished
# 17:07:44 start sampling a new configuration.
# 17:07:44 done sampling a new configuration.
# 17:07:44 HBMASTER: schedule new run for iteration 0
# 17:07:44 HBMASTER: trying submitting job (0, 0, 4) to dispatcher
# 17:07:44 HBMASTER: submitting job (0, 0, 4) to dispatcher
# 17:07:44 DISPATCHER: trying to submit job (0, 0, 4)
# 17:07:44 DISPATCHER: trying to notify the job_runner thread.
# 17:07:44 HBMASTER: job (0, 0, 4) submitted to dispatcher
# 17:07:44 DISPATCHER: Trying to submit another job.
# 17:07:44 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 17:07:44 DISPATCHER: starting job (0, 0, 4) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:07:44 DISPATCHER: job (0, 0, 4) dispatched on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:07:44 WORKER: start processing job (0, 0, 4)
# 17:07:44 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 17:07:44 WORKER: args: ()
# 17:07:44 WORKER: kwargs: {'budget': 1.0, 'config': {'cs_momentum': 0.48667471630655734, 'num_filters_2': 28, 'cs_optimizer': 'SGD', 'num_filters_1': 30, 'lr': 0.06300641147951135, 'num_conv_layers': 2}, 'working_directory': '.'}
# 17:07:49 WORKER: done with job (0, 0, 4), trying to register it.
# 17:07:49 WORKER: registered result for job (0, 0, 4) with dispatcher
# 17:07:49 DISPATCHER: job (0, 0, 4) finished
# 17:07:49 DISPATCHER: register_result: lock acquired
# 17:07:49 DISPATCHER: job (0, 0, 4) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184 finished
# 17:07:49 job_id: (0, 0, 4)
# kwargs: {'budget': 1.0, 'config': {'cs_momentum': 0.48667471630655734, 'num_filters_2': 28, 'cs_optimizer': 'SGD', 'num_filters_1': 30, 'lr': 0.06300641147951135, 'num_conv_layers': 2}, 'working_directory': '.'}
# result: {'info': {'test_accuracy': 0.9193, 'train_accuracy': 0.93359375, 'valid_accuracy': 0.90625, 'model': 'Sequential(\n  (conv0): Conv2d(1, 30, kernel_size=(3, 3), stride=(1, 1))\n  (rel0): ReLU()\n  (pool0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv1): Conv2d(30, 28, kernel_size=(3, 3), stride=(1, 1))\n  (rel1): ReLU()\n  (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=700, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}, 'loss': 0.09375}
# exception: None
#
# 17:07:49 job_callback for (0, 0, 4) started
# 17:07:49 DISPATCHER: Trying to submit another job.
# 17:07:49 job_callback for (0, 0, 4) got condition
# 17:07:49 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 17:07:49 Only 5 run(s) for budget 1.000000 available, need more than 9 -> can't build model!
# 17:07:49 HBMASTER: Trying to run another job!
# 17:07:49 job_callback for (0, 0, 4) finished
# 17:07:49 start sampling a new configuration.
# 17:07:49 done sampling a new configuration.
# 17:07:49 HBMASTER: schedule new run for iteration 0
# 17:07:49 HBMASTER: trying submitting job (0, 0, 5) to dispatcher
# 17:07:49 HBMASTER: submitting job (0, 0, 5) to dispatcher
# 17:07:49 DISPATCHER: trying to submit job (0, 0, 5)
# 17:07:49 DISPATCHER: trying to notify the job_runner thread.
# 17:07:49 HBMASTER: job (0, 0, 5) submitted to dispatcher
# 17:07:49 DISPATCHER: Trying to submit another job.
# 17:07:49 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 17:07:49 DISPATCHER: starting job (0, 0, 5) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:07:49 WORKER: start processing job (0, 0, 5)
# 17:07:49 DISPATCHER: job (0, 0, 5) dispatched on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:07:49 WORKER: args: ()
# 17:07:49 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 17:07:49 WORKER: kwargs: {'budget': 1.0, 'config': {'num_conv_layers': 1, 'num_filters_1': 11, 'lr': 3.931959776435283e-05, 'cs_optimizer': 'Adam'}, 'working_directory': '.'}
# 17:07:50 WORKER: done with job (0, 0, 5), trying to register it.
# 17:07:50 WORKER: registered result for job (0, 0, 5) with dispatcher
# 17:07:50 DISPATCHER: job (0, 0, 5) finished
# 17:07:50 DISPATCHER: register_result: lock acquired
# 17:07:50 DISPATCHER: job (0, 0, 5) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184 finished
# 17:07:50 job_id: (0, 0, 5)
# kwargs: {'budget': 1.0, 'config': {'num_conv_layers': 1, 'num_filters_1': 11, 'lr': 3.931959776435283e-05, 'cs_optimizer': 'Adam'}, 'working_directory': '.'}
# result: {'info': {'test_accuracy': 0.5228, 'train_accuracy': 0.533203125, 'valid_accuracy': 0.552734375, 'model': 'Sequential(\n  (conv0): Conv2d(1, 11, kernel_size=(3, 3), stride=(1, 1))\n  (rel0): ReLU()\n  (pool0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=1859, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}, 'loss': 0.447265625}
# exception: None
#
# 17:07:50 job_callback for (0, 0, 5) started
# 17:07:50 DISPATCHER: Trying to submit another job.
# 17:07:50 job_callback for (0, 0, 5) got condition
# 17:07:50 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 17:07:50 Only 6 run(s) for budget 1.000000 available, need more than 9 -> can't build model!
# 17:07:50 HBMASTER: Trying to run another job!
# 17:07:50 job_callback for (0, 0, 5) finished
# 17:07:50 start sampling a new configuration.
# 17:07:50 done sampling a new configuration.
# 17:07:50 HBMASTER: schedule new run for iteration 0
# 17:07:50 HBMASTER: trying submitting job (0, 0, 6) to dispatcher
# 17:07:50 HBMASTER: submitting job (0, 0, 6) to dispatcher
# 17:07:50 DISPATCHER: trying to submit job (0, 0, 6)
# 17:07:50 DISPATCHER: trying to notify the job_runner thread.
# 17:07:50 HBMASTER: job (0, 0, 6) submitted to dispatcher
# 17:07:50 DISPATCHER: Trying to submit another job.
# 17:07:50 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 17:07:50 DISPATCHER: starting job (0, 0, 6) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:07:50 DISPATCHER: job (0, 0, 6) dispatched on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:07:50 WORKER: start processing job (0, 0, 6)
# 17:07:50 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 17:07:50 WORKER: args: ()
# 17:07:50 WORKER: kwargs: {'budget': 1.0, 'config': {'cs_momentum': 0.6841708449710965, 'num_conv_layers': 1, 'num_filters_1': 31, 'lr': 1.6993150489141215e-06, 'cs_optimizer': 'SGD'}, 'working_directory': '.'}
# 17:07:54 WORKER: done with job (0, 0, 6), trying to register it.
# 17:07:54 WORKER: registered result for job (0, 0, 6) with dispatcher
# 17:07:54 DISPATCHER: job (0, 0, 6) finished
# 17:07:54 DISPATCHER: register_result: lock acquired
# 17:07:54 DISPATCHER: job (0, 0, 6) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184 finished
# 17:07:54 job_id: (0, 0, 6)
# kwargs: {'budget': 1.0, 'config': {'cs_momentum': 0.6841708449710965, 'num_conv_layers': 1, 'num_filters_1': 31, 'lr': 1.6993150489141215e-06, 'cs_optimizer': 'SGD'}, 'working_directory': '.'}
# result: {'info': {'test_accuracy': 0.1555, 'train_accuracy': 0.154296875, 'valid_accuracy': 0.1640625, 'model': 'Sequential(\n  (conv0): Conv2d(1, 31, kernel_size=(3, 3), stride=(1, 1))\n  (rel0): ReLU()\n  (pool0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=5239, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}, 'loss': 0.8359375}
# exception: None
#
# 17:07:54 job_callback for (0, 0, 6) started
# 17:07:54 DISPATCHER: Trying to submit another job.
# 17:07:54 job_callback for (0, 0, 6) got condition
# 17:07:54 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 17:07:54 Only 7 run(s) for budget 1.000000 available, need more than 9 -> can't build model!
# 17:07:54 HBMASTER: Trying to run another job!
# 17:07:54 job_callback for (0, 0, 6) finished
# 17:07:54 start sampling a new configuration.
# 17:07:54 done sampling a new configuration.
# 17:07:54 HBMASTER: schedule new run for iteration 0
# 17:07:54 HBMASTER: trying submitting job (0, 0, 7) to dispatcher
# 17:07:54 HBMASTER: submitting job (0, 0, 7) to dispatcher
# 17:07:54 DISPATCHER: trying to submit job (0, 0, 7)
# 17:07:54 DISPATCHER: trying to notify the job_runner thread.
# 17:07:54 HBMASTER: job (0, 0, 7) submitted to dispatcher
# 17:07:54 DISPATCHER: Trying to submit another job.
# 17:07:54 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 17:07:54 DISPATCHER: starting job (0, 0, 7) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:07:54 DISPATCHER: job (0, 0, 7) dispatched on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:07:54 WORKER: start processing job (0, 0, 7)
# 17:07:54 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 17:07:54 WORKER: args: ()
# 17:07:54 WORKER: kwargs: {'budget': 1.0, 'config': {'num_filters_2': 32, 'num_conv_layers': 2, 'num_filters_1': 21, 'lr': 2.385644323446427e-05, 'cs_optimizer': 'Adam'}, 'working_directory': '.'}
# 17:07:57 WORKER: done with job (0, 0, 7), trying to register it.
# 17:07:57 WORKER: registered result for job (0, 0, 7) with dispatcher
# 17:07:57 DISPATCHER: job (0, 0, 7) finished
# 17:07:57 DISPATCHER: register_result: lock acquired
# 17:07:57 DISPATCHER: job (0, 0, 7) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184 finished
# 17:07:57 job_id: (0, 0, 7)
# kwargs: {'budget': 1.0, 'config': {'num_filters_2': 32, 'num_conv_layers': 2, 'num_filters_1': 21, 'lr': 2.385644323446427e-05, 'cs_optimizer': 'Adam'}, 'working_directory': '.'}
# result: {'info': {'test_accuracy': 0.2675, 'train_accuracy': 0.268310546875, 'valid_accuracy': 0.26171875, 'model': 'Sequential(\n  (conv0): Conv2d(1, 21, kernel_size=(3, 3), stride=(1, 1))\n  (rel0): ReLU()\n  (pool0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv1): Conv2d(21, 32, kernel_size=(3, 3), stride=(1, 1))\n  (rel1): ReLU()\n  (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=800, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}, 'loss': 0.73828125}
# exception: None
#
# 17:07:57 job_callback for (0, 0, 7) started
# 17:07:57 job_callback for (0, 0, 7) got condition
# 17:07:57 DISPATCHER: Trying to submit another job.
# 17:07:57 HBMASTER: Trying to run another job!
# 17:07:57 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 17:07:57 job_callback for (0, 0, 7) finished
# 17:07:57 start sampling a new configuration.
# 17:07:57 done sampling a new configuration.
# 17:07:57 HBMASTER: schedule new run for iteration 0
# 17:07:57 HBMASTER: trying submitting job (0, 0, 8) to dispatcher
# 17:07:57 HBMASTER: submitting job (0, 0, 8) to dispatcher
# 17:07:57 DISPATCHER: trying to submit job (0, 0, 8)
# 17:07:57 DISPATCHER: trying to notify the job_runner thread.
# 17:07:57 HBMASTER: job (0, 0, 8) submitted to dispatcher
# 17:07:57 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 17:07:57 DISPATCHER: Trying to submit another job.
# 17:07:57 DISPATCHER: starting job (0, 0, 8) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:07:57 DISPATCHER: job (0, 0, 8) dispatched on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:07:57 WORKER: start processing job (0, 0, 8)
# 17:07:57 WORKER: args: ()
# 17:07:57 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 17:07:57 WORKER: kwargs: {'budget': 1.0, 'config': {'cs_momentum': 0.7394099124908682, 'num_filters_2': 30, 'cs_optimizer': 'SGD', 'num_filters_3': 15, 'num_filters_1': 31, 'lr': 0.00025416668009291374, 'num_conv_layers': 3}, 'working_directory': '.'}
# 17:08:02 WORKER: done with job (0, 0, 8), trying to register it.
# 17:08:02 WORKER: registered result for job (0, 0, 8) with dispatcher
# 17:08:02 DISPATCHER: job (0, 0, 8) finished
# 17:08:02 DISPATCHER: register_result: lock acquired
# 17:08:02 DISPATCHER: job (0, 0, 8) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184 finished
# 17:08:02 job_id: (0, 0, 8)
# kwargs: {'budget': 1.0, 'config': {'cs_momentum': 0.7394099124908682, 'num_filters_2': 30, 'cs_optimizer': 'SGD', 'num_filters_3': 15, 'num_filters_1': 31, 'lr': 0.00025416668009291374, 'num_conv_layers': 3}, 'working_directory': '.'}
# result: {'info': {'test_accuracy': 0.101, 'train_accuracy': 0.09765625, 'valid_accuracy': 0.109375, 'model': 'Sequential(\n  (conv0): Conv2d(1, 31, kernel_size=(3, 3), stride=(1, 1))\n  (rel0): ReLU()\n  (pool0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv1): Conv2d(31, 30, kernel_size=(3, 3), stride=(1, 1))\n  (rel1): ReLU()\n  (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv2): Conv2d(30, 15, kernel_size=(3, 3), stride=(1, 1))\n  (rel2): ReLU()\n  (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=15, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}, 'loss': 0.890625}
# exception: None
# 17:08:02 job_callback for (0, 0, 8) started
# 17:08:02 DISPATCHER: Trying to submit another job.
# 17:08:02 job_callback for (0, 0, 8) got condition
# 17:08:02 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 17:08:02 HBMASTER: Trying to run another job!
# 17:08:02 job_callback for (0, 0, 8) finished
# 17:08:02 ITERATION: Advancing config (0, 0, 0) to next budget 3.000000
# 17:08:02 ITERATION: Advancing config (0, 0, 2) to next budget 3.000000
# 17:08:02 ITERATION: Advancing config (0, 0, 4) to next budget 3.000000
# 17:08:02 HBMASTER: schedule new run for iteration 0
# 17:08:02 HBMASTER: trying submitting job (0, 0, 0) to dispatcher
# 17:08:02 HBMASTER: submitting job (0, 0, 0) to dispatcher
# 17:08:02 DISPATCHER: trying to submit job (0, 0, 0)
# 17:08:02 DISPATCHER: trying to notify the job_runner thread.
# 17:08:02 HBMASTER: job (0, 0, 0) submitted to dispatcher
# 17:08:02 DISPATCHER: Trying to submit another job.
# 17:08:02 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 17:08:02 DISPATCHER: starting job (0, 0, 0) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:08:02 DISPATCHER: job (0, 0, 0) dispatched on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:08:02 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 17:08:02 WORKER: start processing job (0, 0, 0)
# 17:08:02 WORKER: args: ()
# 17:08:02 WORKER: kwargs: {'budget': 3.0, 'config': {'num_conv_layers': 1, 'num_filters_1': 15, 'lr': 0.009115504957477365, 'cs_optimizer': 'Adam'}, 'working_directory': '.'}
# 17:08:05 WORKER: done with job (0, 0, 0), trying to register it.
# 17:08:05 WORKER: registered result for job (0, 0, 0) with dispatcher
# 17:08:05 DISPATCHER: job (0, 0, 0) finished
# 17:08:05 DISPATCHER: register_result: lock acquired
# 17:08:05 DISPATCHER: job (0, 0, 0) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184 finished
# 17:08:05 job_id: (0, 0, 0)
# kwargs: {'budget': 3.0, 'config': {'num_conv_layers': 1, 'num_filters_1': 15, 'lr': 0.009115504957477365, 'cs_optimizer': 'Adam'}, 'working_directory': '.'}
# result: {'info': {'test_accuracy': 0.9536, 'train_accuracy': 0.98828125, 'valid_accuracy': 0.958984375, 'model': 'Sequential(\n  (conv0): Conv2d(1, 15, kernel_size=(3, 3), stride=(1, 1))\n  (rel0): ReLU()\n  (pool0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=2535, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}, 'loss': 0.041015625}
# exception: None
#
# 17:08:05 job_callback for (0, 0, 0) started
# 17:08:05 DISPATCHER: Trying to submit another job.
# 17:08:05 job_callback for (0, 0, 0) got condition
# 17:08:05 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 17:08:05 Only 1 run(s) for budget 3.000000 available, need more than 9 -> can't build model!
# 17:08:05 HBMASTER: Trying to run another job!
# 17:08:05 job_callback for (0, 0, 0) finished
# 17:08:05 HBMASTER: schedule new run for iteration 0
# 17:08:05 HBMASTER: trying submitting job (0, 0, 2) to dispatcher
# 17:08:05 HBMASTER: submitting job (0, 0, 2) to dispatcher
# 17:08:05 DISPATCHER: trying to submit job (0, 0, 2)
# 17:08:05 DISPATCHER: trying to notify the job_runner thread.
# 17:08:05 HBMASTER: job (0, 0, 2) submitted to dispatcher
# 17:08:05 DISPATCHER: Trying to submit another job.
# 17:08:05 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 17:08:05 DISPATCHER: starting job (0, 0, 2) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:08:05 DISPATCHER: job (0, 0, 2) dispatched on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:08:05 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 17:08:05 WORKER: start processing job (0, 0, 2)
# 17:08:05 WORKER: args: ()
# 17:08:05 WORKER: kwargs: {'budget': 3.0, 'config': {'num_filters_2': 18, 'num_conv_layers': 2, 'num_filters_1': 5, 'lr': 0.002342517850671262, 'cs_optimizer': 'Adam'}, 'working_directory': '.'}
# 17:08:08 WORKER: done with job (0, 0, 2), trying to register it.
# 17:08:08 WORKER: registered result for job (0, 0, 2) with dispatcher
# 17:08:08 DISPATCHER: job (0, 0, 2) finished
# 17:08:08 DISPATCHER: register_result: lock acquired
# 17:08:08 DISPATCHER: job (0, 0, 2) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184 finished
# 17:08:08 job_id: (0, 0, 2)
# kwargs: {'budget': 3.0, 'config': {'num_filters_2': 18, 'num_conv_layers': 2, 'num_filters_1': 5, 'lr': 0.002342517850671262, 'cs_optimizer': 'Adam'}, 'working_directory': '.'}
# result: {'info': {'test_accuracy': 0.9387, 'train_accuracy': 0.96044921875, 'valid_accuracy': 0.935546875, 'model': 'Sequential(\n  (conv0): Conv2d(1, 5, kernel_size=(3, 3), stride=(1, 1))\n  (rel0): ReLU()\n  (pool0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv1): Conv2d(5, 18, kernel_size=(3, 3), stride=(1, 1))\n  (rel1): ReLU()\n  (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=450, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}, 'loss': 0.064453125}
# exception: None
#
# 17:08:08 job_callback for (0, 0, 2) started
# 17:08:08 DISPATCHER: Trying to submit another job.
# 17:08:08 job_callback for (0, 0, 2) got condition
# 17:08:08 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 17:08:08 Only 2 run(s) for budget 3.000000 available, need more than 9 -> can't build model!
# 17:08:08 HBMASTER: Trying to run another job!
# 17:08:08 job_callback for (0, 0, 2) finished
# 17:08:08 HBMASTER: schedule new run for iteration 0
# 17:08:08 HBMASTER: trying submitting job (0, 0, 4) to dispatcher
# 17:08:08 HBMASTER: submitting job (0, 0, 4) to dispatcher
# 17:08:08 DISPATCHER: trying to submit job (0, 0, 4)
# 17:08:08 DISPATCHER: trying to notify the job_runner thread.
# 17:08:08 HBMASTER: job (0, 0, 4) submitted to dispatcher
# 17:08:08 DISPATCHER: Trying to submit another job.
# 17:08:08 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 17:08:08 DISPATCHER: starting job (0, 0, 4) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:08:08 DISPATCHER: job (0, 0, 4) dispatched on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:08:08 WORKER: start processing job (0, 0, 4)
# 17:08:08 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 17:08:08 WORKER: args: ()
# 17:08:08 WORKER: kwargs: {'budget': 3.0, 'config': {'cs_momentum': 0.48667471630655734, 'num_filters_2': 28, 'cs_optimizer': 'SGD', 'num_filters_1': 30, 'lr': 0.06300641147951135, 'num_conv_layers': 2}, 'working_directory': '.'}
# 17:08:16 WORKER: done with job (0, 0, 4), trying to register it.
# 17:08:16 WORKER: registered result for job (0, 0, 4) with dispatcher
# 17:08:16 DISPATCHER: job (0, 0, 4) finished
# 17:08:16 DISPATCHER: register_result: lock acquired
# 17:08:16 DISPATCHER: job (0, 0, 4) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184 finished
# 17:08:16 job_id: (0, 0, 4)
# kwargs: {'budget': 3.0, 'config': {'cs_momentum': 0.48667471630655734, 'num_filters_2': 28, 'cs_optimizer': 'SGD', 'num_filters_1': 30, 'lr': 0.06300641147951135, 'num_conv_layers': 2}, 'working_directory': '.'}
# result: {'info': {'test_accuracy': 0.9566, 'train_accuracy': 0.968994140625, 'valid_accuracy': 0.947265625, 'model': 'Sequential(\n  (conv0): Conv2d(1, 30, kernel_size=(3, 3), stride=(1, 1))\n  (rel0): ReLU()\n  (pool0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv1): Conv2d(30, 28, kernel_size=(3, 3), stride=(1, 1))\n  (rel1): ReLU()\n  (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=700, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}, 'loss': 0.052734375}
# exception: None
#
# 17:08:16 job_callback for (0, 0, 4) started
# 17:08:16 DISPATCHER: Trying to submit another job.
# 17:08:16 job_callback for (0, 0, 4) got condition
# 17:08:16 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 17:08:16 Only 3 run(s) for budget 3.000000 available, need more than 9 -> can't build model!
# 17:08:16 HBMASTER: Trying to run another job!
# 17:08:16 job_callback for (0, 0, 4) finished
# 17:08:16 ITERATION: Advancing config (0, 0, 0) to next budget 9.000000
# 17:08:16 HBMASTER: schedule new run for iteration 0
# 17:08:16 HBMASTER: trying submitting job (0, 0, 0) to dispatcher
# 17:08:16 HBMASTER: submitting job (0, 0, 0) to dispatcher
# 17:08:16 DISPATCHER: trying to submit job (0, 0, 0)
# 17:08:16 DISPATCHER: trying to notify the job_runner thread.
# 17:08:16 HBMASTER: job (0, 0, 0) submitted to dispatcher
# 17:08:16 DISPATCHER: Trying to submit another job.
# 17:08:16 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 17:08:16 DISPATCHER: starting job (0, 0, 0) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:08:16 DISPATCHER: job (0, 0, 0) dispatched on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:08:16 WORKER: start processing job (0, 0, 0)
# 17:08:16 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 17:08:16 WORKER: args: ()
# 17:08:16 WORKER: kwargs: {'budget': 9.0, 'config': {'num_conv_layers': 1, 'num_filters_1': 15, 'lr': 0.009115504957477365, 'cs_optimizer': 'Adam'}, 'working_directory': '.'}
# 17:08:24 WORKER: done with job (0, 0, 0), trying to register it.
# 17:08:24 WORKER: registered result for job (0, 0, 0) with dispatcher
# 17:08:24 DISPATCHER: job (0, 0, 0) finished
# 17:08:24 DISPATCHER: register_result: lock acquired
# 17:08:24 DISPATCHER: job (0, 0, 0) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184 finished
# 17:08:24 job_id: (0, 0, 0)
# kwargs: {'budget': 9.0, 'config': {'num_conv_layers': 1, 'num_filters_1': 15, 'lr': 0.009115504957477365, 'cs_optimizer': 'Adam'}, 'working_directory': '.'}
# result: {'info': {'test_accuracy': 0.9516, 'train_accuracy': 0.99951171875, 'valid_accuracy': 0.955078125, 'model': 'Sequential(\n  (conv0): Conv2d(1, 15, kernel_size=(3, 3), stride=(1, 1))\n  (rel0): ReLU()\n  (pool0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=2535, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}, 'loss': 0.044921875}
# exception: None
#
# 17:08:24 job_callback for (0, 0, 0) started
# 17:08:24 DISPATCHER: Trying to submit another job.
# 17:08:24 job_callback for (0, 0, 0) got condition
# 17:08:24 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 17:08:24 Only 1 run(s) for budget 9.000000 available, need more than 9 -> can't build model!
# 17:08:24 HBMASTER: Trying to run another job!
# 17:08:24 job_callback for (0, 0, 0) finished
# 17:08:24 start sampling a new configuration.
# 17:08:24 done sampling a new configuration.
# 17:08:24 HBMASTER: schedule new run for iteration 1
# 17:08:24 HBMASTER: trying submitting job (1, 0, 0) to dispatcher
# 17:08:24 HBMASTER: submitting job (1, 0, 0) to dispatcher
# 17:08:24 DISPATCHER: trying to submit job (1, 0, 0)
# 17:08:24 DISPATCHER: trying to notify the job_runner thread.
# 17:08:24 HBMASTER: job (1, 0, 0) submitted to dispatcher
# 17:08:24 DISPATCHER: Trying to submit another job.
# 17:08:24 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 17:08:24 DISPATCHER: starting job (1, 0, 0) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:08:24 DISPATCHER: job (1, 0, 0) dispatched on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:08:24 WORKER: start processing job (1, 0, 0)
# 17:08:24 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 17:08:24 WORKER: args: ()
# 17:08:24 WORKER: kwargs: {'budget': 3.0, 'config': {'num_filters_2': 19, 'num_conv_layers': 2, 'num_filters_1': 11, 'lr': 3.751765715420666e-05, 'cs_optimizer': 'Adam'}, 'working_directory': '.'}
# 17:08:28 WORKER: done with job (1, 0, 0), trying to register it.
# 17:08:28 WORKER: registered result for job (1, 0, 0) with dispatcher
# 17:08:28 DISPATCHER: job (1, 0, 0) finished
# 17:08:28 DISPATCHER: register_result: lock acquired
# 17:08:28 DISPATCHER: job (1, 0, 0) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184 finished
# 17:08:28 job_id: (1, 0, 0)
# kwargs: {'budget': 3.0, 'config': {'num_filters_2': 19, 'num_conv_layers': 2, 'num_filters_1': 11, 'lr': 3.751765715420666e-05, 'cs_optimizer': 'Adam'}, 'working_directory': '.'}
# result: {'info': {'test_accuracy': 0.5048, 'train_accuracy': 0.544677734375, 'valid_accuracy': 0.5703125, 'model': 'Sequential(\n  (conv0): Conv2d(1, 11, kernel_size=(3, 3), stride=(1, 1))\n  (rel0): ReLU()\n  (pool0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv1): Conv2d(11, 19, kernel_size=(3, 3), stride=(1, 1))\n  (rel1): ReLU()\n  (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=475, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}, 'loss': 0.4296875}
# exception: None
#
# 17:08:28 job_callback for (1, 0, 0) started
# 17:08:28 DISPATCHER: Trying to submit another job.
# 17:08:28 job_callback for (1, 0, 0) got condition
# 17:08:28 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 17:08:28 Only 4 run(s) for budget 3.000000 available, need more than 9 -> can't build model!
# 17:08:28 HBMASTER: Trying to run another job!
# 17:08:28 job_callback for (1, 0, 0) finished
# 17:08:28 start sampling a new configuration.
# 17:08:28 done sampling a new configuration.
# 17:08:28 HBMASTER: schedule new run for iteration 1
# 17:08:28 HBMASTER: trying submitting job (1, 0, 1) to dispatcher
# 17:08:28 HBMASTER: submitting job (1, 0, 1) to dispatcher
# 17:08:28 DISPATCHER: trying to submit job (1, 0, 1)
# 17:08:28 DISPATCHER: trying to notify the job_runner thread.
# 17:08:28 HBMASTER: job (1, 0, 1) submitted to dispatcher
# 17:08:28 DISPATCHER: Trying to submit another job.
# 17:08:28 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 17:08:28 DISPATCHER: starting job (1, 0, 1) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:08:28 DISPATCHER: job (1, 0, 1) dispatched on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:08:28 WORKER: start processing job (1, 0, 1)
# 17:08:28 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 17:08:28 WORKER: args: ()
# 17:08:28 WORKER: kwargs: {'budget': 3.0, 'config': {'num_filters_2': 10, 'num_conv_layers': 2, 'num_filters_1': 32, 'lr': 0.002839043425554354, 'cs_optimizer': 'Adam'}, 'working_directory': '.'}
# 17:08:31 DISPATCHER: Starting worker discovery
# 17:08:31 DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# 17:08:31 DISPATCHER: Finished worker discovery
# 17:08:34 WORKER: done with job (1, 0, 1), trying to register it.
# 17:08:34 DISPATCHER: job (1, 0, 1) finished
# 17:08:34 WORKER: registered result for job (1, 0, 1) with dispatcher
# 17:08:34 DISPATCHER: register_result: lock acquired
# 17:08:34 DISPATCHER: job (1, 0, 1) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184 finished
# 17:08:34 job_id: (1, 0, 1)
# kwargs: {'budget': 3.0, 'config': {'num_filters_2': 10, 'num_conv_layers': 2, 'num_filters_1': 32, 'lr': 0.002839043425554354, 'cs_optimizer': 'Adam'}, 'working_directory': '.'}
# result: {'info': {'test_accuracy': 0.9625, 'train_accuracy': 0.97705078125, 'valid_accuracy': 0.958984375, 'model': 'Sequential(\n  (conv0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))\n  (rel0): ReLU()\n  (pool0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv1): Conv2d(32, 10, kernel_size=(3, 3), stride=(1, 1))\n  (rel1): ReLU()\n  (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=250, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}, 'loss': 0.041015625}
# exception: None
#
# 17:08:34 job_callback for (1, 0, 1) started
# 17:08:34 DISPATCHER: Trying to submit another job.
# 17:08:34 job_callback for (1, 0, 1) got condition
# 17:08:34 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 17:08:34 Only 5 run(s) for budget 3.000000 available, need more than 9 -> can't build model!
# 17:08:34 HBMASTER: Trying to run another job!
# 17:08:34 job_callback for (1, 0, 1) finished
# 17:08:34 start sampling a new configuration.
# 17:08:34 done sampling a new configuration.
# 17:08:34 HBMASTER: schedule new run for iteration 1
# 17:08:34 HBMASTER: trying submitting job (1, 0, 2) to dispatcher
# 17:08:34 HBMASTER: submitting job (1, 0, 2) to dispatcher
# 17:08:34 DISPATCHER: trying to submit job (1, 0, 2)
# 17:08:34 DISPATCHER: trying to notify the job_runner thread.
# 17:08:34 HBMASTER: job (1, 0, 2) submitted to dispatcher
# 17:08:34 DISPATCHER: Trying to submit another job.
# 17:08:34 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 17:08:34 DISPATCHER: starting job (1, 0, 2) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:08:34 DISPATCHER: job (1, 0, 2) dispatched on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:08:34 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 17:08:34 WORKER: start processing job (1, 0, 2)
# 17:08:34 WORKER: args: ()
# 17:08:34 WORKER: kwargs: {'budget': 3.0, 'config': {'cs_momentum': 0.5077602951934002, 'num_filters_2': 27, 'cs_optimizer': 'SGD', 'num_filters_3': 25, 'num_filters_1': 30, 'lr': 7.810852281030876e-05, 'num_conv_layers': 3}, 'working_directory': '.'}
# 17:08:42 WORKER: done with job (1, 0, 2), trying to register it.
# 17:08:42 WORKER: registered result for job (1, 0, 2) with dispatcher
# 17:08:42 DISPATCHER: job (1, 0, 2) finished
# 17:08:42 DISPATCHER: register_result: lock acquired
# 17:08:42 DISPATCHER: job (1, 0, 2) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184 finished
# 17:08:42 job_id: (1, 0, 2)
# kwargs: {'budget': 3.0, 'config': {'cs_momentum': 0.5077602951934002, 'num_filters_2': 27, 'cs_optimizer': 'SGD', 'num_filters_3': 25, 'num_filters_1': 30, 'lr': 7.810852281030876e-05, 'num_conv_layers': 3}, 'working_directory': '.'}
# result: {'info': {'test_accuracy': 0.1007, 'train_accuracy': 0.09765625, 'valid_accuracy': 0.109375, 'model': 'Sequential(\n  (conv0): Conv2d(1, 30, kernel_size=(3, 3), stride=(1, 1))\n  (rel0): ReLU()\n  (pool0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv1): Conv2d(30, 27, kernel_size=(3, 3), stride=(1, 1))\n  (rel1): ReLU()\n  (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv2): Conv2d(27, 25, kernel_size=(3, 3), stride=(1, 1))\n  (rel2): ReLU()\n  (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=25, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}, 'loss': 0.890625}
# exception: None
#
# 17:08:42 job_callback for (1, 0, 2) started
# 17:08:42 DISPATCHER: Trying to submit another job.
# 17:08:42 job_callback for (1, 0, 2) got condition
# 17:08:42 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 17:08:42 Only 6 run(s) for budget 3.000000 available, need more than 9 -> can't build model!
# 17:08:42 HBMASTER: Trying to run another job!
# 17:08:42 job_callback for (1, 0, 2) finished
# 17:08:42 ITERATION: Advancing config (1, 0, 1) to next budget 9.000000
# 17:08:42 HBMASTER: schedule new run for iteration 1
# 17:08:42 HBMASTER: trying submitting job (1, 0, 1) to dispatcher
# 17:08:42 HBMASTER: submitting job (1, 0, 1) to dispatcher
# 17:08:42 DISPATCHER: trying to submit job (1, 0, 1)
# 17:08:42 DISPATCHER: trying to notify the job_runner thread.
# 17:08:42 HBMASTER: job (1, 0, 1) submitted to dispatcher
# 17:08:42 DISPATCHER: Trying to submit another job.
# 17:08:42 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 17:08:42 DISPATCHER: starting job (1, 0, 1) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:08:42 DISPATCHER: job (1, 0, 1) dispatched on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:08:42 WORKER: start processing job (1, 0, 1)
# 17:08:42 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 17:08:42 WORKER: args: ()
# 17:08:42 WORKER: kwargs: {'budget': 9.0, 'config': {'num_filters_2': 10, 'num_conv_layers': 2, 'num_filters_1': 32, 'lr': 0.002839043425554354, 'cs_optimizer': 'Adam'}, 'working_directory': '.'}
# 17:08:57 WORKER: done with job (1, 0, 1), trying to register it.
# 17:08:57 DISPATCHER: job (1, 0, 1) finished
# 17:08:57 WORKER: registered result for job (1, 0, 1) with dispatcher
# 17:08:57 DISPATCHER: register_result: lock acquired
# 17:08:57 DISPATCHER: job (1, 0, 1) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184 finished
# 17:08:57 job_id: (1, 0, 1)
# kwargs: {'budget': 9.0, 'config': {'num_filters_2': 10, 'num_conv_layers': 2, 'num_filters_1': 32, 'lr': 0.002839043425554354, 'cs_optimizer': 'Adam'}, 'working_directory': '.'}
# result: {'info': {'test_accuracy': 0.9648, 'train_accuracy': 0.989501953125, 'valid_accuracy': 0.95703125, 'model': 'Sequential(\n  (conv0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))\n  (rel0): ReLU()\n  (pool0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv1): Conv2d(32, 10, kernel_size=(3, 3), stride=(1, 1))\n  (rel1): ReLU()\n  (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=250, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}, 'loss': 0.04296875}
# exception: None
#
# 17:08:57 job_callback for (1, 0, 1) started
# 17:08:57 DISPATCHER: Trying to submit another job.
# 17:08:57 job_callback for (1, 0, 1) got condition
# 17:08:57 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 17:08:57 Only 2 run(s) for budget 9.000000 available, need more than 9 -> can't build model!
# 17:08:57 HBMASTER: Trying to run another job!
# 17:08:57 job_callback for (1, 0, 1) finished
# 17:08:57 start sampling a new configuration.
# 17:08:57 done sampling a new configuration.
# 17:08:57 HBMASTER: schedule new run for iteration 2
# 17:08:57 HBMASTER: trying submitting job (2, 0, 0) to dispatcher
# 17:08:57 HBMASTER: submitting job (2, 0, 0) to dispatcher
# 17:08:57 DISPATCHER: trying to submit job (2, 0, 0)
# 17:08:57 DISPATCHER: trying to notify the job_runner thread.
# ...
# exception: None
#
# 17:13:49 job_callback for (10, 0, 1) started
# 17:13:49 DISPATCHER: Trying to submit another job.
# 17:13:49 job_callback for (10, 0, 1) got condition
# 17:13:49 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 17:13:49 HBMASTER: Trying to run another job!
# 17:13:49 job_callback for (10, 0, 1) finished
# 17:13:49 start sampling a new configuration.
# 17:13:49 best_vector: [1, 0.6612469527214357, 0.6890426859056025, 0.012109115408675653, 0.6353778037416535, 0.20421058213698584, 0.020023434973738707], 2.7219837370626556e-17, 3.465016368842656e-08, 9.431718204645607e-25
# 17:13:49 done sampling a new configuration.
# 17:13:49 HBMASTER: schedule new run for iteration 10
# 17:13:49 HBMASTER: trying submitting job (10, 0, 2) to dispatcher
# 17:13:49 HBMASTER: submitting job (10, 0, 2) to dispatcher
# 17:13:49 DISPATCHER: trying to submit job (10, 0, 2)
# 17:13:49 DISPATCHER: trying to notify the job_runner thread.
# 17:13:49 HBMASTER: job (10, 0, 2) submitted to dispatcher
# 17:13:49 DISPATCHER: Trying to submit another job.
# 17:13:49 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 17:13:49 DISPATCHER: starting job (10, 0, 2) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:13:49 DISPATCHER: job (10, 0, 2) dispatched on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:13:49 WORKER: start processing job (10, 0, 2)
# 17:13:49 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 17:13:49 WORKER: args: ()
# 17:13:49 WORKER: kwargs: {'budget': 3.0, 'config': {'cs_momentum': 0.629024025704237, 'num_filters_2': 9, 'cs_optimizer': 'SGD', 'num_filters_3': 4, 'num_filters_1': 4, 'lr': 0.0020241130439883066, 'num_conv_layers': 3}, 'working_directory': '.'}
# 17:13:51 WORKER: done with job (10, 0, 2), trying to register it.
# 17:13:51 WORKER: registered result for job (10, 0, 2) with dispatcher
# 17:13:51 DISPATCHER: job (10, 0, 2) finished
# 17:13:51 DISPATCHER: register_result: lock acquired
# 17:13:51 DISPATCHER: job (10, 0, 2) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184 finished
# 17:13:51 job_id: (10, 0, 2)
# kwargs: {'budget': 3.0, 'config': {'cs_momentum': 0.629024025704237, 'num_filters_2': 9, 'cs_optimizer': 'SGD', 'num_filters_3': 4, 'num_filters_1': 4, 'lr': 0.0020241130439883066, 'num_conv_layers': 3}, 'working_directory': '.'}
# result: {'info': {'test_accuracy': 0.1032, 'train_accuracy': 0.098876953125, 'valid_accuracy': 0.091796875, 'model': 'Sequential(\n  (conv0): Conv2d(1, 4, kernel_size=(3, 3), stride=(1, 1))\n  (rel0): ReLU()\n  (pool0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv1): Conv2d(4, 9, kernel_size=(3, 3), stride=(1, 1))\n  (rel1): ReLU()\n  (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv2): Conv2d(9, 4, kernel_size=(3, 3), stride=(1, 1))\n  (rel2): ReLU()\n  (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=4, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}, 'loss': 0.908203125}
# exception: None
#
# 17:13:51 job_callback for (10, 0, 2) started
# 17:13:51 DISPATCHER: Trying to submit another job.
# 17:13:51 job_callback for (10, 0, 2) got condition
# 17:13:51 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 17:13:51 HBMASTER: Trying to run another job!
# 17:13:51 job_callback for (10, 0, 2) finished
# 17:13:51 ITERATION: Advancing config (10, 0, 1) to next budget 9.000000
# 17:13:51 HBMASTER: schedule new run for iteration 10
# 17:13:51 HBMASTER: trying submitting job (10, 0, 1) to dispatcher
# 17:13:51 HBMASTER: submitting job (10, 0, 1) to dispatcher
# 17:13:51 DISPATCHER: trying to submit job (10, 0, 1)
# 17:13:51 DISPATCHER: trying to notify the job_runner thread.
# 17:13:51 HBMASTER: job (10, 0, 1) submitted to dispatcher
# 17:13:51 DISPATCHER: Trying to submit another job.
# 17:13:51 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 17:13:51 DISPATCHER: starting job (10, 0, 1) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:13:51 DISPATCHER: job (10, 0, 1) dispatched on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:13:51 WORKER: start processing job (10, 0, 1)
# 17:13:51 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 17:13:51 WORKER: args: ()
# 17:13:51 WORKER: kwargs: {'budget': 9.0, 'config': {'num_filters_2': 15, 'num_conv_layers': 2, 'num_filters_1': 20, 'lr': 0.0019496948346757815, 'cs_optimizer': 'Adam'}, 'working_directory': '.'}
# 17:14:03 WORKER: done with job (10, 0, 1), trying to register it.
# 17:14:03 WORKER: registered result for job (10, 0, 1) with dispatcher
# 17:14:03 DISPATCHER: job (10, 0, 1) finished
# 17:14:03 DISPATCHER: register_result: lock acquired
# 17:14:03 DISPATCHER: job (10, 0, 1) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184 finished
# 17:14:03 job_id: (10, 0, 1)
# kwargs: {'budget': 9.0, 'config': {'num_filters_2': 15, 'num_conv_layers': 2, 'num_filters_1': 20, 'lr': 0.0019496948346757815, 'cs_optimizer': 'Adam'}, 'working_directory': '.'}
# result: {'info': {'test_accuracy': 0.9665, 'train_accuracy': 0.99072265625, 'valid_accuracy': 0.958984375, 'model': 'Sequential(\n  (conv0): Conv2d(1, 20, kernel_size=(3, 3), stride=(1, 1))\n  (rel0): ReLU()\n  (pool0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv1): Conv2d(20, 15, kernel_size=(3, 3), stride=(1, 1))\n  (rel1): ReLU()\n  (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=375, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}, 'loss': 0.041015625}
# exception: None
#
# 17:14:03 job_callback for (10, 0, 1) started
# 17:14:03 DISPATCHER: Trying to submit another job.
# 17:14:03 job_callback for (10, 0, 1) got condition
# 17:14:03 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 17:14:03 done building a new model for budget 9.000000 based on 8/14 split
# Best loss for this budget:0.035156
#
#
#
#
#
# 17:14:03 HBMASTER: Trying to run another job!
# 17:14:03 job_callback for (10, 0, 1) finished
# 17:14:03 start sampling a new configuration.
# 17:14:03 best_vector: [1, 0.5306739144622807, 0.604965870286561, 0.3464500997343398, 0.6092434230532447, 0.37538474186101833, 0.0051311139181281495], 1.8184192997586707e-30, 0.005499281712049107, 4.954452376396952e-34
# 17:14:03 done sampling a new configuration.
# 17:14:03 HBMASTER: schedule new run for iteration 11
# 17:14:03 HBMASTER: trying submitting job (11, 0, 0) to dispatcher
# 17:14:03 HBMASTER: submitting job (11, 0, 0) to dispatcher
# 17:14:03 DISPATCHER: trying to submit job (11, 0, 0)
# 17:14:03 DISPATCHER: trying to notify the job_runner thread.
# 17:14:03 HBMASTER: job (11, 0, 0) submitted to dispatcher
# 17:14:03 DISPATCHER: Trying to submit another job.
# 17:14:03 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 17:14:03 DISPATCHER: starting job (11, 0, 0) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:14:03 DISPATCHER: job (11, 0, 0) dispatched on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:14:03 WORKER: start processing job (11, 0, 0)
# 17:14:03 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 17:14:03 WORKER: args: ()
# 17:14:03 WORKER: kwargs: {'budget': 9.0, 'config': {'cs_momentum': 0.6031509888227123, 'num_filters_2': 14, 'cs_optimizer': 'SGD', 'num_filters_1': 14, 'lr': 0.00045016276771967455, 'num_conv_layers': 2}, 'working_directory': '.'}
# 17:14:12 WORKER: done with job (11, 0, 0), trying to register it.
# 17:14:12 WORKER: registered result for job (11, 0, 0) with dispatcher
# 17:14:12 DISPATCHER: job (11, 0, 0) finished
# 17:14:12 DISPATCHER: register_result: lock acquired
# 17:14:12 DISPATCHER: job (11, 0, 0) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184 finished
# 17:14:12 job_id: (11, 0, 0)
# kwargs: {'budget': 9.0, 'config': {'cs_momentum': 0.6031509888227123, 'num_filters_2': 14, 'cs_optimizer': 'SGD', 'num_filters_1': 14, 'lr': 0.00045016276771967455, 'num_conv_layers': 2}, 'working_directory': '.'}
# result: {'info': {'test_accuracy': 0.4916, 'train_accuracy': 0.4931640625, 'valid_accuracy': 0.517578125, 'model': 'Sequential(\n  (conv0): Conv2d(1, 14, kernel_size=(3, 3), stride=(1, 1))\n  (rel0): ReLU()\n  (pool0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv1): Conv2d(14, 14, kernel_size=(3, 3), stride=(1, 1))\n  (rel1): ReLU()\n  (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=350, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}, 'loss': 0.482421875}
# exception: None
#
# 17:14:12 job_callback for (11, 0, 0) started
# 17:14:12 DISPATCHER: Trying to submit another job.
# 17:14:12 job_callback for (11, 0, 0) got condition
# 17:14:12 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 17:14:12 done building a new model for budget 9.000000 based on 8/15 split
# Best loss for this budget:0.035156
#
#
#
#
#
# 17:14:12 HBMASTER: Trying to run another job!
# 17:14:12 job_callback for (11, 0, 0) finished
# 17:14:12 start sampling a new configuration.
# 17:14:12 best_vector: [0, 0.6884443425425519, 0.31021909312422186, 0.5654906216759528, 0.5262687688739652, 0.6984202035888956, 0.0034563841029261466], 4.440030996623589e-26, 34.55899337328644, 1.5344300178950101e-24
# 17:14:12 done sampling a new configuration.
# 17:14:12 HBMASTER: schedule new run for iteration 11
# 17:14:12 HBMASTER: trying submitting job (11, 0, 1) to dispatcher
# 17:14:12 HBMASTER: submitting job (11, 0, 1) to dispatcher
# 17:14:12 DISPATCHER: trying to submit job (11, 0, 1)
# 17:14:12 DISPATCHER: trying to notify the job_runner thread.
# 17:14:12 HBMASTER: job (11, 0, 1) submitted to dispatcher
# 17:14:12 DISPATCHER: Trying to submit another job.
# 17:14:12 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 17:14:12 DISPATCHER: starting job (11, 0, 1) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:14:12 DISPATCHER: job (11, 0, 1) dispatched on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:14:12 WORKER: start processing job (11, 0, 1)
# 17:14:12 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 17:14:12 WORKER: args: ()
# 17:14:12 WORKER: kwargs: {'budget': 9.0, 'config': {'num_conv_layers': 1, 'num_filters_1': 20, 'lr': 0.002768354564022049, 'cs_optimizer': 'Adam'}, 'working_directory': '.'}
# 17:14:21 WORKER: done with job (11, 0, 1), trying to register it.
# 17:14:21 WORKER: registered result for job (11, 0, 1) with dispatcher
# 17:14:21 DISPATCHER: job (11, 0, 1) finished
# 17:14:21 DISPATCHER: register_result: lock acquired
# 17:14:21 DISPATCHER: job (11, 0, 1) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184 finished
# 17:14:21 job_id: (11, 0, 1)
# kwargs: {'budget': 9.0, 'config': {'num_conv_layers': 1, 'num_filters_1': 20, 'lr': 0.002768354564022049, 'cs_optimizer': 'Adam'}, 'working_directory': '.'}
# result: {'info': {'test_accuracy': 0.9512, 'train_accuracy': 0.998779296875, 'valid_accuracy': 0.970703125, 'model': 'Sequential(\n  (conv0): Conv2d(1, 20, kernel_size=(3, 3), stride=(1, 1))\n  (rel0): ReLU()\n  (pool0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=3380, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}, 'loss': 0.029296875}
# exception: None
#
# 17:14:21 job_callback for (11, 0, 1) started
# 17:14:21 DISPATCHER: Trying to submit another job.
# 17:14:21 job_callback for (11, 0, 1) got condition
# 17:14:21 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 17:14:21 done building a new model for budget 9.000000 based on 8/16 split
# Best loss for this budget:0.029297
#
#
#
#
#
# 17:14:21 HBMASTER: Trying to run another job!
# 17:14:21 job_callback for (11, 0, 1) finished
# 17:14:21 start sampling a new configuration.
# 17:14:22 best_vector: [0, 0.4376689586899054, 0.40069564545601877, 0.6370428700147016, 0.5180729893457627, 0.8406304894910379, 0.004841067909430685], 8.638335882533572e-30, 0.10161369299114123, 8.777732103221254e-31
# 17:14:22 done sampling a new configuration.
# 17:14:22 HBMASTER: schedule new run for iteration 11
# 17:14:22 HBMASTER: trying submitting job (11, 0, 2) to dispatcher
# 17:14:22 HBMASTER: submitting job (11, 0, 2) to dispatcher
# 17:14:22 DISPATCHER: trying to submit job (11, 0, 2)
# 17:14:22 DISPATCHER: trying to notify the job_runner thread.
# 17:14:22 HBMASTER: job (11, 0, 2) submitted to dispatcher
# 17:14:22 DISPATCHER: Trying to submit another job.
# 17:14:22 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 17:14:22 DISPATCHER: starting job (11, 0, 2) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:14:22 DISPATCHER: job (11, 0, 2) dispatched on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184
# 17:14:22 WORKER: start processing job (11, 0, 2)
# 17:14:22 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 17:14:22 WORKER: args: ()
# 17:14:22 WORKER: kwargs: {'budget': 9.0, 'config': {'num_filters_2': 28, 'num_conv_layers': 2, 'num_filters_1': 22, 'lr': 0.00015429249200004825, 'cs_optimizer': 'Adam'}, 'working_directory': '.'}
# 17:14:31 DISPATCHER: Starting worker discovery
# 17:14:31 DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# 17:14:31 DISPATCHER: Finished worker discovery
# 17:14:36 WORKER: done with job (11, 0, 2), trying to register it.
# 17:14:36 WORKER: registered result for job (11, 0, 2) with dispatcher
# 17:14:36 DISPATCHER: job (11, 0, 2) finished
# 17:14:36 DISPATCHER: register_result: lock acquired
# 17:14:36 DISPATCHER: job (11, 0, 2) on hpbandster.run_bohb_run_1.worker.Eduardo-XPS-Ubuntu.16781140505805629184 finished
# 17:14:36 job_id: (11, 0, 2)
# kwargs: {'budget': 9.0, 'config': {'num_filters_2': 28, 'num_conv_layers': 2, 'num_filters_1': 22, 'lr': 0.00015429249200004825, 'cs_optimizer': 'Adam'}, 'working_directory': '.'}
# result: {'info': {'test_accuracy': 0.9147, 'train_accuracy': 0.931640625, 'valid_accuracy': 0.912109375, 'model': 'Sequential(\n  (conv0): Conv2d(1, 22, kernel_size=(3, 3), stride=(1, 1))\n  (rel0): ReLU()\n  (pool0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (conv1): Conv2d(22, 28, kernel_size=(3, 3), stride=(1, 1))\n  (rel1): ReLU()\n  (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (flat): Flatten()\n  (lin): Linear(in_features=700, out_features=10, bias=True)\n  (logsoftmax): LogSoftmax()\n)'}, 'loss': 0.087890625}
# exception: None
#
# 17:14:36 job_callback for (11, 0, 2) started
# 17:14:36 DISPATCHER: Trying to submit another job.
# 17:14:36 job_callback for (11, 0, 2) got condition
# 17:14:36 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 17:14:36 done building a new model for budget 9.000000 based on 8/17 split
# Best loss for this budget:0.029297
#
#
#
#
#
# 17:14:36 HBMASTER: Trying to run another job!
# 17:14:36 job_callback for (11, 0, 2) finished
# 17:14:36 HBMASTER: shutdown initiated, shutdown_workers = True
# 17:14:36 WORKER: shutting down now!
# 17:14:36 DISPATCHER: Dispatcher shutting down
# Write result to file ./bohb_result.pkl
# 17:14:36 DISPATCHER: Trying to submit another job.
# 17:14:36 DISPATCHER: job_runner shutting down
# 17:14:36 DISPATCHER: discover_workers shutting down
# 17:14:36 DISPATCHER: 'discover_worker' thread exited
# 17:14:36 DISPATCHER: 'job_runner' thread exited
# 17:14:36 DISPATCHER: shut down complete

# %% [markdown]
# ### Evaluate result
#
# The result object which we dumped to disk contains all the runs with the different configurations.
# Here we will analyse it further. The [HpBandSter Analysis Example](https://automl.github.io/HpBandSter/build/html/auto_examples/plot_example_6_analysis.html) is there, if you need help.

# %%
#  load a saved result object if necessary
with open(result_file, 'rb') as f:
    result = pickle.load(f)

# %% [markdown]
# **Task:** Print the model of the best run, evaluated on the largest budget, with it's final validation error. *Tipp:* Have a look at the [HpBandSter Result Docs](https://automl.github.io/HpBandSter/build/html/core/result.html).

# %%
# From the next cell, to make "id2conf" works
import hpbandster.visualization as hpvis

all_runs = result.get_all_runs()
id2conf = result.get_id2config_mapping()

# START TODO ################

incumbent_id = result.get_incumbent_id()
incumbent_last_run = result.get_runs_by_id(incumbent_id)[-1]

incumbent_cs = id2conf[incumbent_id]['config']
incumbent_val_acc = incumbent_last_run.info['valid_accuracy']
incumbent_val_loss = incumbent_last_run.loss
model_bobh = incumbent_last_run.info['model']

print('Best found configuration: {}'.format(incumbent_cs))
print("===============================================================================")
print("")
print('Validation accuracy: {:.4f}, Validation loss: {:.5f}'.format(incumbent_val_acc, incumbent_val_loss))
print(model_bobh)

# END TODO ################
# Out:
# Best found configuration: {'cs_optimizer': 'Adam', 'num_filters_1': 20, 'lr': 0.002768354564022049, 'num_conv_layers': 1}
# ===============================================================================
#
# Validation accuracy: 0.9707, Validation loss: 0.02930
# Sequential(
#   (conv0): Conv2d(1, 20, kernel_size=(3, 3), stride=(1, 1))
#   (rel0): ReLU()
#   (pool0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (flat): Flatten()
#   (lin): Linear(in_features=3380, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax()
# )

# %% [markdown]
# We can gain deeper insight through plotting results. Thanks to the [HpBandSter Visualization Module](https://automl.github.io/HpBandSter/build/html/core/visualization.html) plotting is a one-liner.

# %%
import hpbandster.visualization as hpvis

all_runs = result.get_all_runs()
id2conf = result.get_id2config_mapping()

# %% [markdown]
# First let's see, if we really can evaluate more configurations when makeing use of low budget runs.
#
# **Task:** Plot the finished runs over time. How many runs per minute did finish for the individual budgets (only approximately)?
#
# **Answer:**
#
# #### For the budget 9
# * Number of finished runs: 20
# * Time: ~430s = 7.16 minute
# * **Average: 2,8 runs/minute**
#
# #### For the budget 3
# * Number of finished runs: 24
# * Time: ~370s = 6.16 minute
# * **Average: 3,9 runs/minute**
#
# #### For the budget 1
# * Number of finished runs: 37
# * Time: ~350s = 5.83 minute
# * **Average: 6,34 runs/minute**
#
# Note: Running on CPU

# %%
# START TODO ##################
import warnings

hpvis.finished_runs_over_time(all_runs)
warnings.filterwarnings("ignore")
# Out:
# 17:17:02 update_title_pos
# 17:17:02 update_title_pos
# 17:17:02 update_title_pos
# 17:17:02 update_title_pos
# 17:17:02 update_title_pos

# %% [markdown]
# Evaluating configurations on lower budgets doesn't make sense - even if they are faster - if the performance ranking isn't consistent from low to high budget. This means, that the loss rankings for configurations should correlate. In simplified terms: The best configuration after one epoch should also be the best after nine epochs, the second best should stay the second best and so on.
#
# **Task:** Plot correlations of rankings across budgets. Are the correlations high enough?
#
# **Answer:**
#
# It depends on the budget. The color and variable "spearman" represent the correlation. The closer is, the more correlation across budgets. A larger correlation should mean a lower loss.
#
# In our case, budget (9) and (1) have negative correlation between them. For the others, this correlation increases.

# %%
# START TODO ##################

hpvis.correlation_across_budgets(result)
# Out:
# 17:17:05 locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x7fc9c1649dd8>
# 17:17:05 Using auto colorbar locator on colorbar
# 17:17:05 locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x7fc9c1649dd8>
# 17:17:05 Setting pcolormesh
# (<Figure size 432x288 with 2 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fc9c168ac88>)
# 17:17:05 update_title_pos
# 17:17:05 not adjusting title pos because title was already placed manually: 1.050000
# 17:17:05 findfont: Matching :family=sans-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=12.0 to DejaVu Sans ('/home/eduardoalvarado/py_35_env/lib/python3.5/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf') with score of 0.050000.
# 17:17:05 update_title_pos
# 17:17:05 update_title_pos
# 17:17:05 title position was updated manually, not adjusting
# 17:17:05 update_title_pos
# 17:17:05 update_title_pos
# 17:17:05 title position was updated manually, not adjusting
# 17:17:05 update_title_pos
# 17:17:05 update_title_pos
# 17:17:05 title position was updated manually, not adjusting
# 17:17:05 update_title_pos
# 17:17:05 update_title_pos
# 17:17:05 title position was updated manually, not adjusting
# 17:17:05 update_title_pos

# %% [markdown]
# We usually assume, that training on a higher budget (number of epochs) and sampling more configurations can lead to better results. Let's check this.
#
# **Task:** Plot the losses over time. Do our assumptions hold true? Why?
#
# **Answer:**
#
# The different lines represent the budgets. A larger budget has lower loss. Nevertheless, and regardless the outliers, our three budgets have losses lower 0.2.

# %%
# START TODO ##################

hpvis.losses_over_time(all_runs)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fc9c155f940>)
# 17:17:18 update_title_pos
# 17:17:18 update_title_pos
# 17:17:18 update_title_pos
# 17:17:18 update_title_pos
# 17:17:18 update_title_pos

# %% [markdown]
# Remember that BOHB uses a model after some time to improve the configuation sampling. We can check, if the BO-sampled configurations work better than the random-sampled.
#
# **Task:** Plot loss histograms for all budgets only with BO-sampled and only with random-sampled configurations (6 histograms). Is the BO-sampling useful?
#
# **Answer:**
#
# Yes! In the subplots we can observe the following:
#
# In the case of the low budget (1), using random search, there is a large frequency of high losses during the  process. Instead, by using BOHB those large losses almost dissapear.
#
# In a general way, increasing budgets reduce the amount of large losses.
#
# This can be noticed in the budget (9) with BOHB, where the frequency of high losses decreases and only almost remain few small losses. For Random Search, to increase the budget doesn't provide any special advantage with respect to the medium-high losses.
#
# Therefore we can affirm that BOHB improves the efficiency for sampling.

# %%
# START TODO ##################

hpvis.performance_histogram_model_vs_random(all_runs, id2conf)
# Out:
# (<Figure size 432x288 with 6 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc9c152af60>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7fc9c15583c8>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc9c14e7668>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7fc9c14febe0>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc9c1515eb8>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7fc9c14b3470>]],
#        dtype=object))
# 17:17:22 update_title_pos
# 17:17:22 update_title_pos
# 17:17:22 update_title_pos
# 17:17:22 update_title_pos
# 17:17:22 update_title_pos
# 17:17:22 update_title_pos
# 17:17:22 update_title_pos
# 17:17:22 update_title_pos
# 17:17:22 update_title_pos
# 17:17:22 update_title_pos
# 17:17:22 update_title_pos
# 17:17:22 update_title_pos
# 17:17:22 update_title_pos
# 17:17:22 update_title_pos
# 17:17:22 update_title_pos
# 17:17:22 update_title_pos
# 17:17:22 update_title_pos
# 17:17:22 update_title_pos
# 17:17:23 update_title_pos
# 17:17:23 update_title_pos
# 17:17:23 update_title_pos
# 17:17:23 update_title_pos
# 17:17:23 update_title_pos
# 17:17:23 update_title_pos
# 17:17:23 update_title_pos
# 17:17:23 update_title_pos
# 17:17:23 update_title_pos
# 17:17:23 update_title_pos
# 17:17:23 update_title_pos
# 17:17:23 update_title_pos

# %% [markdown]
# ### Your Feedback on Exercise 6.2
#
# More difficult than the last part. We dedicate more time for this than expected. Although the beginning is similar, the debug and reasoning for BOHB requires a little bit of time to understand. Cool exercise! :)
