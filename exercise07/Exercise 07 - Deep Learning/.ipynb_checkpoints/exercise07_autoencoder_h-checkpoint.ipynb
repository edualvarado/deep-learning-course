# %% [markdown]
# # Seventh Exercise (Chapter 3 & Chapter 14)
#
# In the first part we will recap basics of probability theory.
#
# In the second part, we're going to implement an autoencoder and explore the learned latent space.

# %% [markdown]
# ## 7.1 Probability
#
# Solve the first two exercises mathematically. Answer using markdown and latex in this notebook. Please provide intermediate steps and explanations.
#
# ### 7.1.1 Bertrand's Box Paradox
#
# Consider a box containing the following 3 cards
#
# - one with two black sides
# - one with two white sides
# - one with a black and a white side
#
# From the three cards, one is drawn at random and put on the table. You can only see the side facing up.
#
# **Questions:**
#
# a) What are the probabilities that the card on the table shows a black side? What are the probabilities it shows a white side?
# b) If we draw a card and it shows black, compute the probability that the other side of the card is also black.
# c) Find the the probability that the other side of the card is black if the card shows a white side.

# %% [markdown]
# **Answers**
#
# $p(card1)=p(card2)=p(card3) = \frac{1}{3}$
#
# probabilty of a specific side of a card, given we don't distinguish between front and back if they have the same color : $\frac{1}{2}$
#
# **a)**
#
# $p(front = black) = \frac{1}{3} + \frac{1}{3}\times\frac{1}{2} = \frac{1}{2} $ either the black card or black side of the mix card
#
# $p(front = white) = \frac{1}{3} + \frac{1}{3}\times\frac{1}{2} = \frac{1}{2} $ either the white card or white side of the mix card
#
# **b)**
#
# $
# p(back=black|front=black) = \frac{p(front=black, back=black)}{p(back=black)}=\frac{\frac{1}{3}}{\frac{1}{3}+\frac{1}{3}\times\frac{1}{2}} = \frac{2}{3}
# $
#
# **c)**
#
# $p(back = black|front = white) = \frac{p(back=black, front=white)}{p(front=white)}=\frac{\frac{1}{3}}{\frac{1}{2}}=\frac{2}{3}$

# %% [markdown]
# ## 7.1.2 Entropy and Kullback Leibler Divergence
#
# **Questions:**
#
# a) Compute the Entropy of the normal distribution
#
# \begin{equation*}
# \mathcal N(x; \mu,\sigma) = \frac{1}{\sqrt{2\pi\sigma^2}} \mathrm{e}^{\frac{-(x-\mu)^2}{2\sigma^2}}\,.
# \end{equation*}
#
# b) Find the Kullback-Leibler divergence between two Gaussian distributions, i.e.
#
# \begin{equation*}
# D_{KL}\left( \mathcal N(\mu_1, \sigma_1) \vert\vert \mathcal N(\mu_2, \sigma_2) \right)\,.
# \end{equation*}
#
# **Answers:**
#
# **A)**
#
# $
# p(x)=\frac{1}{\sqrt{2\pi\sigma^2}}e^{\frac{-(x-\mu)^2}{2\sigma^2}} \\
# \int_{-\infty}^{\infty}f(x)=1 \\
# H(p)=-\mathbb{E}_{x \sim p}[log(p(x))] = -\int_{-\infty}^{\infty}f(x)log(f(x))dx = \\
# -\int_{-\infty}^{\infty}f(x)log(\frac{1}{\sqrt{2\pi\sigma^2}})dx - log(e)\int_{-\infty}^{\infty}f(x)\frac{-(x-\mu)^2}{2\sigma^2}dx = \\
# \frac{1}{2}log(2\pi\sigma^2)+ log(e)\frac{\sigma^2}{2\sigma^2} = \frac{1}{2}(log(2\pi\sigma^2)+log(e))=\\
# \frac{1}{2}log(2\pi e\sigma^2)
# $
#
# **B)**
#
# $
# p\sim\mathcal N(\mu_1, \sigma_1)\\ q\sim\mathcal N(\mu_2, \sigma_2)\\
# D_{KL} (p||q) = H(p,q) - H(p) = -\int p(x)log(q(x))dx + \int p(x)log(p(x))dx \\
# H(p,q) = -\int p(x)log(q(x))dx = -\int p(x)log(\frac{1}{\sqrt{2\pi\sigma_2^2}})dx - log(e)\int p(x)\frac{-(x-\mu_2)^2}{2\sigma_2^2}dx = \\
# \frac{1}{2}log(2\pi\sigma_2^2)+ \frac{\int p(x)x^2dx - \int p(x)2x\mu_2 dx+\int p(x)\mu_2^2dx}{2\sigma_2^2} =\\
# \frac{1}{2}log(2\pi\sigma_2^2)+ \frac{\mathbb{E}[x^2]-2\mathbb{E}[x]\mu_2 +\mu_2^2}{2\sigma_2^2} = \frac{1}{2}log(2\pi\sigma_2^2)+ \frac{\sigma_1^2+\mu_1^2-2\mu_1\mu_2 +\mu_2^2}{2\sigma_2^2} = \\
# \frac{1}{2}log(2\pi\sigma_2^2)+ \frac{\sigma_1^2+(\mu_1-\mu_2)^2}{2\sigma_2^2} \\
# D_{KL} (p||q) = H(p,q) - H(p) = \frac{1}{2}log(2\pi\sigma_2^2)+ \frac{\sigma_1^2+(\mu_1-\mu_2)^2}{2\sigma_2^2} - \frac{1}{2}log(2\pi e\sigma_1^2) = \\
# log\frac{\sigma_2}{\sigma_1}+\frac{\sigma_1^2+(\mu_1-\mu_2)^2}{2\sigma_2^2} - \frac{1}{2}
# $

# %% [markdown]
# ## 7.1.3 Distributions and CLT
#
# The central limit theorem states that for i.i.d. random samples $\{X_i\}$ from an (almost) arbitrary distribution with given mean $\mu$ and variance $\sigma^2$, the mean $\frac{1}{n}\sum_{i=1}^n X_i$ follows approximately a normal distribution. More precisely, it reads
#
# \begin{equation*}
# 	\frac{1}{n} \sum_{i=1}^n X_i \xrightarrow{n\to\infty} \mathcal N(\mu, \frac{\sigma^2}{\sqrt{n}})\,.
# \end{equation*}
#
# **Questions:**
#
# - a) Draw $n=1,16,64, 1024$ samples from the distributions below for $1024$ times (each). Draw for each (n, distribution) pair a histogram over the sample mean. Include the corresponding normal distribution (pdf) in the plot.
#
#     - the exponential distribution $p(X) = \lambda \mathrm{e}^{-\lambda X}$
#     - the Gaussian/normal distribution
# - b) Assume, that you can only sample from uniform distributions. Implement functions to sample from an approximated standard normal distribution and an approximated normal distribution. Plot the distributions in comparison to the numpy implementation.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

sample_count = [1, 16, 64, 1024]

for idx, sc in enumerate(sample_count):
    means_exp = []
    means_normal = []
    for i in range(1024):
        means_exp.append(np.mean(np.random.exponential(size = sc)))
        means_normal.append(np.mean(np.random.normal(size = sc)))
    means_exp.sort()
    means_normal.sort()
    plt.figure()
    plt.title(f"histogram of sample means, size:{sc}, exponential distribution")
    plt.plot(means_exp,stats.norm.pdf(means_exp, np.mean(means_exp), np.std(means_exp)),'-.')
    plt.hist(means_exp,density=True)
    plt.figure()
    plt.title(f"histogram of sample means, size:{sc}, normal distribution")
    plt.plot(means_normal,stats.norm.pdf(means_normal, np.mean(means_normal), np.std(means_normal)),'-.')
    plt.hist(means_normal,density=True)
    #plt.plot(stats.norm.pdf(means,mu,var))

# %%
# b)
def std_normal(size: int = 1) -> np.ndarray:
    """ Sample from a standard normal distribution. 
        The normal distribution is approximated via a uniform dist.
    
        n_samples: number of samples of a standard normal distribution
        return:    samples. length = n_samples
    """
    ret = np.zeros(size)
    for i in range(size):
        ret[i] = 0.5*np.sum(np.random.uniform(-1,1,12))
    return ret

def normal(loc: float = 0.0, scale: float = 1.0, size: int = 1) -> np.ndarray:
    """ Sample from a normal distribution.
        The normal distribution is approximated via a uniform dist.
    
        loc: mean of the distribution
        scale: standard deviation spread of the distribution.
        
        n_samples: number of samples
        return:    samples. length = n_samples
    """
    ret = np.zeros(size)
    for i in range(size):
        ret[i] = 0.5*np.sum(np.random.uniform(-scale,scale,12))
        ret[i] += loc
    return ret

n_samples = 10000
nbins = 20

sl_std_normal = std_normal(n_samples)
plt.figure()
plt.title("self implemented std normal distribution")
plt.hist(sl_std_normal, bins=nbins)

np_std_normal = np.random.normal(size=n_samples)
plt.figure()
plt.title("numpy std normal distribution")
plt.hist(np_std_normal, bins=nbins)
## END TODO ########################

# plot histograms for N(mean=-10, std=3) with normal and np.random.normal
## START TODO ########################
sl_normal = normal(loc=-10, scale= 3, size=n_samples)
plt.figure()
plt.title("self implemented normal distribution")
plt.hist(sl_normal, bins=nbins)

np_normal = np.random.normal(loc=-10, scale = 3, size = n_samples)
plt.figure()
plt.title("numpy normal distribution")
plt.hist(np_normal, bins =nbins)
## END TODO ########################
# Out:
# (array([1.000e+00, 8.000e+00, 1.200e+01, 4.200e+01, 8.300e+01, 2.500e+02,
#         4.140e+02, 8.160e+02, 1.133e+03, 1.399e+03, 1.519e+03, 1.452e+03,
#         1.213e+03, 8.030e+02, 4.690e+02, 2.450e+02, 8.700e+01, 3.600e+01,
#         1.400e+01, 4.000e+00]),
#  array([-22.48128236, -21.30221118, -20.12313999, -18.94406881,
#         -17.76499762, -16.58592644, -15.40685525, -14.22778407,
#         -13.04871288, -11.8696417 , -10.69057051,  -9.51149933,
#          -8.33242815,  -7.15335696,  -5.97428578,  -4.79521459,
#          -3.61614341,  -2.43707222,  -1.25800104,  -0.07892985,
#           1.10014133]),
#  <a list of 20 Patch objects>)

# %% [markdown]
# ### Your Feedback on Exercise 7.1
#
# * **Major Problems: ** Some probability theory that I had to look up online
# * **Helpful? ** Yes
# * **Duration (hours): ** 2~3 hours
# * **Other feedback: ** It'd be great if we knew how the first exercise relates to the second one

# %% [markdown]
# ## 7.2 Autoencoder
#
# Let's now implement our own variational auto encoder (VAE). The VAE is described in chapter 20.10.3 of the Deep Learning Book and you can find the original paper [here](https://arxiv.org/pdf/1312.6114.pdf).
#
# Compared to a "standard" auto encoder, a VAE learns to approximate the posterior.

# %%
from __future__ import print_function
import os
import argparse
from typing import Tuple

import torch
import torch.utils.data
from torch import nn, optim
from torch.nn import functional as F
from torchvision import datasets, transforms
from torchvision.utils import save_image

import numpy as np
import matplotlib.pyplot as plt

# %%
torch.manual_seed(0)
device = torch.device("cpu")

# %%
train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=True, download=True,
    transform=transforms.Compose([transforms.ToTensor()])),
    batch_size=128, shuffle=True)
test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=False, transform=transforms.ToTensor()),
    batch_size=128, shuffle=False)

# %%
class Flatten(nn.Module): 
    def forward(self, input):
        self.input_shape = input.shape
        return input.view(input.size(0), -1)
    
class VAE(nn.Module):
    def __init__(self, latent_space_size=2):
        super().__init__()
        """Variational auto encoder.
        
        Create the VAE with the MLP encoder having one hidden layer
        and two output layers (mean and log of the variance).
        Use a hidden size of 100 and each output size of `latent_space_size`.
        
        The decoder should be as powerful as the encoder.
        """
        self.input_size = 28*28
        self.hidden_size = 100
        self.latent_size = latent_space_size
        self.encode_hidden = nn.Linear(self.input_size,self.hidden_size)
        self.encode_latent_mu  = nn.Linear(self.hidden_size, latent_space_size)
        self.encode_latent_std = nn.Linear(self.hidden_size, latent_space_size)
        
        self.decode_hidden  = nn.Linear(latent_space_size, self.hidden_size)
        self.decode_output = nn.Linear(self.hidden_size, self.input_size)
        
    def encode(self, x) -> Tuple[torch.Tensor, torch.Tensor]:
        """ Encode x to distribution.
        
        Compute the hidden representation. Estimate and return the mean
        and the log of the variance from the hidden representation. Use
        relu as activation function for the hidden representation.
        """
        x = Flatten().forward(x)
        hidden = self.encode_hidden.forward(x)
        rel = nn.ReLU()
        hidden = rel(hidden)
        mu = self.encode_latent_mu.forward(hidden)
        logvar = self.encode_latent_std.forward(hidden)
        #logvar = torch.log(logvar)
        return mu, logvar
    
    def reparameterize(self, mu, logvar) -> torch.Tensor:
        """Sample from the estimated distribution.
        
        In training mode, return a sample from N(mu, logvar).
        In evaluation mode, just return the mean.
        
        Hint: You estimate the log of the variance, so you need to transform
        this to std deviation first, as torch.randn
        """
        sample = mu
        if self.training:
            std = torch.exp(0.5*logvar)
            epsilon = torch.randn(mu.shape)
            sample = mu + std*epsilon
            assert sample.requires_grad, "fuck you"
        
        return sample

    def decode(self, z) -> torch.Tensor:
        """ Decode the latent representation.
        
        Compute the hidden representation from the latent space z,
        use relu as activation. Then reconstruct the signal from
        the hidden representation, using a sigmoid as activation.
        """
        hidden = self.decode_hidden.forward(z)
        rel = nn.ReLU()
        hidden = rel(hidden)
        output = self.decode_output.forward(hidden)
        sig = nn.Sigmoid()
        x_reconstructed = sig(output)
        return x_reconstructed
    def forward(self, x) -> Tuple[torch.Tensor, torch.Tensor, torch.Tensor]:
        """Encode, reparameterize and decode.
        
        Returns:
            (The decoded result, mu, logvar)
        """
        mu, logvar = self.encode(x)
        mu_r = self.reparameterize(mu, logvar)
        x_reconstructed = self.decode(mu_r)
        return x_reconstructed, mu, logvar

# %%
# Reconstruction + KL divergence losses summed over all elements and batch
def loss_function(x_reconstructed, x, mu, logvar, kl_loss_weight=1):
    ## START TODO ########################
    # compute the binary cross entropy between x and the reconstructed x
    
    rec_loss = F.binary_cross_entropy(x_reconstructed.view(x_reconstructed.shape[0],1,28,28),x, reduction='sum')
    
    # Here your results from 7.1.2 come into play - The first distribution is
    # the N(mu, logvar) and the second is N(0, 1). Plugging this into
    # the result from 7.1.2 yields
    # 0.5 * sum(1 + log(sigma^2) - mu^2 - sigma^2)
    # you can also check Appendix B from the VAE paper:
    # https://arxiv.org/abs/1312.6114
    var = torch.exp(logvar)
    kl_div_loss = - 0.5 * torch.sum(1 + logvar - torch.pow(mu,2) - var)
    
    ## END TODO ########################
    return rec_loss + kl_div_loss * kl_loss_weight

# %%
def train(model, epoch, optimizer, kl_loss_weight=1, save_images=False):
    model.train()
    train_loss = 0
    for batch_idx, (data, _) in enumerate(train_loader):
        data = data.to(device)
        optimizer.zero_grad()
        reconstructed_batch, mu, logvar = model(data)
        loss = loss_function(reconstructed_batch, data, mu, logvar, kl_loss_weight)
        loss.backward()
        train_loss += loss.item()
        optimizer.step()
    if save_images:
        n = min(data.size(0), 8)
        training_image = torch.cat([data[:n]])
        save_image(training_image.cpu(),
                   'results/training_samples_' + str(epoch) + '.png', nrow=n)

    print('====> Epoch: {} Average train set loss: {:.4f}'.format(
          epoch, train_loss / len(train_loader.dataset)))


def test(model, epoch, kl_loss_weight=1, save_images=False):
    model.eval()
    test_loss = 0
    with torch.no_grad():
        for i, (data, _) in enumerate(test_loader):
            data = data.to(device)
            reconstructed_batch, mu, logvar = model(data)
            test_loss += loss_function(reconstructed_batch, data, mu, logvar, kl_loss_weight).item()
            if i == 0:
                n = min(data.size(0), 8)
                comparison = torch.cat([data[:n], reconstructed_batch.view(128, 1, 28, 28)[:n]])
                if not save_images:
                    continue
                save_image(comparison.cpu(),
                         'results/reconstruction_' + str(epoch) + '.png', nrow=n)

    test_loss /= len(test_loader.dataset)
    print('====> Average test set loss: {:.4f}'.format(test_loss))

# %%
latent_space_size = 2
model = VAE(latent_space_size).to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-3)

if not os.path.isdir('results'):
    os.mkdir('results')

for epoch in range(1, 25):
    train(model, epoch, optimizer, save_images=True)
    test(model, epoch, save_images=True)
    with torch.no_grad():
        ## START TODO ########################
        # sample 64 images (generate a random latent_space and decode)
        samples = model.decode(torch.randn(64,2))
        save_image(samples.view(64, 1, 28, 28),
                   'results/sample_' + str(epoch) + '.png')
# Out:
# ====> Epoch: 1 Average train set loss: 212.4038
# ====> Average test set loss: 180.6513
# ====> Epoch: 2 Average train set loss: 177.7111
# ====> Average test set loss: 172.0407
# ====> Epoch: 3 Average train set loss: 171.2833
# ====> Average test set loss: 166.8174
# ====> Epoch: 4 Average train set loss: 167.5602
# ====> Average test set loss: 164.3448
# ====> Epoch: 5 Average train set loss: 165.3301
# ====> Average test set loss: 162.8239
# ====> Epoch: 6 Average train set loss: 163.6668
# ====> Average test set loss: 161.4392
# ====> Epoch: 7 Average train set loss: 162.5607
# ====> Average test set loss: 160.4709
# ====> Epoch: 8 Average train set loss: 161.5376
# ====> Average test set loss: 159.6688
# ====> Epoch: 9 Average train set loss: 160.7893
# ====> Average test set loss: 158.9864
# ====> Epoch: 10 Average train set loss: 160.0927
# ====> Average test set loss: 158.4552
# ====> Epoch: 11 Average train set loss: 159.5619
# ====> Average test set loss: 157.9971
# ====> Epoch: 12 Average train set loss: 159.0554
# ====> Average test set loss: 157.5810
# ====> Epoch: 13 Average train set loss: 158.6198
# ====> Average test set loss: 157.3133
# ====> Epoch: 14 Average train set loss: 158.1596
# ====> Average test set loss: 157.1120
# ====> Epoch: 15 Average train set loss: 157.8234
# ====> Average test set loss: 156.7184
# ====> Epoch: 16 Average train set loss: 157.5307
# ====> Average test set loss: 156.2432
# ====> Epoch: 17 Average train set loss: 157.1309
# ====> Average test set loss: 155.9921
# ====> Epoch: 18 Average train set loss: 156.8468
# ====> Average test set loss: 155.5840
# ====> Epoch: 19 Average train set loss: 156.5952
# ====> Average test set loss: 155.4106
# ====> Epoch: 20 Average train set loss: 156.3267
# ====> Average test set loss: 155.3320
# ====> Epoch: 21 Average train set loss: 156.0545
# ====> Average test set loss: 155.0349
# ====> Epoch: 22 Average train set loss: 155.7814
# ====> Average test set loss: 155.3334
# ====> Epoch: 23 Average train set loss: 155.5632
# ====> Average test set loss: 154.5323
# ====> Epoch: 24 Average train set loss: 155.3222
# ====> Average test set loss: 154.4624

# %% [markdown]
# ## Exploring the latent space
#
# One of the easiest ways to visualize the latent space is to limit the size to two dimensions (which of course might not always capture the data well) and to sample from the model over a 2D grid. This is what we're going to do below. Also, we can nicely visualize the concept of a VAE. We plot the mean over the estimated means for each class (the numbers 0 to 9) and the mean estimated standard deviation for each class (the blue crosses).

# %%
def get_mu_logvar(model: nn.Module) -> Tuple[torch.Tensor, torch.Tensor]:
    """Compute the model's prediction of mean and logvar for all
       images in the MNIST test set.
    """
    mus, logvars = [], []
    for data, _ in test_loader:
        data = data.to(device)
        reconstructed_batch, mu, logvar = model(data)
        mus.append(mu)
        logvars.append(logvar)
    return torch.cat(mus), torch.cat(logvars)

def sample_on_grid(latent_min: Tuple[int, int], latent_max: Tuple[int, int], 
                   model: nn.Module, grid_size: int) -> Tuple[np.ndarray, np.ndarray]:
    ## START TODO ########################
    # create a grid in two directions from latent_min to latent_max, using
    # the respective dimension
    x1 = torch.linspace(latent_min[0],latent_max[0],grid_size)
    x2 = torch.linspace(latent_min[1],latent_max[1],grid_size)
    # use the created grid as latent variables and run them through the decoder
    x1v, x2v = torch.meshgrid([x1, x2])
    x1v = x1v.reshape(1,-1)
    x2v = x2v.reshape(1,-1)
    decoded = model.decode(torch.t(torch.cat([x2v,x1v])))
    print(decoded.shape)
    ## END TODO ########################
    step_size = np.array((x1[1] - x1[0], x2[1] - x2[0]))
    return decoded.reshape(grid_size, grid_size, 28, 28), step_size

def plot_latent_space(model: nn.Module):
    model.eval()
    mus, logvars = get_mu_logvar(model)
    mus = mus.detach().numpy()
    stddev = np.exp(0.5*logvars.detach().numpy())

    labels = torch.cat([label for _, label in test_loader]).detach().numpy()
    num_samples = labels.shape[0]
    class_mu_0 = np.bincount(labels, weights=mus[:, 0]) / np.bincount(labels)
    class_mu_1 = np.bincount(labels, weights=mus[:, 1]) / np.bincount(labels)
    mean_mu = np.stack((class_mu_0, class_mu_1))
    print("Per class mean of estimated mean:\n", mean_mu)

    class_stddev_0 = np.bincount(labels, weights=stddev[:, 0]) / np.bincount(labels)
    class_stddev_1 = np.bincount(labels, weights=stddev[:, 1]) / np.bincount(labels)
    mean_stddev = np.stack((class_stddev_0, class_stddev_1))
    print("Per class mean of estimated std deviation:\n", mean_stddev)

    # get the minimum and maximum values of the latent space means
    # we will use this as boundaries from which we sample in the latent space
    latent_min = np.min(mean_mu - mean_stddev * 2, axis=1)
    latent_max = np.max(mean_mu + mean_stddev * 2, axis=1)

    # Produce a 20x20 2D grid of evenly spaced values between latent_min ant latent_max
    decoded, step_size = sample_on_grid(latent_min, latent_max, model, grid_size=20)
    
    # visualize the decoded images
    # using reshape and np.concatenate and calling imshow only once
    # is a lot faster than creating a subplot and calling imshow 400 times.
    # It's also necessary to be able to plot the means
    block_img = np.concatenate(np.concatenate(decoded.detach().numpy(), axis=1), axis=1)
    f = plt.figure(figsize=(12,12))
    plt.imshow(block_img, cmap='Greys')
    plt.axis('off');

    # visualize the mean mu and the mean standard deviation of each class
    # scale the mean accordingly, as the plot's axes represent pixels
    scale = (28 / step_size)

    mean_mu_scaled = 28/2 + scale.reshape(2, 1) * (mean_mu - latent_min.reshape(2,1))
    # we scale the stddev by 2 so the arrows are extended a bit more
    mean_stddev_scaled = mean_stddev * scale.reshape(2, 1) * 2
    # plot the std deviation
    plt.errorbar(mean_mu_scaled[0], mean_mu_scaled[1],
                 yerr=mean_stddev_scaled[1], xerr=mean_stddev_scaled[0],
                 linestyle='None')
    # plot the means
    plt.scatter(mean_mu_scaled[0], mean_mu_scaled[1])

    for i, txt in enumerate([str(i) for i in range(0,10)]):
        plt.annotate(txt, (mean_mu_scaled[0][i] + 3, mean_mu_scaled[1][i] - 3),
                     color='blue',
                     bbox={'facecolor':'white', 'alpha':0.9, 'pad':1, 'edgecolor':'none'})
    plt.show()

plot_latent_space(model)
# Out:
# Per class mean of estimated mean:
#  [[-1.82719205  2.503451   -0.52467031 -0.62310358  0.65020801 -0.32120499
#   -0.94414874  1.1633943   0.06083594  0.94573426]
#  [-0.75411672 -0.95796621  0.24038881  1.6053405   0.75302089  0.68411427
#   -0.27642463  0.83821919  0.27783647  1.10105513]]
# Per class mean of estimated std deviation:
#  [[0.07840367 0.16203628 0.050947   0.06700495 0.06549549 0.07364384
#   0.05919698 0.07405652 0.06689571 0.06776024]
#  [0.0732348  0.11062959 0.0635954  0.1424053  0.08796873 0.10642435
#   0.05481909 0.09076284 0.08013115 0.09767337]]
# torch.Size([400, 784])

# %% [markdown]
# ## Exploring the influence of the KL-divergence in the loss
#
# Let's now investigate the influence of the KL-divergence by training
# - one model where we weight the KL-divergence part of the loss by a factor of 30 and
# - one model where we remove it (weight 0).
#
# Visualize the latent space as we did above.
#
# **ToDo** What do you observe? How can these results be explained? What is the role of the KL divergence term?

# %%
latent_space_size = 2
model_large_kl = VAE(latent_space_size).to(device)
optimizer = optim.Adam(model_large_kl.parameters(), lr=1e-3)

if not os.path.isdir('results'):
    os.mkdir('results')

for epoch in range(1, 15):
    train(model_large_kl, epoch, optimizer, kl_loss_weight=30, save_images=True)
    test(model_large_kl, epoch, save_images=True)
    with torch.no_grad():
        # sample 64 images (generate a random latent_space and decode)
        samples = model_large_kl.decode(torch.randn(64,2))
        save_image(samples.view(64, 1, 28, 28),
                   'results/sample_' + str(epoch) + '.png')
# Out:
# ====> Epoch: 1 Average train set loss: 238.1503
# ====> Average test set loss: 209.2627
# ====> Epoch: 2 Average train set loss: 206.9451
# ====> Average test set loss: 206.5583
# ====> Epoch: 3 Average train set loss: 206.4917
# ====> Average test set loss: 205.8896
# ====> Epoch: 4 Average train set loss: 206.3981
# ====> Average test set loss: 205.9334
# ====> Epoch: 5 Average train set loss: 206.2895
# ====> Average test set loss: 205.7869
# ====> Epoch: 6 Average train set loss: 206.3033
# ====> Average test set loss: 205.8225
# ====> Epoch: 7 Average train set loss: 206.2113
# ====> Average test set loss: 205.6860
# ====> Epoch: 8 Average train set loss: 206.2435
# ====> Average test set loss: 205.6767
# ====> Epoch: 9 Average train set loss: 206.2583
# ====> Average test set loss: 205.7080
# ====> Epoch: 10 Average train set loss: 206.2110
# ====> Average test set loss: 205.5401
# ====> Epoch: 11 Average train set loss: 206.2260
# ====> Average test set loss: 205.5294
# ====> Epoch: 12 Average train set loss: 206.1873
# ====> Average test set loss: 205.2144
# ====> Epoch: 13 Average train set loss: 206.2044
# ====> Average test set loss: 205.4575
# ====> Epoch: 14 Average train set loss: 206.1664
# ====> Average test set loss: 204.8741

# %%
plot_latent_space(model_large_kl)
# Out:
# Per class mean of estimated mean:
#  [[-0.16370565  0.10154491 -0.02474059  0.01481356 -0.00261471 -0.01036983
#   -0.04648775  0.03414887  0.01092139  0.02074822]
#  [-0.26230572  0.1712417  -0.07117777 -0.02699205  0.02442055 -0.01748835
#   -0.07432693  0.09468885  0.00612781  0.06308554]]
# Per class mean of estimated std deviation:
#  [[0.94555655 1.03260152 0.9817254  0.99364423 0.99695546 0.99318763
#   0.97908239 1.00999112 0.99775606 1.00509844]
#  [0.94864245 1.0140313  0.97937746 0.98926358 0.99004364 0.98831715
#   0.97704433 0.99868805 0.99122847 0.99574539]]
# torch.Size([400, 784])

# %%
model_no_kl = VAE(latent_space_size).to(device)
optimizer = optim.Adam(model_no_kl.parameters(), lr=1e-3)

for epoch in range(1, 15):
    train(model_no_kl, epoch, optimizer, kl_loss_weight=0, save_images=False)
    test(model_no_kl, epoch, save_images=False)
    with torch.no_grad():
        # sample 64 images (generate a random latent_space and decode)
        samples = model_no_kl.decode(torch.randn(64,2))
        save_image(samples.view(64, 1, 28, 28),
                   'results/sample_' + str(epoch) + '.png')
# Out:
# ====> Epoch: 1 Average train set loss: 201.5385
# ====> Average test set loss: 224.1255
# ====> Epoch: 2 Average train set loss: 171.5271
# ====> Average test set loss: 221.1136
# ====> Epoch: 3 Average train set loss: 166.1444
# ====> Average test set loss: 218.2018
# ====> Epoch: 4 Average train set loss: 162.8701
# ====> Average test set loss: 217.8720
# ====> Epoch: 5 Average train set loss: 160.6287
# ====> Average test set loss: 222.4518
# ====> Epoch: 6 Average train set loss: 158.9624
# ====> Average test set loss: 226.0967
# ====> Epoch: 7 Average train set loss: 157.6484
# ====> Average test set loss: 227.4332
# ====> Epoch: 8 Average train set loss: 156.5939
# ====> Average test set loss: 234.6793
# ====> Epoch: 9 Average train set loss: 155.7841
# ====> Average test set loss: 233.2041
# ====> Epoch: 10 Average train set loss: 154.9698
# ====> Average test set loss: 241.9779
# ====> Epoch: 11 Average train set loss: 154.2862
# ====> Average test set loss: 239.2532
# ====> Epoch: 12 Average train set loss: 153.6838
# ====> Average test set loss: 243.2820
# ====> Epoch: 13 Average train set loss: 153.0685
# ====> Average test set loss: 247.7471
# ====> Epoch: 14 Average train set loss: 152.5301
# ====> Average test set loss: 248.5753

# %%
plot_latent_space(model_no_kl)
# Out:
# Per class mean of estimated mean:
#  [[  7.3163318  -25.73302726   0.8477038   -0.0618691   -3.63750831
#    -0.78588621   3.23306432 -10.18908857  -2.08521595  -6.0503858 ]
#  [  3.30220549  -2.03604621   3.07021432   9.56904788   5.05170874
#     6.31164576   3.3984304   10.50893733   3.52208044   7.76521003]]
# Per class mean of estimated std deviation:
#  [[0.00047247 0.01251587 0.00201716 0.00186835 0.00187691 0.00312813
#   0.00213264 0.00191734 0.00122359 0.0011181 ]
#  [0.00042874 0.00266951 0.00207563 0.00202324 0.00122843 0.00193192
#   0.00144759 0.00168208 0.00067084 0.00079806]]
# torch.Size([400, 784])

# %% [markdown]
# ### Your Feedback on Exercise 7.2
#
# * **Major Problems: ** Not any major problems. it wasn't working but you helped me in the exercise session. I still don't completely understand the (probability)theory behind it. My axes were flipped but I flipped the way I concatenated the vectors and it worked.
# * **Helpful? ** Very. The generative models are the most interesting topic in deep learning.
# * **Duration (hours): ** overall maybe 8-9 hours in 3 days, including the time I spent reading the book to understand the theory.
# * **Other feedback: **
